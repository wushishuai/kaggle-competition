# %% [markdown]
# # Imports

# %%
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing, impute
from IPython.display import display

plt.style.use('ggplot')

# %%
random_state = 42

# %% [markdown]
# # Data Collection

# %%
df_train = pd.read_csv('train.csv', index_col=0)
X_test = pd.read_csv('test.csv', index_col=0)

# %%
column_y = df_train.columns.difference(X_test.columns)[0]
X = df_train.drop(columns=column_y)
y = df_train[column_y]

# %%
X.index.intersection(X_test.index)
# Out:
# Int64Index([], dtype='int64', name='Id')

# %%
df_combined = pd.concat([X.assign(set='train'),
                         X_test.assign(set='test')], axis=0)

# %%
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 1 to 2919
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2919 non-null   int64
#  1   MSZoning       2915 non-null   object
#  2   LotFrontage    2433 non-null   float64
#  3   LotArea        2919 non-null   int64
#  4   Street         2919 non-null   object
#  5   Alley          198 non-null    object
#  6   LotShape       2919 non-null   object
#  7   LandContour    2919 non-null   object
#  8   Utilities      2917 non-null   object
#  9   LotConfig      2919 non-null   object
#  10  LandSlope      2919 non-null   object
#  11  Neighborhood   2919 non-null   object
#  12  Condition1     2919 non-null   object
#  13  Condition2     2919 non-null   object
#  14  BldgType       2919 non-null   object
#  15  HouseStyle     2919 non-null   object
#  16  OverallQual    2919 non-null   int64
#  17  OverallCond    2919 non-null   int64
#  18  YearBuilt      2919 non-null   int64
#  19  YearRemodAdd   2919 non-null   int64
#  20  RoofStyle      2919 non-null   object
#  21  RoofMatl       2919 non-null   object
#  22  Exterior1st    2918 non-null   object
#  23  Exterior2nd    2918 non-null   object
#  24  MasVnrType     2895 non-null   object
#  25  MasVnrArea     2896 non-null   float64
#  26  ExterQual      2919 non-null   object
#  27  ExterCond      2919 non-null   object
#  28  Foundation     2919 non-null   object
#  29  BsmtQual       2838 non-null   object
#  30  BsmtCond       2837 non-null   object
#  31  BsmtExposure   2837 non-null   object
#  32  BsmtFinType1   2840 non-null   object
#  33  BsmtFinSF1     2918 non-null   float64
#  34  BsmtFinType2   2839 non-null   object
#  35  BsmtFinSF2     2918 non-null   float64
#  36  BsmtUnfSF      2918 non-null   float64
#  37  TotalBsmtSF    2918 non-null   float64
#  38  Heating        2919 non-null   object
#  39  HeatingQC      2919 non-null   object
#  40  CentralAir     2919 non-null   object
#  41  Electrical     2918 non-null   object
#  42  1stFlrSF       2919 non-null   int64
#  43  2ndFlrSF       2919 non-null   int64
#  44  LowQualFinSF   2919 non-null   int64
#  45  GrLivArea      2919 non-null   int64
#  46  BsmtFullBath   2917 non-null   float64
#  47  BsmtHalfBath   2917 non-null   float64
#  48  FullBath       2919 non-null   int64
#  49  HalfBath       2919 non-null   int64
#  50  BedroomAbvGr   2919 non-null   int64
#  51  KitchenAbvGr   2919 non-null   int64
#  52  KitchenQual    2918 non-null   object
#  53  TotRmsAbvGrd   2919 non-null   int64
#  54  Functional     2917 non-null   object
#  55  Fireplaces     2919 non-null   int64
#  56  FireplaceQu    1499 non-null   object
#  57  GarageType     2762 non-null   object
#  58  GarageYrBlt    2760 non-null   float64
#  59  GarageFinish   2760 non-null   object
#  60  GarageCars     2918 non-null   float64
#  61  GarageArea     2918 non-null   float64
#  62  GarageQual     2760 non-null   object
#  63  GarageCond     2760 non-null   object
#  64  PavedDrive     2919 non-null   object
#  65  WoodDeckSF     2919 non-null   int64
#  66  OpenPorchSF    2919 non-null   int64
#  67  EnclosedPorch  2919 non-null   int64
#  68  3SsnPorch      2919 non-null   int64
#  69  ScreenPorch    2919 non-null   int64
#  70  PoolArea       2919 non-null   int64
#  71  PoolQC         10 non-null     object
#  72  Fence          571 non-null    object
#  73  MiscFeature    105 non-null    object
#  74  MiscVal        2919 non-null   int64
#  75  MoSold         2919 non-null   int64
#  76  YrSold         2919 non-null   int64
#  77  SaleType       2918 non-null   object
#  78  SaleCondition  2919 non-null   object
#  79  set            2919 non-null   object
# dtypes: float64(11), int64(25), object(44)
# memory usage: 1.8+ MB

# %% [markdown]
# # Short EDA before Processing

# %% [markdown]
# ## Comparison Train / Test

# %%
pd.concat([X.isna().sum().rename('train'),
           X_test.isna().sum().rename('test')], axis=1)\
    .astype('int')\
    .sort_values(['train', 'test'], ascending=False)\
    .style.background_gradient(vmin=0, vmax=max([X.shape[0], X_test.shape[0]]))
# Out:
# <style type="text/css">
# #T_815ac_row0_col0 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_815ac_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_815ac_row1_col0, #T_815ac_row1_col1 {
#   background-color: #034267;
#   color: #f1f1f1;
# }
# #T_815ac_row2_col0 {
#   background-color: #034871;
#   color: #f1f1f1;
# }
# #T_815ac_row2_col1 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_815ac_row3_col0 {
#   background-color: #0566a0;
#   color: #f1f1f1;
# }
# #T_815ac_row3_col1 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_815ac_row4_col0 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_815ac_row4_col1 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_815ac_row5_col0 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_815ac_row5_col1 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_815ac_row6_col0, #T_815ac_row6_col1, #T_815ac_row7_col0, #T_815ac_row7_col1, #T_815ac_row8_col0, #T_815ac_row8_col1, #T_815ac_row9_col0, #T_815ac_row9_col1, #T_815ac_row10_col0, #T_815ac_row10_col1 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_815ac_row11_col0, #T_815ac_row12_col0, #T_815ac_row13_col0, #T_815ac_row14_col0, #T_815ac_row15_col0 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_815ac_row11_col1, #T_815ac_row12_col1, #T_815ac_row13_col1, #T_815ac_row14_col1, #T_815ac_row15_col1 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_815ac_row16_col0, #T_815ac_row17_col0 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_815ac_row16_col1, #T_815ac_row17_col1 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_815ac_row18_col0, #T_815ac_row18_col1, #T_815ac_row19_col0, #T_815ac_row19_col1, #T_815ac_row20_col0, #T_815ac_row20_col1, #T_815ac_row21_col0, #T_815ac_row21_col1, #T_815ac_row22_col0, #T_815ac_row22_col1, #T_815ac_row23_col0, #T_815ac_row23_col1, #T_815ac_row24_col0, #T_815ac_row24_col1, #T_815ac_row25_col0, #T_815ac_row25_col1, #T_815ac_row26_col0, #T_815ac_row26_col1, #T_815ac_row27_col0, #T_815ac_row27_col1, #T_815ac_row28_col0, #T_815ac_row28_col1, #T_815ac_row29_col0, #T_815ac_row29_col1, #T_815ac_row30_col0, #T_815ac_row30_col1, #T_815ac_row31_col0, #T_815ac_row31_col1, #T_815ac_row32_col0, #T_815ac_row32_col1, #T_815ac_row33_col0, #T_815ac_row33_col1, #T_815ac_row34_col0, #T_815ac_row34_col1, #T_815ac_row35_col0, #T_815ac_row35_col1, #T_815ac_row36_col0, #T_815ac_row36_col1, #T_815ac_row37_col0, #T_815ac_row37_col1, #T_815ac_row38_col0, #T_815ac_row38_col1, #T_815ac_row39_col0, #T_815ac_row39_col1, #T_815ac_row40_col0, #T_815ac_row40_col1, #T_815ac_row41_col0, #T_815ac_row41_col1, #T_815ac_row42_col0, #T_815ac_row42_col1, #T_815ac_row43_col0, #T_815ac_row43_col1, #T_815ac_row44_col0, #T_815ac_row44_col1, #T_815ac_row45_col0, #T_815ac_row45_col1, #T_815ac_row46_col0, #T_815ac_row46_col1, #T_815ac_row47_col0, #T_815ac_row47_col1, #T_815ac_row48_col0, #T_815ac_row48_col1, #T_815ac_row49_col0, #T_815ac_row49_col1, #T_815ac_row50_col0, #T_815ac_row50_col1, #T_815ac_row51_col0, #T_815ac_row51_col1, #T_815ac_row52_col0, #T_815ac_row52_col1, #T_815ac_row53_col0, #T_815ac_row53_col1, #T_815ac_row54_col0, #T_815ac_row54_col1, #T_815ac_row55_col0, #T_815ac_row55_col1, #T_815ac_row56_col0, #T_815ac_row56_col1, #T_815ac_row57_col0, #T_815ac_row57_col1, #T_815ac_row58_col0, #T_815ac_row58_col1, #T_815ac_row59_col0, #T_815ac_row59_col1, #T_815ac_row60_col0, #T_815ac_row60_col1, #T_815ac_row61_col0, #T_815ac_row61_col1, #T_815ac_row62_col0, #T_815ac_row62_col1, #T_815ac_row63_col0, #T_815ac_row63_col1, #T_815ac_row64_col0, #T_815ac_row64_col1, #T_815ac_row65_col0, #T_815ac_row65_col1, #T_815ac_row66_col0, #T_815ac_row66_col1, #T_815ac_row67_col0, #T_815ac_row67_col1, #T_815ac_row68_col0, #T_815ac_row68_col1, #T_815ac_row69_col0, #T_815ac_row69_col1, #T_815ac_row70_col0, #T_815ac_row70_col1, #T_815ac_row71_col0, #T_815ac_row71_col1, #T_815ac_row72_col0, #T_815ac_row72_col1, #T_815ac_row73_col0, #T_815ac_row73_col1, #T_815ac_row74_col0, #T_815ac_row74_col1, #T_815ac_row75_col0, #T_815ac_row75_col1, #T_815ac_row76_col0, #T_815ac_row76_col1, #T_815ac_row77_col0, #T_815ac_row77_col1, #T_815ac_row78_col0, #T_815ac_row78_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_815ac_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >train</th>
#       <th class="col_heading level0 col1" >test</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_815ac_level0_row0" class="row_heading level0 row0" >PoolQC</th>
#       <td id="T_815ac_row0_col0" class="data row0 col0" >1453</td>
#       <td id="T_815ac_row0_col1" class="data row0 col1" >1456</td>
#     </tr>
#     <tr>
#       <th id="T_815ac_level0_row1" class="row_heading level0 row1" >MiscFeature</th>
#       <td id="T_815ac_row1_col0" class="data row1 col0" >1406</td>
#       <td id="T_815ac_row1_col1" class="data row1 col1" >1408</td>
#     </tr>
#     <tr>
#       <th id="T_815ac_level0_row2" class="row_heading level0 row2" >Alley</th>
#       <td id="T_815ac_row2_col0" class="data row2 col0" >1369</td>
#       <td id="T_815ac_row2_col1" class="data row2 col1" >1352</td>
#     </tr>
#     <tr>
#       <th id="T_815ac_level0_row3" class="row_heading level0 row3" >Fence</th>
#       <td id="T_815ac_row3_col0" class="data row3 col0" >1179</td>
#       <td id="T_815ac_row3_col1" class="data row3 col1" >1169</td>
#     </tr>
#     <tr>
#       <th id="T_815ac_level0_row4" class="row_heading level0 row4" >FireplaceQu</th>
#       <td id="T_815ac_row4_col0" class="data row4 col0" >690</td>
#       <td id="T_815ac_row4_col1" class="data row4 col1" >730</td>
#     </tr>
#     <tr>
#       <th id="T_815ac_level0_row5" class="row_heading level0 row5" >LotFrontage</th>
#       <td id="T_815ac_row5_col0" class="data row5 col0" >259</td>
#       <td id="T_815ac_row5_col1" class="data row5 col1" >227</td>
#     </tr>
#     <tr>
#       <th id="T_815ac_level0_row6" class="row_heading level0 row6" >GarageYrBlt</th>
#       <td id="T_815ac_row6_col0" class="data row6 col0" >81</td>
#       <td id="T_815ac_row6_col1" class="data row6 col1" >78</td>
#     </tr>
#     <tr>
#       <th id="T_815ac_level0_row7" class="row_heading level0 row7" >GarageFinish</th>
#       <td id="T_815ac_row7_col0" class="data row7 col0" >81</td>
#       <td id="T_815ac_row7_col1" class="data row7 col1" >78</td>
#     </tr>
#     <tr>
#       <th id="T_815ac_level0_row8" class="row_heading level0 row8" >GarageQual</th>
#       <td id="T_815ac_row8_col0" class="data row8 col0" >81</td>
#       <td id="T_815ac_row8_col1" class="data row8 col1" >78</td>
#     </tr>
#     <tr>
#       <th id="T_815ac_level0_row9" class="row_heading level0 row9" >GarageCond</th>
#       <td id="T_815ac_row9_col0" class="data row9 col0" >81</td>
#       <td id="T_815ac_row9_col1" class="data row9 col1" >78</td>
#     </tr>
#     <tr>
#       <th id="T_815ac_level0_row10" class="row_heading level0 row10" >GarageType</th>
#       <td id="T_815ac_row10_col0" class="data row10 col0" >81</td>
#       <td id="T_815ac_row10_col1" class="data row10 col1" >76</td>
#     </tr>
#     <tr>
#       <th id="T_815ac_level0_row11" class="row_heading level0 row11" >BsmtExposure</th>
#       <td id="T_815ac_row11_col0" class="data row11 col0" >38</td>
#       <td id="T_815ac_row11_col1" class="data row11 col1" >44</td>
#     </tr>
#     <tr>
#       <th id="T_815ac_level0_row12" class="row_heading level0 row12" >BsmtFinType2</th>
#       <td id="T_815ac_row12_col0" class="data row12 col0" >38</td>
#       <td id="T_815ac_row12_col1" class="data row12 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_815ac_level0_row13" class="row_heading level0 row13" >BsmtCond</th>
#       <td id="T_815ac_row13_col0" class="data row13 col0" >37</td>
#       <td id="T_815ac_row13_col1" class="data row13 col1" >45</td>
#     </tr>
#     <tr>
#       <th id="T_815ac_level0_row14" class="row_heading level0 row14" >BsmtQual</th>
#       <td id="T_815ac_row14_col0" class="data row14 col0" >37</td>
#       <td id="T_815ac_row14_col1" class="data row14 col1" >44</td>
#     </tr>
#     <tr>
#       <th id="T_815ac_level0_row15" class="row_hea

# %%
with pd.option_context('display.max_columns', None):
    display(df_train.sample(10))
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1039         160       RM         21.0     1533   Pave   NaN      Reg
# 889           20       RL         95.0    15865   Pave   NaN      IR1
# 1227          60       RL         86.0    14598   Pave   NaN      IR1
# 745          120       RL         41.0     5395   Pave   NaN      IR1
# 600          160       RM         24.0     1950   Pave   NaN      Reg
# 1386          50       RM         40.0     5436   Pave   NaN      Reg
# 1060          50       RL          NaN    11275   Pave   NaN      IR1
# 1282          20       RL         50.0     8049   Pave   NaN      IR1
# 1127         120       RL         53.0     3684   Pave   NaN      Reg
# 57           160       FV         24.0     2645   Pave  Pave      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1039         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# 889          Lvl    AllPub    Inside       Mod        NAmes       Norm
# 1227         Lvl    AllPub   CulDSac       Gtl      Somerst      Feedr
# 745          HLS    AllPub    Inside       Gtl      StoneBr       Norm
# 600          Lvl    AllPub    Inside       Gtl      Blueste       Norm
# 1386         Lvl    AllPub    Inside       Gtl       IDOTRR       Norm
# 1060         HLS    AllPub    Corner       Mod      Crawfor       Norm
# 1282         Lvl    AllPub   CulDSac       Gtl       Timber       Norm
# 1127         Lvl    AllPub    Inside       Gtl      Blmngtn       Norm
# 57           Lvl    AllPub    Inside       Gtl      Somerst       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 1039       Norm    Twnhs     2Story            4            6       1970
# 889        Norm     1Fam     1Story            8            6       1970
# 1227       Norm     1Fam     2Story            6            5       2007
# 745        Norm   TwnhsE     1Story            8            5       1993
# 600        Norm    Twnhs     2Story            6            6       1980
# 1386       Norm     1Fam     1.5Fin            4            8       1922
# 1060       Norm     1Fam     1.5Fin            6            7       1932
# 1282       Norm     1Fam     1Story            7            5       1990
# 1127       Norm   TwnhsE     1Story            7            5       2007
# 57         Norm    Twnhs     2Story            8            5       1999
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 1039          2008     Gable  CompShg     CemntBd     CmentBd       None
# 889           1970      Flat  Tar&Grv     Wd Sdng     Wd Sdng       None
# 1227          2007     Gable  CompShg     VinylSd     VinylSd      Stone
# 745           1993     Gable  CompShg     HdBoard     HdBoard       None
# 600           1980     Gable  CompShg     MetalSd     MetalSd       None
# 1386          2007     Gable  CompShg     VinylSd     VinylSd       None
# 1060          1950     Gable  CompShg     MetalSd     MetalSd    BrkFace
# 1282          1990       Hip  CompShg     HdBoard     HdBoard    BrkFace
# 1127          2007       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 57            2000     Gable  CompShg     MetalSd     MetalSd    BrkFace
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# Id
# 1039         0.0        TA        TA     CBlock       TA       TA
# 889          0.0        Gd        Gd      PConc       TA       Gd
# 1227        74.0        Gd        TA      PConc       Gd       TA
# 745          0.0        Gd        TA      PConc       Gd       TA
# 600          0.0        TA        Gd     CBlock       Gd       TA
# 1386         0.0        TA        Gd     BrkTil       TA       TA
# 1060       480.0        TA        TA     CBlock       TA       TA
# 1282        54.0        TA        TA     CBlock       Gd       TA
# 1127       130.0        Gd        TA      PConc       Gd       TA
# 57         456.0        Gd        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# Id
# 1039           No          Unf           0          Unf           0
# 889            Gd          ALQ         351          Rec         823
# 1227           Mn          Unf           0          Unf           0
# 745            No          GLQ         733          Unf           0
# 600            No          LwQ          81          GLQ         612
# 1386           No          BLQ         735          Unf           0
# 1060           Mn          Rec         297          LwQ         557
# 1282           No          ALQ        1053          Unf           0
# 1127           No          Unf           0          Unf           0
# 57             No          GLQ         649          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# Id
# 1039        546          546    GasA        TA          Y      SBrkr
# 889        1043         2217    GasA        Ex          Y      SBrkr
# 1227        894          894    GasA        Ex          Y      SBrkr
# 745         604         1337    GasA        Gd          Y      SBrkr
# 600          23          716    GasA        TA          Y      SBrkr
# 1386         61          796    GasA        Gd          Y      SBrkr
# 1060          0          854    GasA        TA          Y      SBrkr
# 1282        256         1309    GasA        TA          Y      SBrkr
# 1127       1373         1373    GasA        Ex          Y      SBrkr
# 57          321          970    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# Id
# 1039       798       546             0       1344             0             0
# 889       2217         0             0       2217             1             0
# 1227       894      1039             0       1933             0             0
# 745       1337         0             0       1337             1             0
# 600        716       840             0       1556             1             0
# 1386       796       358             0       1154             1             0
# 1060      1096       895             0       1991             0             0
# 1282      1339         0             0       1339             1             0
# 1127      1555         0             0       1555             0             0
# 57         983       756             0       1739             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# Id
# 1039         1         1             3             1          TA
# 889          2         0             4             1          Gd
# 1227         2         1             4             1          Gd
# 745          2         0             2             1          Gd
# 600          2         1             3             1          TA
# 1386         1         0             3             1          Gd
# 1060         1         1             3             1          TA
# 1282         2         0             2             1          TA
# 1127         2         0             2             1          Gd
# 57           2         1             3             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# Id
# 1039             6        Typ           1          TA        NaN          NaN
# 889              8        Typ           1          TA     Attchd       1970.0
# 1227             9        Typ           1          Gd    BuiltIn       2007.0
# 745              5        Typ           1          TA     Attchd       1993.0
# 600              6        Typ           1          TA     Attchd       1980.0
# 1386             7        Typ           0         NaN     Detchd       1922.0
# 1060             7        Typ           1          Gd     Detchd       1977.0
# 1282             6        Typ           1          TA     Attchd       1990.0
# 1127             7        Typ           1          TA     Attchd       2007.0
# 57               7        Typ           0         NaN     Attchd       1999.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# Id
# 1039          NaN           0           0        NaN        NaN          Y
# 889           Unf           2         621         TA         TA          Y
# 1227          Fin           3         668         TA         TA          Y
# 745           RFn           2         462         TA         TA          Y
# 600           Fin           2         452         TA         TA          Y
# 1386          Unf           1         240         TA         TA          N
# 1060          Unf           2         432         TA         Fa          Y
# 1282          Fin           2         484         Gd         Gd          Y
# 1127          Fin           3         660         TA         TA          Y
# 57            Fin           2         480         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# Id
# 1039           0            0              0          0            0
# 889           81          207              0          0          224
# 1227         100           18              0          0            0
# 745           96            0             70        168            0
# 600          161            0              0          0            0
# 1386           0           96              0          0            0
# 1060           0            0             19          0            0
# 1282           0           58              0          0           90
# 1127         143           20              0          0            0
# 57           115            0              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# Id
# 1039         0    NaN    NaN         NaN        0       5    2009       WD
# 889          0    NaN    NaN         NaN        0      10    2007       WD
# 1227         0    NaN    NaN         NaN        0       1    2008       WD
# 745          0    NaN    NaN         NaN        0      10    2008       WD
# 600          0    NaN  GdPrv         NaN        0       7    2008      COD
# 1386         0    NaN  MnPrv         NaN        0       5    2010       WD
# 1060         0    NaN    NaN         NaN        0       3    2007       WD
# 1282         0    NaN    NaN         NaN        0       7    2006       WD
# 1127         0    NaN    NaN         NaN        0       6    2009       WD
# 57           0    NaN    NaN         NaN        0       8    2009       WD
#
#      SaleCondition  SalePrice
# Id
# 1039        Normal      97000
# 889         Normal     268000
# 1227        Normal     214000
# 745         Normal     180000
# 600         Normal     151000
# 1386        Normal     125500
# 1060        Normal     220000
# 1282        Normal     180000
# 1127        Normal     174000
# 57         Abnorml     172500

# %%
columns_num = X.select_dtypes(exclude='object').columns
columns_obj = X.select_dtypes('object').columns

# %%
len(columns_num), len(columns_obj)
# Out:
# (36, 43)

# %%
fig, ax = plt.subplots(figsize=(12, 12))
sns.heatmap(X.isna().T, yticklabels=True, ax=ax, cbar=False)
# Out:
# <AxesSubplot:xlabel='Id'>

# %%
fig, ax = plt.subplots(figsize=(12, 12))
sns.heatmap(X_test.isna().T, yticklabels=True, ax=ax, cbar=False)
# Out:
# <AxesSubplot:xlabel='Id'>

# %%
fig, axs = plt.subplots(ncols=4, nrows=9, figsize=(20, 40))

for col, ax in zip(columns_num, axs.flat):
    sns.histplot(data=df_combined,
                 x=col,
                 hue='set',
                 stat='probability',
                 #multiple='dodge',
                 common_norm=False,
                 ax=ax)

# %%
fig, axs = plt.subplots(ncols=4, nrows=11, figsize=(20, 40))

for col, ax in zip(columns_obj, axs.flat):
    sns.histplot(data=df_combined,
                 y=df_combined[col].fillna('NULL'),
                 hue='set',
                 ax=ax)

# %% [markdown]
# # Feature Preprocessing

# %% [markdown]
# ## String --> Rate or Condition
# Many features are categories which can be replaced with integers:
# - Ex	Excellent -> 5
# - Gd	Good -> 4
# - TA	Typical/Average -> 3
# - Fa	Fair -> 2
# - Po	Poor -> 1
# - NA	No Garage -> 0

# %%
dict_string2value = {
    'Street': {'Pave': 2, 'Grvl': 1},
    'Alley': {'Pave': 2, 'Grvl': 1, 'NULL':0}, # np.NaN: 0
    'LotShape': {'Reg':3, 'IR1':2, 'IR2':1, 'IR3':0},
    'LandContour': {'Lvl':3, 'Bnk':2, 'HLS':1, 'Low':0},
    'Utilities': {"AllPub": 4, "NoSewr": 3, "NoSeWa":2, "ELO": 1, 'NULL':0}, # np.NaN: 0
    'LandSlope': {"Gtl": 3, "Mod": 2, "Sev": 1},
    "ExterQual": {"Ex":5, "Gd":4, "TA":3, "Fa":2, "Po":1},
    "ExterCond": {"Ex":5, "Gd":4, "TA":3, "Fa":2, "Po":1}, 
    "BsmtQual": {"Ex":5, "Gd":4, "TA":3, "Fa":2, "Po":1, 'NULL':0}, # np.NaN: 0
    "BsmtCond": {"Ex":5, "Gd":4, "TA":3, "Fa":2, "Po":1, 'NULL':0}, # np.NaN: 0
    "BsmtExposure": {"Gd":4, "Av":3, "Mn":2, "No":1, 'NULL':0}, # np.NaN: 0
    "BsmtFinType1": {"GLQ":6, "ALQ":5, "BLQ":4, "Rec":3, "LwQ":2, "Unf":1, 'NULL':0}, # np.NaN: 0
    "BsmtFinType2": {"GLQ":6, "ALQ":5, "BLQ":4, "Rec":3, "LwQ":2, "Unf":1, 'NULL':0}, # np.NaN: 0
    "HeatingQC": {"Ex":5, "Gd":4, "TA":3, "Fa":2, "Po":1},
    "CentralAir": {"Y":1, "N":0},
    "Electrical": {"SBrkr":5, "FuseA":4, "FuseF":3, "FuseP":2, "Mix":1, 'NULL':0}, # np.NaN: 0
    "KitchenQual": {"Ex":5, "Gd":4, "TA":3, "Fa":2, "Po":1, 'NULL':0}, # np.NaN: 0
    "Functional": {"Typ":8, "Min1":7, "Min2":6, "Mod":5, "Maj1":4, "Maj2":3, "Sev":2, "Sal":1, 'NULL':0}, # np.NaN: 0
    "FireplaceQu": {"Ex":5, "Gd":4, "TA":3, "Fa":2, "Po":1, 'NULL':0}, # np.NaN: 0
    "GarageFinish": {"Fin":3, "RFn":2, "Unf":1, 'NULL':0}, # np.NaN: 0
    "GarageQual": {"Ex":5, "Gd":4, "TA":3, "Fa":2, "Po":1, 'NULL':0}, # np.NaN: 0
    "GarageCond": {"Ex":5, "Gd":4, "TA":3, "Fa":2, "Po":1, 'NULL':0}, # np.NaN: 0
    "PavedDrive": {"Y":2, "P":1, "N":0},
    "PoolQC":  {"Ex":4, "Gd":3, "TA":2, "Fa":1, 'NULL':0}, # np.NaN: 0
}

dict_na_1 = {
    "Alley":0,
    "Utilities":0,
    "BsmtQual":0,
    "BsmtCond":0,
    "BsmtExposure":0,
    "BsmtFinType1":0,
    "BsmtFinType2":0,
    "Electrical":0,
    "KitchenQual":0,
    "Functional":0,
    "FireplaceQu":0,
    "GarageFinish":0,
    "GarageQual":0,
    "GarageCond":0,
    "PoolQC":0,
}

# dict_1 = set(list(dict_string2value.keys())+list(dict_na_1.keys()))

def discrete_integer(X):
    #return X.replace(dict_string2value).fillna(dict_na_1)
    columns = list(dict_na_1.keys())
    X = X.copy()
    X[columns] = X[columns].fillna('NULL')
    return X.replace(dict_string2value)

def to_ordered_categories(X):
    X = X.copy()
    for k, v in dict_string2value.items():
        categories = list(v.values())
        X[k] = pd.Categorical(X[k], categories=categories, ordered=True)
    return X

ordered_categories = list(dict_string2value.keys())

df_combined_1 = discrete_integer(df_combined)
X_1 = discrete_integer(X)
X_test_1 = discrete_integer(X_test)

# %% [markdown]
# Box-plot to confirm that the value are in correct order (highest value is higher price)

# %%
sns.catplot(data=X_1[dict_string2value].assign(y=y).melt(id_vars=['y']),
            x='value',
            col="variable",
            y='y',
            kind='box',
            sharex=False,
            col_wrap=5,
            height=5)
# Out:
# D:\application\anaconda3\envs\d2l\lib\site-packages\seaborn\categorical.py:3806: UserWarning: Setting `sharex=False` with `color=None` may cause different levels of the `x` variable to share colors. This will change in a future version.
#   warnings.warn(msg.format("sharex", "x"), UserWarning)

# %%
X_1[dict_string2value]\
    .corrwith(y)\
    .sort_values(ascending=False)\
    .to_frame()\
    .style\
    .bar(vmin=-1, align='zero', vmax=1)
# Out:
# <style type="text/css">
# #T_5b835_row0_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 84.1%, transparent 84.1%);
# }
# #T_5b835_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 83.0%, transparent 83.0%);
# }
# #T_5b835_row2_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 79.3%, transparent 79.3%);
# }
# #T_5b835_row3_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 77.5%, transparent 77.5%);
# }
# #T_5b835_row4_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 76.0%, transparent 76.0%);
# }
# #T_5b835_row5_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 71.4%, transparent 71.4%);
# }
# #T_5b835_row6_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 68.7%, transparent 68.7%);
# }
# #T_5b835_row7_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 65.2%, transparent 65.2%);
# }
# #T_5b835_row8_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 63.7%, transparent 63.7%);
# }
# #T_5b835_row9_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 63.2%, transparent 63.2%);
# }
# #T_5b835_row10_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 62.6%, transparent 62.6%);
# }
# #T_5b835_row11_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 61.6%, transparent 61.6%);
# }
# #T_5b835_row12_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 61.2%, transparent 61.2%);
# }
# #T_5b835_row13_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 60.6%, transparent 60.6%);
# }
# #T_5b835_row14_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 55.8%, transparent 55.8%);
# }
# #T_5b835_row15_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 55.4%, transparent 55.4%);
# }
# #T_5b835_row16_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 52.1%, transparent 52.1%);
# }
# #T_5b835_row17_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 50.9%, transparent 50.9%);
# }
# #T_5b835_row18_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 50.7%, transparent 50.7%);
# }
# #T_5b835_row19_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 49.7%, #d65f5f 49.7%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_5b835_row20_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 47.4%, #d65f5f 47.4%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_5b835_row21_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 46.3%, #d65f5f 46.3%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_5b835_row22_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 45.4%, #d65f5f 45.4%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_5b835_row23_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 36.6%, #d65f5f 36.6%, #d65f5f 50.0%, transparent 50.0%);
# }
# </style>
# <table id="T_5b835_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b835_level0_row0" class="row_heading level0 row0" >ExterQual</th>
#       <td id="T_5b835_row0_col0" class="data row0 col0" >0.682639</td>
#     </tr>
#     <tr>
#       <th id="T_5b835_level0_row1" class="row_heading level0 row1" >KitchenQual</th>
#       <td id="T_5b835_row1_col0" class="data row1 col0" >0.659600</td>
#     </tr>
#     <tr>
#       <th id="T_5b835_level0_row2" class="row_heading level0 row2" >BsmtQual</th>
#       <td id="T_5b835_row2_col0" class="data row2 col0" >0.585207</td>
#     </tr>
#     <tr>
#       <th id="T_5b835_level0_row3" class="row_heading level0 row3" >GarageFinish</th>
#       <td id="T_5b835_row3_col0" class="data row3 col0" >0.549247</td>
#     </tr>
#     <tr>
#       <th id="T_5b835_level0_row4" class="row_heading level0 row4" >FireplaceQu</th>
#       <td id="T_5b835_row4_col0" class="data row4 col0" >0.520438</td>
#     </tr>
#     <tr>
#       <th id="T_5b835_level0_row5" class="row_heading level0 row5" >HeatingQC</th>
#       <td id="T_5b835_row5_col0" class="data row5 col0" >0.427649</td>
#     </tr>
#     <tr>
#       <th id="T_5b835_level0_row6" class="row_heading level0 row6" >BsmtExposure</th>
#       <td id="T_5b835_row6_col0" class="data row6 col0" >0.374696</td>
#     </tr>
#     <tr>
#       <th id="T_5b835_level0_row7" class="row_heading level0 row7" >BsmtFinType1</th>
#       <td id="T_5b835_row7_col0" class="data row7 col0" >0.304908</td>
#     </tr>
#     <tr>
#       <th id="T_5b835_level0_row8" class="row_heading level0 row8" >GarageQual</th>
#       <td id="T_5b835_row8_col0" class="data row8 col0" >0.273839</td>
#     </tr>
#     <tr>
#       <th id="T_5b835_level0_row9" class="row_heading level0 row9" >GarageCond</th>
#       <td id="T_5b835_row9_col0" class="data row9 col0" >0.263191</td>
#     </tr>
#     <tr>
#       <th id="T_5b835_level0_row10" class="row_heading level0 row10" >CentralAir</th>
#       <td id="T_5b835_row10_col0" class="data row10 col0" >0.251328</td>
#     </tr>
#     <tr>
#       <th id="T_5b835_level0_row11" class="row_heading level0 row11" >PavedDrive</th>
#       <td id="T_5b835_row11_col0" class="data row11 col0" >0.231357</td>
#     </tr>
#     <tr>
#       <th id="T_5b835_level0_row12" class="row_heading level0 row12" >Electrical</th>
#       <td id="T_5b835_row12_col0" class="data row12 col0" >0.223563</td>
#     </tr>
#     <tr>
#       <th id="T_5b835_level0_row13" class="row_heading level0 row13" >BsmtCond</th>
#       <td id="T_5b835_row13_col0" class="data row13 col0" >0.212607</td>
#     </tr>
#     <tr>
#       <th id="T_5b835_level0_row14" class="row_heading level0 row14" >PoolQC</th>
#       <td id="T_5b835_row14_col0" class="data row14 col0" >0.115484</td>
#     </tr>
#     <tr>
#       <th id="T_5b835_level0_row15" class="row_heading level0 row15" >Functional</th>
#       <td id="T_5b835_row15_col0" class="data row15 col0" >0.107619</td>
#     </tr>
#     <tr>
#       <th id="T_5b835_level0_row16" class="row_heading level0 row16" >Street</th>
#       <td id="T_5b835_row16_col0" class="data row16 col0" >0.041036</td>
#     </tr>
#     <tr>
#       <th id="T_5b835_level0_row17" class="row_heading level0 row17" >ExterCond</th>
#       <td id="T_5b835_row17_col0" class="data row17 col0" >0.018899</td>
#     </tr>
#     <tr>
#       <th id="T_5b835_level0_row18" class="row_heading level0 row18" >Utilities</th>
#       <td id="T_5b835_row18_col0" class="data row18 col0" >0.014314</td>
#     </tr>
#     <tr>
#       <th id="T_5b835_level0_row19" class="row_heading level0 row19" >BsmtFinType2</th>
#       <td id="T_5b835_row19_col0" class="data row19 col0" >-0.005323</td>
#     </tr>
#     <tr>
#       <th id="T_5b835_level0_row20" class="row_heading level0 row20" >LandSlope</th>
#       <td id="T_5b835_row20_col0" class="data row20 col0" >-0.051152</td>
#     </tr>
#     <tr>
#       <th id="T_5b835_level0_row21" class="row_heading level0 row21" >LandContour</th>
#       <td id="T_5b835_row21_col0" class="data row21 col0" >-0.073042</td>
#     </tr>
#     <tr>
#       <th id="T_5b835_level0_row22" class="row_heading level0 row22" >Alley</th>
#       <t

# %% [markdown]
# Not all features correlate linearly with the target

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### NA in discrete columns

# %%
columns_na = df_combined.columns[(df_combined_1.isna().sum() > 0)].sort_values().tolist()
print(columns_na)
# Out:
# ['BsmtFinSF1', 'BsmtFinSF2', 'BsmtFullBath', 'BsmtHalfBath', 'BsmtUnfSF', 'Exterior1st', 'Exterior2nd', 'Fence', 'GarageArea', 'GarageCars', 'GarageType', 'GarageYrBlt', 'LotFrontage', 'MSZoning', 'MasVnrArea', 'MasVnrType', 'MiscFeature', 'SaleType', 'TotalBsmtSF']

# %% [markdown]
# It seems that some missing values could be replaced with 0 or "other" or "none"
#
# We distinguish them between:
# - numbers (example: *SF, *Area), we could replace NaN --> 0
# - categories (example: Misc) we could replace NaN --> None
# - categories (example: SaleType) we could replace NaN --> Other

# %%
df_combined_1[columns_na]\
    .apply('nunique')\
    .sort_values()\
    .to_frame(name='number of unique values')\
    .style\
    .bar()
# Out:
# <style type="text/css">
# #T_c291c_row0_col0 {
#   width: 10em;
#   height: 80%;
# }
# #T_c291c_row1_col0, #T_c291c_row2_col0, #T_c291c_row3_col0, #T_c291c_row4_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 0.1%, transparent 0.1%);
# }
# #T_c291c_row5_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 0.2%, transparent 0.2%);
# }
# #T_c291c_row6_col0, #T_c291c_row7_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 0.3%, transparent 0.3%);
# }
# #T_c291c_row8_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 0.5%, transparent 0.5%);
# }
# #T_c291c_row9_col0, #T_c291c_row10_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 1.1%, transparent 1.1%);
# }
# #T_c291c_row11_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 8.8%, transparent 8.8%);
# }
# #T_c291c_row12_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 11.0%, transparent 11.0%);
# }
# #T_c291c_row13_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 23.8%, transparent 23.8%);
# }
# #T_c291c_row14_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 39.0%, transparent 39.0%);
# }
# #T_c291c_row15_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 53.0%, transparent 53.0%);
# }
# #T_c291c_row16_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 87.3%, transparent 87.3%);
# }
# #T_c291c_row17_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 93.2%, transparent 93.2%);
# }
# #T_c291c_row18_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_c291c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >number of unique values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c291c_level0_row0" class="row_heading level0 row0" >BsmtHalfBath</th>
#       <td id="T_c291c_row0_col0" class="data row0 col0" >3</td>
#     </tr>
#     <tr>
#       <th id="T_c291c_level0_row1" class="row_heading level0 row1" >BsmtFullBath</th>
#       <td id="T_c291c_row1_col0" class="data row1 col0" >4</td>
#     </tr>
#     <tr>
#       <th id="T_c291c_level0_row2" class="row_heading level0 row2" >MiscFeature</th>
#       <td id="T_c291c_row2_col0" class="data row2 col0" >4</td>
#     </tr>
#     <tr>
#       <th id="T_c291c_level0_row3" class="row_heading level0 row3" >Fence</th>
#       <td id="T_c291c_row3_col0" class="data row3 col0" >4</td>
#     </tr>
#     <tr>
#       <th id="T_c291c_level0_row4" class="row_heading level0 row4" >MasVnrType</th>
#       <td id="T_c291c_row4_col0" class="data row4 col0" >4</td>
#     </tr>
#     <tr>
#       <th id="T_c291c_level0_row5" class="row_heading level0 row5" >MSZoning</th>
#       <td id="T_c291c_row5_col0" class="data row5 col0" >5</td>
#     </tr>
#     <tr>
#       <th id="T_c291c_level0_row6" class="row_heading level0 row6" >GarageCars</th>
#       <td id="T_c291c_row6_col0" class="data row6 col0" >6</td>
#     </tr>
#     <tr>
#       <th id="T_c291c_level0_row7" class="row_heading level0 row7" >GarageType</th>
#       <td id="T_c291c_row7_col0" class="data row7 col0" >6</td>
#     </tr>
#     <tr>
#       <th id="T_c291c_level0_row8" class="row_heading level0 row8" >SaleType</th>
#       <td id="T_c291c_row8_col0" class="data row8 col0" >9</td>
#     </tr>
#     <tr>
#       <th id="T_c291c_level0_row9" class="row_heading level0 row9" >Exterior1st</th>
#       <td id="T_c291c_row9_col0" class="data row9 col0" >15</td>
#     </tr>
#     <tr>
#       <th id="T_c291c_level0_row10" class="row_heading level0 row10" >Exterior2nd</th>
#       <td id="T_c291c_row10_col0" class="data row10 col0" >16</td>
#     </tr>
#     <tr>
#       <th id="T_c291c_level0_row11" class="row_heading level0 row11" >GarageYrBlt</th>
#       <td id="T_c291c_row11_col0" class="data row11 col0" >103</td>
#     </tr>
#     <tr>
#       <th id="T_c291c_level0_row12" class="row_heading level0 row12" >LotFrontage</th>
#       <td id="T_c291c_row12_col0" class="data row12 col0" >128</td>
#     </tr>
#     <tr>
#       <th id="T_c291c_level0_row13" class="row_heading level0 row13" >BsmtFinSF2</th>
#       <td id="T_c291c_row13_col0" class="data row13 col0" >272</td>
#     </tr>
#     <tr>
#       <th id="T_c291c_level0_row14" class="row_heading level0 row14" >MasVnrArea</th>
#       <td id="T_c291c_row14_col0" class="data row14 col0" >444</td>
#     </tr>
#     <tr>
#       <th id="T_c291c_level0_row15" class="row_heading level0 row15" >GarageArea</th>
#       <td id="T_c291c_row15_col0" class="data row15 col0" >603</td>
#     </tr>
#     <tr>
#       <th id="T_c291c_level0_row16" class="row_heading level0 row16" >BsmtFinSF1</th>
#       <td id="T_c291c_row16_col0" class="data row16 col0" >991</td>
#     </tr>
#     <tr>
#       <th id="T_c291c_level0_row17" class="row_heading level0 row17" >TotalBsmtSF</th>
#       <td id="T_c291c_row17_col0" class="data row17 col0" >1058</td>
#     </tr>
#     <tr>
#       <th id="T_c291c_level0_row18" class="row_heading level0 row18" >BsmtUnfSF</th>
#       <td id="T_c291c_row18_col0" class="data row18 col0" >1135</td>
#     </tr>
#   </tbody>
# </table>

# %%
columns_na_cat = df_combined_1[columns_na].apply('nunique').loc[lambda x: x<20].index

unique_values = pd.DataFrame(
    [[c, X_1[c].unique(),[x for x in X_test_1[c].unique() if not(x in X_1[c].unique())]]
      for c in columns_na_cat],
    columns=['column name', 'train unique values', 'other values in test']
).set_index('column name')

unique_values.join([X_1[columns_na_cat].isna().sum().rename('NA train'),
                    X_test_1[columns_na_cat].isna().sum().rename('NA test')]).style
# Out:
# <style type="text/css">
# </style>
# <table id="T_1c629_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >train unique values</th>
#       <th class="col_heading level0 col1" >other values in test</th>
#       <th class="col_heading level0 col2" >NA train</th>
#       <th class="col_heading level0 col3" >NA test</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >column name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1c629_level0_row0" class="row_heading level0 row0" >BsmtFullBath</th>
#       <td id="T_1c629_row0_col0" class="data row0 col0" >[1 0 2 3]</td>
#       <td id="T_1c629_row0_col1" class="data row0 col1" >[nan]</td>
#       <td id="T_1c629_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_1c629_row0_col3" class="data row0 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_1c629_level0_row1" class="row_heading level0 row1" >BsmtHalfBath</th>
#       <td id="T_1c629_row1_col0" class="data row1 col0" >[0 1 2]</td>
#       <td id="T_1c629_row1_col1" class="data row1 col1" >[nan]</td>
#       <td id="T_1c629_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_1c629_row1_col3" class="data row1 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_1c629_level0_row2" class="row_heading level0 row2" >Exterior1st</th>
#       <td id="T_1c629_row2_col0" class="data row2 col0" >['VinylSd' 'MetalSd' 'Wd Sdng' 'HdBoard' 'BrkFace' 'WdShing' 'CemntBd'
#  'Plywood' 'AsbShng' 'Stucco' 'BrkComm' 'AsphShn' 'Stone' 'ImStucc'
#  'CBlock']</td>
#       <td id="T_1c629_row2_col1" class="data row2 col1" >[nan]</td>
#       <td id="T_1c629_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_1c629_row2_col3" class="data row2 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_1c629_level0_row3" class="row_heading level0 row3" >Exterior2nd</th>
#       <td id="T_1c629_row3_col0" class="data row3 col0" >['VinylSd' 'MetalSd' 'Wd Shng' 'HdBoard' 'Plywood' 'Wd Sdng' 'CmentBd'
#  'BrkFace' 'Stucco' 'AsbShng' 'Brk Cmn' 'ImStucc' 'AsphShn' 'Stone'
#  'Other' 'CBlock']</td>
#       <td id="T_1c629_row3_col1" class="data row3 col1" >[nan]</td>
#       <td id="T_1c629_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_1c629_row3_col3" class="data row3 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_1c629_level0_row4" class="row_heading level0 row4" >Fence</th>
#       <td id="T_1c629_row4_col0" class="data row4 col0" >[nan 'MnPrv' 'GdWo' 'GdPrv' 'MnWw']</td>
#       <td id="T_1c629_row4_col1" class="data row4 col1" >[nan]</td>
#       <td id="T_1c629_row4_col2" class="data row4 col2" >1179</td>
#       <td id="T_1c629_row4_col3" class="data row4 col3" >1169</td>
#     </tr>
#     <tr>
#       <th id="T_1c629_level0_row5" class="row_heading level0 row5" >GarageCars</th>
#       <td id="T_1c629_row5_col0" class="data row5 col0" >[2 3 1 0 4]</td>
#       <td id="T_1c629_row5_col1" class="data row5 col1" >[5.0, nan]</td>
#       <td id="T_1c629_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_1c629_row5_col3" class="data row5 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_1c629_level0_row6" class="row_heading level0 row6" >GarageType</th>
#       <td id="T_1c629_row6_col0" class="data row6 col0" >['Attchd' 'Detchd' 'BuiltIn' 'CarPort' nan 'Basment' '2Types']</td>
#       <td id="T_1c629_row6_col1" class="data row6 col1" >[nan]</td>
#       <td id="T_1c629_row6_col2" class="data row6 col2" >81</td>
#       <td id="T_1c629_row6_col3" class="data row6 col3" >76</td>
#     </tr>
#     <tr>
#       <th id="T_1c629_level0_row7" class="row_heading level0 row7" >MSZoning</th>
#       <td id="T_1c629_row7_col0" class="data row7 col0" >['RL' 'RM' 'C (all)' 'FV' 'RH']</td>
#       <td id="T_1c629_row7_col1" class="data row7 col1" >[nan]</td>
#       <td id="T_1c629_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_1c629_row7_col3" class="data row7 col3" >4</td>
#     </tr>
#     <tr>
#       <th id="T_1c629_level0_row8" class="row_heading level0 row8" >MasVnrType</th>
#       <td id="T_1c629_row8_col0" class="data row8 col0" >['BrkFace' 'None' 'Stone' 'BrkCmn' nan]</td>
#       <td id="T_1c629_row8_col1" class="data row8 col1" >[nan]</td>
#       <td id="T_1c629_row8_col2" class="data row8 col2" >8</td>
#       <td id="T_1c629_row8_col3" class="data row8 col3" >16</td>
#     </tr>
#     <tr>
#       <th id="T_1c629_level0_row9" class="row_heading level0 row9" >MiscFeature</th>
#       <td id="T_1c629_row9_col0" class="data row9 col0" >[nan 'Shed' 'Gar2' 'Othr' 'TenC']</td>
#       <td id="T_1c629_row9_col1" class="data row9 col1" >[nan]</td>
#       <td id="T_1c629_row9_col2" class="data row9 col2" >1406</td>
#       <td id="T_1c629_row9_col3" class="data row9 col3" >1408</td>
#     </tr>
#     <tr>
#       <th id="T_1c629_level0_row10" class="row_heading level0 row10" >SaleType</th>
#       <td id="T_1c629_row10_col0" class="data row10 col0" >['WD' 'New' 'COD' 'ConLD' 'ConLI' 'CWD' 'ConLw' 'Con' 'Oth']</td>
#       <td id="T_1c629_row10_col1" class="data row10 col1" >[nan]</td>
#       <td id="T_1c629_row10_col2" class="data row10 col2" >0</td>
#       <td id="T_1c629_row10_col3" class="data row10 col3" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We can notice wronly imputed category in some columns, such as:
# - "Brk Cmn" which should be "Brk Comm"
# - "CmentBd" which should be "CemntBd"
# - "Wd Shng" which should be "WdShing"

# %% [markdown]
# The above columns with low NA value (and moreover if all in test) will be replaced by 0 or 'other', as it seems just that the data in test was not cleaned compared to train
# Ther other above columns will be replaced by the category available in documentation such as "None" or "NA"
#
# For the columns with an "Other" option which is never used, we will impute the value later.

# %%
columns_na_num = df_combined_1[columns_na].apply('nunique').loc[lambda x: x>=20].index

df_combined_1[columns_na_num].describe(include='all')
# Out:
#         BsmtFinSF1   BsmtFinSF2    BsmtUnfSF   GarageArea  GarageYrBlt  \
# count  2918.000000  2918.000000  2918.000000  2918.000000  2760.000000
# mean    441.423235    49.582248   560.772104   472.874572  1978.113406
# std     455.610826   169.205611   439.543659   215.394815    25.574285
# min       0.000000     0.000000     0.000000     0.000000  1895.000000
# 25%       0.000000     0.000000   220.000000   320.000000  1960.000000
# 50%     368.500000     0.000000   467.000000   480.000000  1979.000000
# 75%     733.000000     0.000000   805.500000   576.000000  2002.000000
# max    5644.000000  1526.000000  2336.000000  1488.000000  2207.000000
#
#        LotFrontage   MasVnrArea  TotalBsmtSF
# count  2433.000000  2896.000000  2918.000000
# mean     69.305795   102.201312  1051.777587
# std      23.344905   179.334253   440.766258
# min      21.000000     0.000000     0.000000
# 25%      59.000000     0.000000   793.000000
# 50%      68.000000     0.000000   989.500000
# 75%      80.000000   164.000000  1302.000000
# max     313.000000  1600.000000  6110.000000

# %%
dict_na_2_num = [
    "BsmtFinSF1",
    "BsmtFinSF2",
    "BsmtUnfSF",
    "GarageArea",
    #"GarageYrBlt",
    #"LotFrontage",
    "MasVnrArea",
    "TotalBsmtSF",
]
dict_na_2_num = {k:0 for k in dict_na_2_num}

dict_na_2_other = {
    "BsmtFullBath": 0,
    "BsmtHalfBath": 0,
    # "Exterior1st": "Other"
    "Exterior2nd": "Other",
    "GarageCars": 0,
    "GarageType": "NA",
    "MasVnrType": "None",
    "MiscFeature": "NA", # "Elev" is never used
    "Fence":"NA",
}

def discrete_na(X):
    return X.fillna(dict_na_2_num).fillna(dict_na_2_other)

X_2 = discrete_na(X_1)
X_test_2 = discrete_na(X_test_1)
df_combined_2 = discrete_na(df_combined_1)

# %%
display(X_2\
    .loc[:, lambda x: x.isna().sum() > 0]\
    .describe(include='all'))

display(X_test_2\
    .loc[:, lambda x: x.isna().sum() > 0]\
    .describe(include='all'))
# Out:
#        LotFrontage  GarageYrBlt
# count  1201.000000  1379.000000
# mean     70.049958  1978.506164
# std      24.284752    24.689725
# min      21.000000  1900.000000
# 25%      59.000000  1961.000000
# 50%      69.000000  1980.000000
# 75%      80.000000  2002.000000
# max     313.000000  2010.000000
#        MSZoning  LotFrontage Exterior1st  GarageYrBlt SaleType
# count      1455  1232.000000        1458  1381.000000     1458
# unique        5          NaN          13          NaN        9
# top          RL          NaN     VinylSd          NaN       WD
# freq       1114          NaN         510          NaN     1258
# mean        NaN    68.580357         NaN  1977.721217      NaN
# std         NaN    22.376841         NaN    26.431175      NaN
# min         NaN    21.000000         NaN  1895.000000      NaN
# 25%         NaN    58.000000         NaN  1959.000000      NaN
# 50%         NaN    67.000000         NaN  1979.000000      NaN
# 75%         NaN    80.000000         NaN  2002.000000      NaN
# max         NaN   200.000000         NaN  2207.000000      NaN

# %% [markdown]
# ### NA in numerical columns

# %%
X[['LotFrontage']].describe()
# Out:
#        LotFrontage
# count  1201.000000
# mean     70.049958
# std      24.284752
# min      21.000000
# 25%      59.000000
# 50%      69.000000
# 75%      80.000000
# max     313.000000

# %%
sns.catplot(
    data=df_train.assign(LotFrontage_isna=df_train.LotFrontage.isna())\
                 [['LotConfig', 'LotFrontage_isna', 'SalePrice', 'Neighborhood']]\
                 .melt(id_vars=['LotFrontage_isna', 'SalePrice']),
#     data=X.select_dtypes('object').assign(LotFrontage_isna=df_train.LotFrontage.isna(), SalePrice=y).melt(id_vars=['LotFrontage_isna', 'SalePrice']),
    y='value',
    #hue='LotFrontage_isna',
    x='SalePrice',
    col='variable',
    hue='LotFrontage_isna',
    #col_wrap=5,
    kind='boxen',
    sharey=False,
    sharex=True,
    height=10,
)

# %%
columns_isna_lotfrontage_different_top = ~(df_train.loc[df_train.LotFrontage.isna(), :].describe(include='object') == df_train.loc[~df_train.LotFrontage.isna(), :].describe(include='object')).loc['top', :]
columns_isna_lotfrontage_different_top = columns_isna_lotfrontage_different_top[columns_isna_lotfrontage_different_top].index.tolist()
columns_isna_lotfrontage_different_top
# Out:
# ['LotShape', 'Foundation', 'BsmtQual', 'BsmtFinType1', 'FireplaceQu', 'PoolQC']

# %%
# sns.catplot(
#     data=df_train.assign(LotFrontage_isna=df_train.LotFrontage.isna())[columns_isna_lotfrontage_different_top+['LotFrontage_isna', 'SalePrice']].melt(id_vars=['LotFrontage_isna', 'SalePrice']),
# #     data=X.select_dtypes('object').assign(LotFrontage_isna=df_train.LotFrontage.isna(), SalePrice=y).melt(id_vars=['LotFrontage_isna', 'SalePrice']),
#     x='value',
#     #hue='LotFrontage_isna',
#     y='SalePrice',
#     row='variable',
#     col='LotFrontage_isna',
#     #col_wrap=5,
#     kind='boxen',
#     sharex=False,
# )

# %%
columns_isna_lotfrontage_different_top = df_train.select_dtypes('number').columns[np.isclose(
    df_train.loc[df_train.LotFrontage.isna(), :].describe(include='number').loc['mean', :],
    df_train.loc[~df_train.LotFrontage.isna(), :].describe(include='number').loc['mean', :],
    rtol=1e-3
)].tolist()
columns_isna_lotfrontage_different_top
# Out:
# ['YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
# sns.catplot(
#     data=df_train[columns_isna_lotfrontage_different_top].assign(LotFrontage_isna=df_train['LotFrontage'].isna()).melt(id_vars='LotFrontage_isna'),
#     x='LotFrontage_isna',
#     y='value',
#     col='variable',
#     col_wrap=5,
#     kind='box',
#     sharey=False
# )

# %%
def numerical_na(X):
    return X.fillna({"LotFrontage":0})

# %% [markdown]
# ### Wrong Categories

# %%
# columns_cat = df_combined_2\
#     .drop(columns='set')\
#     .apply('nunique')\
#     .loc[lambda x: x<20]\
#     .index

columns_cat = df_combined_2\
  .drop(columns='set')\
  .select_dtypes('object')\
  .columns

unique_values = pd.DataFrame(
    [[c, X_2[c].unique(),X_2[c].nunique(), [x for x in X_test_2[c].unique() if not(x in X_2[c].unique())]]
      for c in columns_cat],
    columns=['column name', 'train unique values', 'train n unique values', 'other values in test']
)

unique_values.set_index('column name').style
# Out:
# <style type="text/css">
# </style>
# <table id="T_9c0dd_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >train unique values</th>
#       <th class="col_heading level0 col1" >train n unique values</th>
#       <th class="col_heading level0 col2" >other values in test</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >column name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c0dd_level0_row0" class="row_heading level0 row0" >MSZoning</th>
#       <td id="T_9c0dd_row0_col0" class="data row0 col0" >['RL' 'RM' 'C (all)' 'FV' 'RH']</td>
#       <td id="T_9c0dd_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_9c0dd_row0_col2" class="data row0 col2" >[nan]</td>
#     </tr>
#     <tr>
#       <th id="T_9c0dd_level0_row1" class="row_heading level0 row1" >LotConfig</th>
#       <td id="T_9c0dd_row1_col0" class="data row1 col0" >['Inside' 'FR2' 'Corner' 'CulDSac' 'FR3']</td>
#       <td id="T_9c0dd_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_9c0dd_row1_col2" class="data row1 col2" >[]</td>
#     </tr>
#     <tr>
#       <th id="T_9c0dd_level0_row2" class="row_heading level0 row2" >Neighborhood</th>
#       <td id="T_9c0dd_row2_col0" class="data row2 col0" >['CollgCr' 'Veenker' 'Crawfor' 'NoRidge' 'Mitchel' 'Somerst' 'NWAmes'
#  'OldTown' 'BrkSide' 'Sawyer' 'NridgHt' 'NAmes' 'SawyerW' 'IDOTRR'
#  'MeadowV' 'Edwards' 'Timber' 'Gilbert' 'StoneBr' 'ClearCr' 'NPkVill'
#  'Blmngtn' 'BrDale' 'SWISU' 'Blueste']</td>
#       <td id="T_9c0dd_row2_col1" class="data row2 col1" >25</td>
#       <td id="T_9c0dd_row2_col2" class="data row2 col2" >[]</td>
#     </tr>
#     <tr>
#       <th id="T_9c0dd_level0_row3" class="row_heading level0 row3" >Condition1</th>
#       <td id="T_9c0dd_row3_col0" class="data row3 col0" >['Norm' 'Feedr' 'PosN' 'Artery' 'RRAe' 'RRNn' 'RRAn' 'PosA' 'RRNe']</td>
#       <td id="T_9c0dd_row3_col1" class="data row3 col1" >9</td>
#       <td id="T_9c0dd_row3_col2" class="data row3 col2" >[]</td>
#     </tr>
#     <tr>
#       <th id="T_9c0dd_level0_row4" class="row_heading level0 row4" >Condition2</th>
#       <td id="T_9c0dd_row4_col0" class="data row4 col0" >['Norm' 'Artery' 'RRNn' 'Feedr' 'PosN' 'PosA' 'RRAn' 'RRAe']</td>
#       <td id="T_9c0dd_row4_col1" class="data row4 col1" >8</td>
#       <td id="T_9c0dd_row4_col2" class="data row4 col2" >[]</td>
#     </tr>
#     <tr>
#       <th id="T_9c0dd_level0_row5" class="row_heading level0 row5" >BldgType</th>
#       <td id="T_9c0dd_row5_col0" class="data row5 col0" >['1Fam' '2fmCon' 'Duplex' 'TwnhsE' 'Twnhs']</td>
#       <td id="T_9c0dd_row5_col1" class="data row5 col1" >5</td>
#       <td id="T_9c0dd_row5_col2" class="data row5 col2" >[]</td>
#     </tr>
#     <tr>
#       <th id="T_9c0dd_level0_row6" class="row_heading level0 row6" >HouseStyle</th>
#       <td id="T_9c0dd_row6_col0" class="data row6 col0" >['2Story' '1Story' '1.5Fin' '1.5Unf' 'SFoyer' 'SLvl' '2.5Unf' '2.5Fin']</td>
#       <td id="T_9c0dd_row6_col1" class="data row6 col1" >8</td>
#       <td id="T_9c0dd_row6_col2" class="data row6 col2" >[]</td>
#     </tr>
#     <tr>
#       <th id="T_9c0dd_level0_row7" class="row_heading level0 row7" >RoofStyle</th>
#       <td id="T_9c0dd_row7_col0" class="data row7 col0" >['Gable' 'Hip' 'Gambrel' 'Mansard' 'Flat' 'Shed']</td>
#       <td id="T_9c0dd_row7_col1" class="data row7 col1" >6</td>
#       <td id="T_9c0dd_row7_col2" class="data row7 col2" >[]</td>
#     </tr>
#     <tr>
#       <th id="T_9c0dd_level0_row8" class="row_heading level0 row8" >RoofMatl</th>
#       <td id="T_9c0dd_row8_col0" class="data row8 col0" >['CompShg' 'WdShngl' 'Metal' 'WdShake' 'Membran' 'Tar&Grv' 'Roll'
#  'ClyTile']</td>
#       <td id="T_9c0dd_row8_col1" class="data row8 col1" >8</td>
#       <td id="T_9c0dd_row8_col2" class="data row8 col2" >[]</td>
#     </tr>
#     <tr>
#       <th id="T_9c0dd_level0_row9" class="row_heading level0 row9" >Exterior1st</th>
#       <td id="T_9c0dd_row9_col0" class="data row9 col0" >['VinylSd' 'MetalSd' 'Wd Sdng' 'HdBoard' 'BrkFace' 'WdShing' 'CemntBd'
#  'Plywood' 'AsbShng' 'Stucco' 'BrkComm' 'AsphShn' 'Stone' 'ImStucc'
#  'CBlock']</td>
#       <td id="T_9c0dd_row9_col1" class="data row9 col1" >15</td>
#       <td id="T_9c0dd_row9_col2" class="data row9 col2" >[nan]</td>
#     </tr>
#     <tr>
#       <th id="T_9c0dd_level0_row10" class="row_heading level0 row10" >Exterior2nd</th>
#       <td id="T_9c0dd_row10_col0" class="data row10 col0" >['VinylSd' 'MetalSd' 'Wd Shng' 'HdBoard' 'Plywood' 'Wd Sdng' 'CmentBd'
#  'BrkFace' 'Stucco' 'AsbShng' 'Brk Cmn' 'ImStucc' 'AsphShn' 'Stone'
#  'Other' 'CBlock']</td>
#       <td id="T_9c0dd_row10_col1" class="data row10 col1" >16</td>
#       <td id="T_9c0dd_row10_col2" class="data row10 col2" >[]</td>
#     </tr>
#     <tr>
#       <th id="T_9c0dd_level0_row11" class="row_heading level0 row11" >MasVnrType</th>
#       <td id="T_9c0dd_row11_col0" class="data row11 col0" >['BrkFace' 'None' 'Stone' 'BrkCmn']</td>
#       <td id="T_9c0dd_row11_col1" class="data row11 col1" >4</td>
#       <td id="T_9c0dd_row11_col2" class="data row11 col2" >[]</td>
#     </tr>
#     <tr>
#       <th id="T_9c0dd_level0_row12" class="row_heading level0 row12" >Foundation</th>
#       <td id="T_9c0dd_row12_col0" class="data row12 col0" >['PConc' 'CBlock' 'BrkTil' 'Wood' 'Slab' 'Stone']</td>
#       <td id="T_9c0dd_row12_col1" class="data row12 col1" >6</td>
#       <td id="T_9c0dd_row12_col2" class="data row12 col2" >[]</td>
#     </tr>
#     <tr>
#       <th id="T_9c0dd_level0_row13" class="row_heading level0 row13" >Heating</th>
#       <td id="T_9c0dd_row13_col0" class="data row13 col0" >['GasA' 'GasW' 'Grav' 'Wall' 'OthW' 'Floor']</td>
#       <td id="T_9c0dd_row13_col1" class="data row13 col1" >6</td>
#       <td id="T_9c0dd_row13_col2" class="data row13 col2" >[]</td>
#     </tr>
#     <tr>
#       <th id="T_9c0dd_level0_row14" class="row_heading level0 row14" >GarageType</th>
#       <td id="T_9c0dd_row14_col0" class="data row14 col0" >['Attchd' 'Detchd' 'BuiltIn' 'CarPort' 'NA' 'Basment' '2Types']</td>
#       <td id="T_9c0dd_row14_col1" class="data row14 col1" >7</td>
#       <td id="T_9c0dd_row14_col2" class="data row14 col2" >[]</td>
#     </tr>
#     <tr>
#       <th id="T_9c0dd_level0_row15" class="row_heading level0 row15" >Fence</th>
#       <td id="T_9c0dd_row15_col0" class="data row15 col0" >['NA' 'MnPrv' 'GdWo' 'GdPrv' 'MnWw']</td>
#       <td id="T_9c0dd_row15_col1" class="data row15 col1" >5</td>
#       <td id="T_9c0dd_row15_col2" class="data row15 col2" >[]</td>
#     </tr>
#     <tr>
#       <th id="T_9c0dd_level0_row16" class="row_heading level0 row16" >MiscFeature</th>
#       <td id="T_9c0dd_row16_col0" class="data row16 col0" >['NA' 'Shed' 'Gar2' 'Othr' 'TenC']</td>
#       <td id="T_9c0dd_row16_col1" class="data row16 col1" >5</td>
#       <td id="T_9c0dd_row16_col2" class="data row16 col2" >[]</td>
#     </tr>
#     <tr>
#       <th id="T_9c0dd_level0_row17" class="row_heading level0 row17" >SaleType</th>
#       <td id="T_9c0dd_row17_col0" class="data row17 col0" >['WD' 'New' 'COD' 'ConLD' 'ConLI' 'CWD' 'ConLw' 'Con' 'Oth']</td>
#       <td id="T_9c0dd_row17_col1" class="data row17 col1" >9</td>
#       <td id="T_9c0dd_row17_col2" class="data row17 col2" >[nan]</td>
#     </tr>
#     <tr>
#       <th id="T_9c0dd_level0_row18" class="row_heading level0 row18" >SaleCondition</th>
#       <td id="T_9c0dd_row18_col0" class="data row18 col0" >['Normal' 'Abnorml' 'Partial' 'AdjLand' 'Alloca' 'Family']</td>
#       <td id="T_9c0dd_row18_col1" class="data row18 col1" >6</td>
#       <td id="T_9c0dd_row18_col2" class="data row18 col2" >[]</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Specific issue of Exterior2nd

# %%
X_2.query("Exterior1st=='Wd Sdng'")['Exterior2nd'].value_counts()
# Out:
# Wd Sdng    177
# Wd Shng      9
# Plywood      8
# ImStucc      3
# HdBoard      2
# VinylSd      2
# BrkFace      1
# AsbShng      1
# MetalSd      1
# Stucco       1
# Stone        1
# Name: Exterior2nd, dtype: int64

# %%
X_2.query("Exterior1st=='WdShing'")['Exterior2nd'].value_counts()
# Out:
# Wd Shng    17
# Plywood     5
# HdBoard     2
# Wd Sdng     1
# Stucco      1
# Name: Exterior2nd, dtype: int64

# %%
X_2.query("Exterior2nd=='Wd Shng'")['Exterior1st'].value_counts()
# Out:
# WdShing    17
# Wd Sdng     9
# VinylSd     5
# Stucco      3
# BrkFace     1
# CemntBd     1
# MetalSd     1
# HdBoard     1
# Name: Exterior1st, dtype: int64

# %% [markdown]
# For [Exterior1st, Exterior2nd], from the amount of:
# - [Wd Sdng, Wd Sdng]
# - [Wd Sdng, Wd Shng]
# - [WdShing, Wd Shng]
# I would say that "Wd Shng" --> "WdShing"

# %%
dict_clean_3 = {
    "Exterior2nd": {"CmentBd": "CemntBd",
                    "Brk Cmn":"BrkComm",
                    "Wd Shng": "WdShing"}
}

def wrong_categories(X):
    return X.replace(dict_clean_3)

X_3 = wrong_categories(X_2)
X_test_3 = wrong_categories(X_test_2)
df_combined_3 = wrong_categories(df_combined_2)

# %% [markdown]
# ### Dates

# %%
df_combined_3[["YearBuilt", "YearRemodAdd", "GarageYrBlt", "YrSold"]].describe()
# Out:
#          YearBuilt  YearRemodAdd  GarageYrBlt       YrSold
# count  2919.000000   2919.000000  2760.000000  2919.000000
# mean   1971.312778   1984.264474  1978.113406  2007.792737
# std      30.291442     20.894344    25.574285     1.314964
# min    1872.000000   1950.000000  1895.000000  2006.000000
# 25%    1953.500000   1965.000000  1960.000000  2007.000000
# 50%    1973.000000   1993.000000  1979.000000  2008.000000
# 75%    2001.000000   2004.000000  2002.000000  2009.000000
# max    2010.000000   2010.000000  2207.000000  2010.000000

# %%
with pd.option_context('display.max_columns', None):
    display(df_combined[['YearBuilt', 'GarageYrBlt', 'YrSold', 'YearRemodAdd', 'set']].sort_values('GarageYrBlt', ascending=False).head(10))
# Out:
#       YearBuilt  GarageYrBlt  YrSold  YearRemodAdd    set
# Id
# 2593       2006       2207.0    2007          2007   test
# 1503       2010       2010.0    2010          2010   test
# 988        2009       2010.0    2010          2010  train
# 379        2010       2010.0    2010          2010  train
# 1609       2009       2010.0    2010          2010   test
# 820        2009       2010.0    2010          2010  train
# 645        2009       2009.0    2009          2009  train
# 516        2009       2009.0    2009          2009  train
# 573        2009       2009.0    2009          2009  train
# 582        2008       2009.0    2009          2009  train

# %%
df_combined_3\
    .query("GarageYrBlt<YearBuilt|YrSold<YearBuilt|YearRemodAdd<YearBuilt")\
    [['YearBuilt', 'GarageYrBlt', 'YrSold', 'YearRemodAdd', 'set']]\
    .assign(issue_Garage=lambda x: x['GarageYrBlt']<x['YearBuilt'])
# Out:
#       YearBuilt  GarageYrBlt  YrSold  YearRemodAdd    set  issue_Garage
# Id
# 30         1927       1920.0    2008          1950  train          True
# 94         1910       1900.0    2007          1998  train          True
# 325        1967       1961.0    2010          2007  train          True
# 601        2005       2003.0    2006          2005  train          True
# 737        1950       1949.0    2006          1950  train          True
# 1104       1959       1954.0    2006          1959  train          True
# 1377       1930       1925.0    2008          1950  train          True
# 1415       1923       1922.0    2008          2000  train          True
# 1419       1963       1962.0    2008          1963  train          True
# 1522       1959       1956.0    2010          1959   test          True
# 1577       2010       2009.0    2010          2010   test          True
# 1806       1935       1920.0    2009          1998   test          True
# 1841       1978       1960.0    2009          1978   test          True
# 1877       2002       2002.0    2009          2001   test         False
# 1896       1941       1940.0    2009          1950   test          True
# 1898       1935       1926.0    2009          1950   test          True
# 2123       1945       1925.0    2008          1995   test          True
# 2264       2006       2005.0    2007          2007   test          True
# 2510       2006       2005.0    2007          2006   test          True
# 2550       2008       2008.0    2007          2009   test         False

# %%
X['GarageYrBlt'].isna().sum()
# Out:
# 81

# %%
print('Nb of rows with no Garage', X['GarageQual'].isna().sum())
print('Nb of rows with GarageYrBlt==NaN', X['GarageYrBlt'].isna().sum())
# Out:
# Nb of rows with no Garage 81
# Nb of rows with GarageYrBlt==NaN 81

# %% [markdown]
# I plan to add new features such as the difference in years instead of years

# %%
def wrong_dates(X_init):
    X = X_init.copy()

    # X.loc[X['YrSold'] < X['YearBuilt'], 'YrSold'] = X.loc[X['YrSold'] < X['YearBuilt'], 'YearBuilt']
    # X.loc[X['YearRemodAdd'] < X['YearBuilt'], 'YearRemodAdd'] = X.loc[X['YearRemodAdd'] < X['YearBuilt'], 'YearBuilt']
    # X.loc[X['GarageYrBlt'] < X['YearBuilt'], 'GarageYrBlt'] = X.loc[X['GarageYrBlt'] < X['YearBuilt'], 'YearBuilt']
    
    X['GarageYrBlt'] = X['GarageYrBlt'].fillna(0)
    X.loc[X['GarageYrBlt'] > 2010, 'GarageYrBlt'] = X.loc[X['GarageYrBlt'] > 2010, 'YearRemodAdd']
    return X

# %%
X['GarageYrBlt'].isna().sum()
# Out:
# 81

# %% [markdown]
# ## Preprocessing Summary

# %%
def preproc(X):
    return X.pipe(discrete_integer)\
            .pipe(discrete_na)\
            .pipe(wrong_categories)\
            .pipe(wrong_dates)\
            .pipe(to_ordered_categories)#\
            #.pipe(numerical_na)

# %%
X_pre = preproc(X)
X_test_pre = preproc(X_test)
df_combined_pre = preproc(df_combined)

# %%
X_pre['Utilities']
# Out:
# Id
# 1       4
# 2       4
# 3       4
# 4       4
# 5       4
#        ..
# 1456    4
# 1457    4
# 1458    4
# 1459    4
# 1460    4
# Name: Utilities, Length: 1460, dtype: category
# Categories (5, int64): [4 < 3 < 2 < 1 < 0]

# %%
X_pre_cat_list = X_pre.select_dtypes('category').apply(lambda x: x.cat.categories)
X_test_pre_cat_list = X_test_pre.select_dtypes('category').apply(lambda x: x.cat.categories)

for column in X_pre_cat_list.index:
    same_category = X_pre_cat_list[column].equals(X_test_pre_cat_list[column])
    if same_category:
        print(column, 'OK')
    else:
        print(column, X_pre_cat_list[column], X_test_pre_cat_list[column])
# Out:
# Street OK
# Alley OK
# LotShape OK
# LandContour OK
# Utilities OK
# LandSlope OK
# ExterQual OK
# ExterCond OK
# BsmtQual OK
# BsmtCond OK
# BsmtExposure OK
# BsmtFinType1 OK
# BsmtFinType2 OK
# HeatingQC OK
# CentralAir OK
# Electrical OK
# KitchenQual OK
# Functional OK
# FireplaceQu OK
# GarageFinish OK
# GarageQual OK
# GarageCond OK
# PavedDrive OK
# PoolQC OK

# %%
X_pre.nunique()\
    .rename('nunique')\
    .to_frame()\
    .join([X_pre.isna().sum().rename('isna'),
           X_pre.dtypes.rename('type'),
           X_test_pre.isna().sum().rename('isna test')])\
    .sort_values('nunique')\
    .style.bar()
# Out:
# <style type="text/css">
# #T_015d6_row0_col0, #T_015d6_row0_col1, #T_015d6_row0_col3, #T_015d6_row1_col0, #T_015d6_row1_col1, #T_015d6_row1_col3, #T_015d6_row2_col0, #T_015d6_row2_col1, #T_015d6_row2_col3, #T_015d6_row3_col1, #T_015d6_row3_col3, #T_015d6_row4_col1, #T_015d6_row4_col3, #T_015d6_row5_col1, #T_015d6_row5_col3, #T_015d6_row6_col1, #T_015d6_row6_col3, #T_015d6_row7_col1, #T_015d6_row7_col3, #T_015d6_row8_col1, #T_015d6_row8_col3, #T_015d6_row9_col1, #T_015d6_row9_col3, #T_015d6_row10_col1, #T_015d6_row10_col3, #T_015d6_row11_col1, #T_015d6_row11_col3, #T_015d6_row12_col1, #T_015d6_row12_col3, #T_015d6_row13_col1, #T_015d6_row13_col3, #T_015d6_row14_col1, #T_015d6_row14_col3, #T_015d6_row15_col1, #T_015d6_row15_col3, #T_015d6_row16_col1, #T_015d6_row16_col3, #T_015d6_row17_col1, #T_015d6_row17_col3, #T_015d6_row18_col1, #T_015d6_row18_col3, #T_015d6_row19_col1, #T_015d6_row19_col3, #T_015d6_row20_col1, #T_015d6_row20_col3, #T_015d6_row21_col1, #T_015d6_row21_col3, #T_015d6_row22_col1, #T_015d6_row22_col3, #T_015d6_row23_col1, #T_015d6_row23_col3, #T_015d6_row24_col1, #T_015d6_row24_col3, #T_015d6_row25_col1, #T_015d6_row25_col3, #T_015d6_row26_col1, #T_015d6_row26_col3, #T_015d6_row27_col1, #T_015d6_row27_col3, #T_015d6_row28_col1, #T_015d6_row28_col3, #T_015d6_row29_col1, #T_015d6_row29_col3, #T_015d6_row30_col1, #T_015d6_row31_col1, #T_015d6_row31_col3, #T_015d6_row32_col1, #T_015d6_row32_col3, #T_015d6_row33_col1, #T_015d6_row33_col3, #T_015d6_row34_col1, #T_015d6_row34_col3, #T_015d6_row35_col1, #T_015d6_row35_col3, #T_015d6_row36_col1, #T_015d6_row36_col3, #T_015d6_row37_col1, #T_015d6_row37_col3, #T_015d6_row38_col1, #T_015d6_row38_col3, #T_015d6_row39_col1, #T_015d6_row39_col3, #T_015d6_row40_col1, #T_015d6_row40_col3, #T_015d6_row41_col1, #T_015d6_row41_col3, #T_015d6_row42_col1, #T_015d6_row42_col3, #T_015d6_row43_col1, #T_015d6_row43_col3, #T_015d6_row44_col1, #T_015d6_row44_col3, #T_015d6_row45_col1, #T_015d6_row45_col3, #T_015d6_row46_col1, #T_015d6_row46_col3, #T_015d6_row47_col1, #T_015d6_row47_col3, #T_015d6_row48_col1, #T_015d6_row49_col1, #T_015d6_row49_col3, #T_015d6_row50_col1, #T_015d6_row50_col3, #T_015d6_row51_col1, #T_015d6_row51_col3, #T_015d6_row52_col1, #T_015d6_row52_col3, #T_015d6_row53_col1, #T_015d6_row53_col3, #T_015d6_row54_col1, #T_015d6_row54_col3, #T_015d6_row55_col1, #T_015d6_row56_col1, #T_015d6_row56_col3, #T_015d6_row57_col1, #T_015d6_row57_col3, #T_015d6_row58_col1, #T_015d6_row58_col3, #T_015d6_row59_col1, #T_015d6_row59_col3, #T_015d6_row60_col1, #T_015d6_row60_col3, #T_015d6_row61_col1, #T_015d6_row61_col3, #T_015d6_row62_col1, #T_015d6_row62_col3, #T_015d6_row63_col1, #T_015d6_row63_col3, #T_015d6_row65_col1, #T_015d6_row65_col3, #T_015d6_row66_col1, #T_015d6_row66_col3, #T_015d6_row67_col1, #T_015d6_row67_col3, #T_015d6_row68_col1, #T_015d6_row68_col3, #T_015d6_row69_col1, #T_015d6_row69_col3, #T_015d6_row70_col1, #T_015d6_row70_col3, #T_015d6_row71_col1, #T_015d6_row71_col3, #T_015d6_row72_col1, #T_015d6_row72_col3, #T_015d6_row73_col1, #T_015d6_row73_col3, #T_015d6_row74_col1, #T_015d6_row74_col3, #T_015d6_row75_col1, #T_015d6_row75_col3, #T_015d6_row76_col1, #T_015d6_row76_col3, #T_015d6_row77_col1, #T_015d6_row77_col3, #T_015d6_row78_col1, #T_015d6_row78_col3 {
#   width: 10em;
#   height: 80%;
# }
# #T_015d6_row3_col0, #T_015d6_row4_col0, #T_015d6_row5_col0, #T_015d6_row6_col0, #T_015d6_row7_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 0.1%, transparent 0.1%);
# }
# #T_015d6_row8_col0, #T_015d6_row9_col0, #T_015d6_row10_col0, #T_015d6_row11_col0, #T_015d6_row12_col0, #T_015d6_row13_col0, #T_015d6_row14_col0, #T_015d6_row15_col0, #T_015d6_row16_col0, #T_015d6_row17_col0, #T_015d6_row18_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 0.2%, transparent 0.2%);
# }
# #T_015d6_row19_col0, #T_015d6_row20_col0, #T_015d6_row21_col0, #T_015d6_row22_col0, #T_015d6_row23_col0, #T_015d6_row24_col0, #T_015d6_row25_col0, #T_015d6_row26_col0, #T_015d6_row27_col0, #T_015d6_row28_col0, #T_015d6_row29_col0, #T_015d6_row30_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 0.3%, transparent 0.3%);
# }
# #T_015d6_row30_col3, #T_015d6_row58_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 1.8%, transparent 1.8%);
# }
# #T_015d6_row31_col0, #T_015d6_row32_col0, #T_015d6_row33_col0, #T_015d6_row34_col0, #T_015d6_row35_col0, #T_015d6_row36_col0, #T_015d6_row37_col0, #T_015d6_row38_col0, #T_015d6_row48_col3, #T_015d6_row55_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 0.4%, transparent 0.4%);
# }
# #T_015d6_row39_col0, #T_015d6_row40_col0, #T_015d6_row41_col0, #T_015d6_row42_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 0.5%, transparent 0.5%);
# }
# #T_015d6_row43_col0, #T_015d6_row44_col0, #T_015d6_row45_col0, #T_015d6_row46_col0, #T_015d6_row47_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 0.6%, transparent 0.6%);
# }
# #T_015d6_row48_col0, #T_015d6_row49_col0, #T_015d6_row50_col0, #T_015d6_row51_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 0.7%, transparent 0.7%);
# }
# #T_015d6_row52_col0, #T_015d6_row53_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 0.9%, transparent 0.9%);
# }
# #T_015d6_row54_col0, #T_015d6_row55_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 1.2%, transparent 1.2%);
# }
# #T_015d6_row56_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 1.3%, transparent 1.3%);
# }
# #T_015d6_row57_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 1.7%, transparent 1.7%);
# }
# #T_015d6_row59_col0, #T_015d6_row60_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 2.1%, transparent 2.1%);
# }
# #T_015d6_row61_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 5.5%, transparent 5.5%);
# }
# #T_015d6_row62_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 6.9%, transparent 6.9%);
# }
# #T_015d6_row63_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 9.0%, transparent 9.0%);
# }
# #T_015d6_row64_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 10.1%, transparent 10.1%);
# }
# #T_015d6_row64_col1, #T_015d6_row64_col3, #T_015d6_row78_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
# }
# #T_015d6_row65_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 10.3%, transparent 10.3%);
# }
# #T_015d6_row66_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 11.0%, transparent 11.0%);
# }
# #T_015d6_row67_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 13.3%, transparent 13.3%);
# }
# #T_015d6_row68_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 18.7%, transparent 18.7%);
# }
# #T_015d6_row69_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 25.4%, transparent 25.4%);
# }
# #T_015d6_row70_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 30.3%, transparent 30.3%);
# }
# #T_015d6_row71_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 38.7%, transparent 38.7%);
# }
# #T_015d6_row72_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 41.0%, transparent 41.0%);
# }
# #T_015d6_row73_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 59.3%, transparent 59.3%);
# }
# #T_015d6_row74_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 67.1%, transparent 67.1%);
# }
# #T_015d6_row75_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 70.1%, transparent 70.1%);
# }
# #T_015d6_row76_col0 {
#   width: 10em;
#   height: 80%;

# %%
columns_discrete = X.select_dtypes('object').columns.tolist()
columns_discrete = columns_discrete + ['MSSubClass', 'OverallQual', 'OverallCond']
columns_discrete, len(columns_discrete)
# Out:
# (['MSZoning',
#   'Street',
#   'Alley',
#   'LotShape',
#   'LandContour',
#   'Utilities',
#   'LotConfig',
#   'LandSlope',
#   'Neighborhood',
#   'Condition1',
#   'Condition2',
#   'BldgType',
#   'HouseStyle',
#   'RoofStyle',
#   'RoofMatl',
#   'Exterior1st',
#   'Exterior2nd',
#   'MasVnrType',
#   'ExterQual',
#   'ExterCond',
#   'Foundation',
#   'BsmtQual',
#   'BsmtCond',
#   'BsmtExposure',
#   'BsmtFinType1',
#   'BsmtFinType2',
#   'Heating',
#   'HeatingQC',
#   'CentralAir',
#   'Electrical',
#   'KitchenQual',
#   'Functional',
#   'FireplaceQu',
#   'GarageType',
#   'GarageFinish',
#   'GarageQual',
#   'GarageCond',
#   'PavedDrive',
#   'PoolQC',
#   'Fence',
#   'MiscFeature',
#   'SaleType',
#   'SaleCondition',
#   'MSSubClass',
#   'OverallQual',
#   'OverallCond'],
#  46)

# %%
ordered_categories
# Out:
# ['Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LandSlope',
#  'ExterQual',
#  'ExterCond',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC']

# %% [markdown]
# # EDA Univariate

# %%
import statsmodels.api as sm
import scipy.stats as stats

# %% [markdown]
# ## Target
#
# Evaluation score is RMSE(log(y))

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

sns.histplot(x=y, ax=axs[0])
sm.ProbPlot(y).qqplot(line='s', ax=axs[1], fmt='k')

plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(10, 10))
stats.boxcox_normplot(y, -20, 20, plot=ax)
plt.show()

# %%
maxlog = preprocessing.PowerTransformer().fit(y.to_frame()).lambdas_[0]
llf = stats.yeojohnson_llf(maxlog, y)

maxlog, llf
# Out:
# (-0.07693210208638519, -17423.60999924448)

# %%
y_boxcox = preprocessing.PowerTransformer(method='box-cox', standardize=False).fit_transform(y.to_frame())
y_boxcox = pd.Series(y_boxcox[:,0], index=y.index, name=y.name)

fig, axs = plt.subplots(1, 2, figsize=(12, 6))

sns.histplot(x=y_boxcox, ax=axs[0])
sm.ProbPlot(y_boxcox).qqplot(line='s', ax=axs[1], fmt='k')

plt.tight_layout()

# %% [markdown]
# Power transform normalize the target distribution
# Let's use log(y) from now on

# %% [markdown]
# ## Features

# %%
X_plot = X_pre.drop(columns=columns_discrete).select_dtypes('number')

fig, axs = plt.subplots(X_plot.shape[1], 2, figsize=(12, 100))

power_info = {"maxlog":{}, "llf":{}}

for i, c in enumerate(X_plot.columns):
    zero_skewed = (X_plot[c] == 0).sum() > (X_plot.shape[0] / 3)
    is_negative = X_plot[c].min() <= 0

    sns.histplot(x=X_plot[c], ax=axs[i, 0])
    sm.ProbPlot(X_plot[c]).qqplot(line='s', ax=axs[i, 1], fmt='k')

    if zero_skewed:
        x = X_plot[c].replace(0, np.NaN).dropna()
    else:
        x = X_plot[c].dropna()

    if is_negative:
        maxlog = preprocessing.PowerTransformer().fit(x.to_frame()).lambdas_[0]
        llf = stats.yeojohnson_llf(maxlog, x)
    else:
        maxlog = preprocessing.PowerTransformer(method='box-cox').fit(x.to_frame()).lambdas_[0]
        llf = stats.boxcox_llf(maxlog, x)
    power_info["maxlog"][c], power_info["llf"][c] = maxlog, llf

    if zero_skewed:
        axs[i, 1].set_title(f"w/o 0: $\lambda$={maxlog:.3f}, llf={llf:.3f}")
    else:
        axs[i, 1].set_title(f"$\lambda$={maxlog:.3f}, llf={llf:.3f}")

plt.tight_layout()
# Out:
# D:\application\anaconda3\envs\d2l\lib\site-packages\numpy\core\_methods.py:232: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# D:\application\anaconda3\envs\d2l\lib\site-packages\sklearn\preprocessing\_data.py:3251: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# D:\application\anaconda3\envs\d2l\lib\site-packages\scipy\stats\morestats.py:1557: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(trans.var(axis=0))
# D:\application\anaconda3\envs\d2l\lib\site-packages\scipy\stats\morestats.py:1557: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(trans.var(axis=0))
# D:\application\anaconda3\envs\d2l\lib\site-packages\scipy\stats\morestats.py:914: RuntimeWarning: divide by zero encountered in log
#   return (lmb - 1) * np.sum(logdata, axis=0) - N/2 * np.log(variance)
# D:\application\anaconda3\envs\d2l\lib\site-packages\scipy\stats\morestats.py:914: RuntimeWarning: divide by zero encountered in log
#   return (lmb - 1) * np.sum(logdata, axis=0) - N/2 * np.log(variance)

# %%
pd.DataFrame(power_info).sort_values("llf").style.background_gradient()
# Out:
# D:\application\anaconda3\envs\d2l\lib\site-packages\pandas\io\formats\style.py:2817: RuntimeWarning: invalid value encountered in double_scalars
#   norm = colors.Normalize(smin - (rng * low), smax + (rng * high))
# <style type="text/css">
# #T_bb276_row0_col0, #T_bb276_row1_col0, #T_bb276_row3_col0, #T_bb276_row5_col0, #T_bb276_row7_col0, #T_bb276_row10_col0, #T_bb276_row11_col0, #T_bb276_row12_col0, #T_bb276_row13_col0, #T_bb276_row14_col0, #T_bb276_row16_col0, #T_bb276_row18_col0, #T_bb276_row19_col0, #T_bb276_row20_col0, #T_bb276_row22_col0 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_bb276_row0_col1, #T_bb276_row1_col1, #T_bb276_row2_col1, #T_bb276_row3_col1, #T_bb276_row4_col1, #T_bb276_row5_col1, #T_bb276_row6_col1, #T_bb276_row7_col1, #T_bb276_row8_col1, #T_bb276_row9_col1, #T_bb276_row10_col1, #T_bb276_row11_col1, #T_bb276_row12_col1, #T_bb276_row13_col1, #T_bb276_row14_col1, #T_bb276_row15_col1, #T_bb276_row16_col1, #T_bb276_row17_col1, #T_bb276_row18_col1, #T_bb276_row19_col1, #T_bb276_row20_col1, #T_bb276_row21_col1, #T_bb276_row22_col1, #T_bb276_row23_col1, #T_bb276_row24_col1, #T_bb276_row25_col1, #T_bb276_row26_col1, #T_bb276_row27_col1, #T_bb276_row28_col1, #T_bb276_row29_col1, #T_bb276_row30_col1, #T_bb276_row31_col1, #T_bb276_row32_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_bb276_row2_col0, #T_bb276_row6_col0, #T_bb276_row15_col0, #T_bb276_row17_col0, #T_bb276_row21_col0, #T_bb276_row24_col0, #T_bb276_row25_col0, #T_bb276_row26_col0 {
#   background-color: #045e94;
#   color: #f1f1f1;
# }
# #T_bb276_row4_col0 {
#   background-color: #045e93;
#   color: #f1f1f1;
# }
# #T_bb276_row8_col0 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_bb276_row9_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_bb276_row23_col0 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_bb276_row27_col0 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_bb276_row28_col0 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_bb276_row29_col0 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_bb276_row30_col0 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_bb276_row31_col0 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# #T_bb276_row32_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_bb276_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >maxlog</th>
#       <th class="col_heading level0 col1" >llf</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bb276_level0_row0" class="row_heading level0 row0" >LotArea</th>
#       <td id="T_bb276_row0_col0" class="data row0 col0" >0.030946</td>
#       <td id="T_bb276_row0_col1" class="data row0 col1" >-12338.598017</td>
#     </tr>
#     <tr>
#       <th id="T_bb276_level0_row1" class="row_heading level0 row1" >GrLivArea</th>
#       <td id="T_bb276_row1_col0" class="data row1 col0" >0.006305</td>
#       <td id="T_bb276_row1_col1" class="data row1 col1" >-9007.421673</td>
#     </tr>
#     <tr>
#       <th id="T_bb276_level0_row2" class="row_heading level0 row2" >TotalBsmtSF</th>
#       <td id="T_bb276_row2_col0" class="data row2 col0" >0.739602</td>
#       <td id="T_bb276_row2_col1" class="data row2 col1" >-8823.889064</td>
#     </tr>
#     <tr>
#       <th id="T_bb276_level0_row3" class="row_heading level0 row3" >1stFlrSF</th>
#       <td id="T_bb276_row3_col0" class="data row3 col0" >-0.078832</td>
#       <td id="T_bb276_row3_col1" class="data row3 col1" >-8555.762378</td>
#     </tr>
#     <tr>
#       <th id="T_bb276_level0_row4" class="row_heading level0 row4" >GarageYrBlt</th>
#       <td id="T_bb276_row4_col0" class="data row4 col0" >2.337545</td>
#       <td id="T_bb276_row4_col1" class="data row4 col1" >-8523.795892</td>
#     </tr>
#     <tr>
#       <th id="T_bb276_level0_row5" class="row_heading level0 row5" >BsmtUnfSF</th>
#       <td id="T_bb276_row5_col0" class="data row5 col0" >0.471272</td>
#       <td id="T_bb276_row5_col1" class="data row5 col1" >-8522.428473</td>
#     </tr>
#     <tr>
#       <th id="T_bb276_level0_row6" class="row_heading level0 row6" >GarageArea</th>
#       <td id="T_bb276_row6_col0" class="data row6 col0" >0.811258</td>
#       <td id="T_bb276_row6_col1" class="data row6 col1" >-7801.022947</td>
#     </tr>
#     <tr>
#       <th id="T_bb276_level0_row7" class="row_heading level0 row7" >BsmtFinSF1</th>
#       <td id="T_bb276_row7_col0" class="data row7 col0" >0.228726</td>
#       <td id="T_bb276_row7_col1" class="data row7 col1" >-7577.201536</td>
#     </tr>
#     <tr>
#       <th id="T_bb276_level0_row8" class="row_heading level0 row8" >YearBuilt</th>
#       <td id="T_bb276_row8_col0" class="data row8 col0" >22.116550</td>
#       <td id="T_bb276_row8_col1" class="data row8 col1" >-4906.245486</td>
#     </tr>
#     <tr>
#       <th id="T_bb276_level0_row9" class="row_heading level0 row9" >YearRemodAdd</th>
#       <td id="T_bb276_row9_col0" class="data row9 col0" >40.568178</td>
#       <td id="T_bb276_row9_col1" class="data row9 col1" >-4346.202618</td>
#     </tr>
#     <tr>
#       <th id="T_bb276_level0_row10" class="row_heading level0 row10" >LotFrontage</th>
#       <td id="T_bb276_row10_col0" class="data row10 col0" >0.400786</td>
#       <td id="T_bb276_row10_col1" class="data row10 col1" >-3748.870089</td>
#     </tr>
#     <tr>
#       <th id="T_bb276_level0_row11" class="row_heading level0 row11" >2ndFlrSF</th>
#       <td id="T_bb276_row11_col0" class="data row11 col0" >0.524767</td>
#       <td id="T_bb276_row11_col1" class="data row11 col1" >-3522.847490</td>
#     </tr>
#     <tr>
#       <th id="T_bb276_level0_row12" class="row_heading level0 row12" >WoodDeckSF</th>
#       <td id="T_bb276_row12_col0" class="data row12 col0" >0.274359</td>
#       <td id="T_bb276_row12_col1" class="data row12 col1" >-3194.031466</td>
#     </tr>
#     <tr>
#       <th id="T_bb276_level0_row13" class="row_heading level0 row13" >OpenPorchSF</th>
#       <td id="T_bb276_row13_col0" class="data row13 col0" >-0.067064</td>
#       <td id="T_bb276_row13_col1" class="data row13 col1" >-3099.145979</td>
#     </tr>
#     <tr>
#       <th id="T_bb276_level0_row14" class="row_heading level0 row14" >MasVnrArea</th>
#       <td id="T_bb276_row14_col0" class="data row14 col0" >0.248840</td>
#       <td id="T_bb276_row14_col1" class="data row14 col1" >-2976.069410</td>
#     </tr>
#     <tr>
#       <th id="T_bb276_level0_row15" class="row_heading level0 row15" >MoSold</th>
#       <td id="T_bb276_row15_col0" class="data row15 col0" >0.775925</td>
#       <td id="T_bb276_row15_col1" class="data row15 col1" >-1439.205650</td>
#     </tr>
#     <tr>
#       <th id="T_bb276_level0_row16" class="row_heading level0 row16" >BsmtFinSF2</th>
#       <td id="T_bb276_row16_col0" class="data row16 col0" >0.300276</td>
#       <td id="T_bb276_row16_col1" class="data row16 col1" >-916.980260</td>
#     </tr>
#     <tr>
#       <th id="T_bb276_level0_row17" class="row_heading level0 row17" >EnclosedPorch</th>
#       <td id="T_bb276_row17_col0" class="data row17 col0" >0.550330</td>
#       <td id="T_bb276_row17_col1" class="data row17 col1" >-892.301322</td>
#     </tr>
#     <tr>
#       <th id="T_bb276_level0_row18" class="row_heading level0 row18" >TotRmsAbvGrd</th>
#       <td id="T_bb276_row18_col0" class="data row18 col0" >0.218075</td>
#       <td id="T_bb276_row18_col1" class="data row18 col1" >-662.294990</td>
#     </tr>
#     <tr>
#       <th id="T_bb276_level0_row19" class="row_heading level0 row19" >ScreenPorch</th>
#       <td id="T_bb276_row19_col0" class="data row19 col0" >0.283401</td>
#       <td id="T_bb276_row19_col1" class="data row19 col1" >-495.491600</td>
#     </tr>
#     <tr>
#       <th id="T_bb276_level0_row20" class="row_heading level0 row20" >MiscVal</th>
#       <td id="T_bb276_row20_col0" class="data row20 col0" >-0.204536</td>
#       <td id="T_bb276_row20_col1" class="data row20 col1" >-330.447743</td>
#     </tr>
#     <tr>
#       <th id="T_bb276_level0_row21" class="row_heading level0 row21" >LowQualFinSF</th>
#       <td id="T_bb276_row21_col0" class="data row21 col0" >0.958386</td>
#       <td id="T_bb276_row21_col1" class="data row21 col1" >-132.580700</td>
#     </tr>
#     <tr>
#       <th id="T_bb276_level0_row22" class="row_heading level0 row22" >3SsnPorch</th>
#       <td id="T_bb276_row22_col0" class="data row22 col0" >0.508110</td>
#       <td id="

# %% [markdown]
# We can convert some features to a standard distributed feature (with a power transform)
#
# It is called area_columns but contains `MiscValue` which is a price, converted to match `log(y)`

# %%
area_columns = X.columns[X.columns.str.contains('MiscVal|Area|SF|Porch$', case=True)]
len(area_columns)
# Out:
# 18

# %%
X_pre[area_columns].describe(include='all')
# Out:
#              LotArea   MasVnrArea   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  \
# count    1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean    10516.828082   103.117123   443.639726    46.549315   567.240411
# std      9981.264932   180.731373   456.098091   161.319273   441.866955
# min      1300.000000     0.000000     0.000000     0.000000     0.000000
# 25%      7553.500000     0.000000     0.000000     0.000000   223.000000
# 50%      9478.500000     0.000000   383.500000     0.000000   477.500000
# 75%     11601.500000   164.250000   712.250000     0.000000   808.000000
# max    215245.000000  1600.000000  5644.000000  1474.000000  2336.000000
#
#        TotalBsmtSF     1stFlrSF     2ndFlrSF  LowQualFinSF    GrLivArea  \
# count  1460.000000  1460.000000  1460.000000   1460.000000  1460.000000
# mean   1057.429452  1162.626712   346.992466      5.844521  1515.463699
# std     438.705324   386.587738   436.528436     48.623081   525.480383
# min       0.000000   334.000000     0.000000      0.000000   334.000000
# 25%     795.750000   882.000000     0.000000      0.000000  1129.500000
# 50%     991.500000  1087.000000     0.000000      0.000000  1464.000000
# 75%    1298.250000  1391.250000   728.000000      0.000000  1776.750000
# max    6110.000000  4692.000000  2065.000000    572.000000  5642.000000
#
#         GarageArea   WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  \
# count  1460.000000  1460.000000  1460.000000    1460.000000  1460.000000
# mean    472.980137    94.244521    46.660274      21.954110     3.409589
# std     213.804841   125.338794    66.256028      61.119149    29.317331
# min       0.000000     0.000000     0.000000       0.000000     0.000000
# 25%     334.500000     0.000000     0.000000       0.000000     0.000000
# 50%     480.000000     0.000000    25.000000       0.000000     0.000000
# 75%     576.000000   168.000000    68.000000       0.000000     0.000000
# max    1418.000000   857.000000   547.000000     552.000000   508.000000
#
#        ScreenPorch     PoolArea       MiscVal
# count  1460.000000  1460.000000   1460.000000
# mean     15.060959     2.758904     43.489041
# std      55.757415    40.177307    496.123024
# min       0.000000     0.000000      0.000000
# 25%       0.000000     0.000000      0.000000
# 50%       0.000000     0.000000      0.000000
# 75%       0.000000     0.000000      0.000000
# max     480.000000   738.000000  15500.000000

# %%
def area_scaling(X):
    X = X.copy()
    area_columns = X.columns[X.columns.str.contains('MiscVal|Area|SF|Porch$', case=True)]
    X[area_columns] = preprocessing.power_transform(X[area_columns])
    return X

# %% [markdown]
# The features which describes an area can be standardized with PowerTransform

# %% [markdown]
# # Baseline model

# %% [markdown]
# ## Baseline Processing

# %%
y_proc = np.log(y)

# %%
# columns_discrete, ordered_categories
columns_category = X.select_dtypes('object').columns.tolist() + ['MSSubClass']
columns_object = X_pre.select_dtypes('object').columns.tolist() + ['MSSubClass']
columns_numeric = X.drop(columns=columns_object).columns.tolist()
columns_object
# Out:
# ['MSZoning',
#  'LotConfig',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'Foundation',
#  'Heating',
#  'GarageType',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition',
#  'MSSubClass']

# %%
def force_clean(X=X_pre, X_train=X_pre, final_imputer=True):
    X_clean = X.copy()
    X_train = X_train.copy()
    
    # Bug in sklearn 0.23 with SimpleImputer for categorical values (convert to numerical)
    #imputer = impute.SimpleImputer(strategy='most_frequent').fit(X_train[columns_category])
    #X_clean[columns_category] = imputer.transform(X_clean[columns_category])
    
    columns_object = X.select_dtypes('object').columns.tolist()
    # Temporary solution
    X_most_frequent = X_train[columns_object].apply(lambda x: x.mode()[0])
    X_train[columns_object] = X_train[columns_object].fillna(X_most_frequent)
    X_clean[columns_object] = X_clean[columns_object].fillna(X_most_frequent)
    
    encoder = preprocessing.OrdinalEncoder(dtype=int).fit(X_train[columns_object])
    X_train[columns_object] = encoder.transform(X_train[columns_object])
    X_clean[columns_object] = encoder.transform(X_clean[columns_object])
    
    X_train[columns_object] = X_train[columns_object].astype('category')
    X_clean[columns_object] = X_clean[columns_object].astype('category')
    
    if final_imputer:
        imputer = impute.KNNImputer().fit(X_train)
        X_nona = pd.DataFrame(imputer.transform(X_clean), index=X_clean.index, columns=X_clean.columns)
        X_clean = X_clean.fillna(X_nona)
    
    return X_clean

X_clean = force_clean(X_pre, X_pre)
X_clean_test = force_clean(X_test_pre, X_pre)

# %% [markdown]
# It is important to keep initial code values for MSSubClass (could it correlate more to target ?)

# %%
import lightgbm as lgb
import xgboost as xgb
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import cross_val_score, GridSearchCV, cross_val_predict
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import ElasticNet
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# ## Folds

# %%
#rng = np.random.RandomState(42)
rng = 42

# %%
#y_encoded, _ = pd.cut(y_proc, 8).factorize()
y_encoded, _ = pd.qcut(y_proc, 10).factorize()
sns.histplot(x=y_proc, hue=y_encoded, multiple='stack')
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Count'>

# %%
folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=rng)
y_encoded, _ = pd.qcut(y, q=10).factorize()

def get_folds(X_clean=X_clean, y=y_proc, y_encoded=y_encoded):
    #y_encoded = pd.qcut(preprocessing.power_transform(y.to_frame())[:, 0], q=20)
    #y_encoded = preprocessing.LabelEncoder().fit_transform(y_encoded)
    y_encoded, _ = pd.qcut(y, q=10).factorize()
    return folds.split(X_clean, y_encoded)

# %%
folds_index = pd.DataFrame(np.full((y.shape[0], 5), -1),
                           index=y.index,
                           columns=[f'fold{x}' for x in range(5)])

for i, (train_index, test_index) in enumerate(get_folds()):
    folds_index.iloc[train_index,i] = 0
    folds_index.iloc[test_index, i] = 1

folds_index.apply(lambda x: x.value_counts())
# Out:
#    fold0  fold1  fold2  fold3  fold4
# 0   1168   1168   1168   1168   1168
# 1    292    292    292    292    292

# %%
fig, axs = plt.subplots(2, 3, figsize=(20, 10))
axs = axs.flat

for i, c in enumerate(folds_index.columns):
    sns.histplot(x=y_proc,
                hue=folds_index.iloc[:, i],
                ax=axs[i])

sns.histplot(x=y_proc, ax=axs[5])
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Count'>

# %% [markdown]
# ## Base Model

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
from sklearn.dummy import DummyRegressor

# %%
cross_val_score(DummyRegressor(), X_clean, y_proc, cv=5, scoring='neg_root_mean_squared_error')
# Out:
# array([-0.3867785 , -0.4251402 , -0.40997109, -0.38299932, -0.39125229])

# %%
from sklearn.compose import make_column_selector

def score_models(X, y=y_proc, cv=None, clean=False, pipe=None, return_search=False, return_styled=True):
    
    if clean:
        X = force_clean(X, X)
    else:
        X = X.copy()
    
    if cv is None:
        y_encoded, _ = pd.qcut(y, q=10).factorize()
        cv = folds.split(X, y_encoded)
    
    models = [
        lgb.LGBMRegressor(objective="rmse", random_state=random_state, n_jobs=1),
        #SVR(),
        Ridge(),
        #ElasticNet(),
    ]
    
    estimator = Pipeline([("proc", pipe),
                          ("_dtype_", 'passthrough'),
                          ("model", DummyRegressor())])
    
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror',
                                 eval_metric='rmse',
                                 random_state=random_state,
                                 #enable_categorical=True,
                                 n_jobs=1)
        
    # bugfix XGB<0.15 with `enable_categorical` parameter missing    
    def convert_cat_to_int(X):
        if not isinstance(X, pd.DataFrame):
            return X
        cat_cols = X.select_dtypes("category").columns
        X[cat_cols] = X[cat_cols].apply(lambda x: x.cat.codes)
        return X
    
    transformer_cat_to_int = preprocessing.FunctionTransformer(convert_cat_to_int)
    
    param_grid = [{'_dtype_':['passthrough'], 'model':models},
                  {'_dtype_':[transformer_cat_to_int], 'model': [xgb_model]}]
    
    gscv = GridSearchCV(
        estimator=estimator,
        param_grid=param_grid,
        scoring='neg_root_mean_squared_error',
        n_jobs=4,
        refit=False,
        cv=cv,
        error_score='raise',
        return_train_score=True,
    )
    gscv.fit(X, y)
    
    def convert_class_to_name(x):
        if isinstance(x, (str,int, float, bool)):
            return x
        else:
            return type(x).__name__

    r = pd.DataFrame(gscv.cv_results_)
    r = r.drop(r.filter(regex='^split|^params$|param__dtype_|rank_test_score|std_\w+_time|score_time', axis=1).columns, axis=1)
    r = r.applymap(convert_class_to_name).set_index("param_model").sort_index()
    r[['mean_train_score', 'mean_test_score']] *= -1
    
    if return_styled:
        r = r.style.bar(subset=['mean_fit_time', 'mean_train_score', 'mean_test_score'], vmin=0)
    
    if return_search:
        return (gscv, r)
    else:
        return r

# %%
score_models(X_clean)
# Out:
# <style type="text/css">
# #T_b9c8a_row0_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 28.8%, transparent 28.8%);
# }
# #T_b9c8a_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 80.3%, transparent 80.3%);
# }
# #T_b9c8a_row0_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 29.7%, transparent 29.7%);
# }
# #T_b9c8a_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 2.2%, transparent 2.2%);
# }
# #T_b9c8a_row1_col1, #T_b9c8a_row1_col3, #T_b9c8a_row2_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
# }
# #T_b9c8a_row2_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 88.2%, transparent 88.2%);
# }
# #T_b9c8a_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 5.7%, transparent 5.7%);
# }
# </style>
# <table id="T_b9c8a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >mean_fit_time</th>
#       <th class="col_heading level0 col1" >mean_test_score</th>
#       <th class="col_heading level0 col2" >std_test_score</th>
#       <th class="col_heading level0 col3" >mean_train_score</th>
#       <th class="col_heading level0 col4" >std_train_score</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >param_model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9c8a_level0_row0" class="row_heading level0 row0" >LGBMRegressor</th>
#       <td id="T_b9c8a_row0_col0" class="data row0 col0" >0.142403</td>
#       <td id="T_b9c8a_row0_col1" class="data row0 col1" >0.133059</td>
#       <td id="T_b9c8a_row0_col2" class="data row0 col2" >0.016813</td>
#       <td id="T_b9c8a_row0_col3" class="data row0 col3" >0.038326</td>
#       <td id="T_b9c8a_row0_col4" class="data row0 col4" >0.001698</td>
#     </tr>
#     <tr>
#       <th id="T_b9c8a_level0_row1" class="row_heading level0 row1" >Ridge</th>
#       <td id="T_b9c8a_row1_col0" class="data row1 col0" >0.010800</td>
#       <td id="T_b9c8a_row1_col1" class="data row1 col1" >0.165763</td>
#       <td id="T_b9c8a_row1_col2" class="data row1 col2" >0.042284</td>
#       <td id="T_b9c8a_row1_col3" class="data row1 col3" >0.129176</td>
#       <td id="T_b9c8a_row1_col4" class="data row1 col4" >0.009979</td>
#     </tr>
#     <tr>
#       <th id="T_b9c8a_level0_row2" class="row_heading level0 row2" >XGBRegressor</th>
#       <td id="T_b9c8a_row2_col0" class="data row2 col0" >0.494000</td>
#       <td id="T_b9c8a_row2_col1" class="data row2 col1" >0.146241</td>
#       <td id="T_b9c8a_row2_col2" class="data row2 col2" >0.017503</td>
#       <td id="T_b9c8a_row2_col3" class="data row2 col3" >0.007353</td>
#       <td id="T_b9c8a_row2_col4" class="data row2 col4" >0.000871</td>
#     </tr>
#   </tbody>
# </table>

# %%
base_score = score_models(X_clean, return_styled=False)

def test_new(*args, X=X_clean, pipe=None, return_styled=True, base_score=base_score):
    
    new_series = []    
    for i, new in enumerate(args):
        if isinstance(new, pd.Series):
            new = new.rename(f'new{i}')
        new_series.append(new)
        
    score = score_models(X.join(new_series), pipe=pipe, return_styled=False)
    
    r = base_score.add_prefix('base-').join(score.add_prefix('new-'))
    r = r.assign(diff_mean=r['new-mean_test_score'] - r['base-mean_test_score'],
                 diff_std=r['new-std_test_score'] - r['base-std_test_score'])
    if return_styled:
        r = r.style.bar(subset=['base-mean_fit_time',
                                'new-mean_fit_time',
                                'base-mean_train_score',
                                'new-mean_train_score',
                                'base-mean_test_score',
                                'new-mean_test_score'], vmin=0)
    return r

# %% [markdown]
# # Feature Engineering - Univariate

# %% [markdown]
# ## Simple stuff

# %%
test_new(
    X_clean['GarageType'] == 0,
    X_clean['FireplaceQu'] == 0,
    X_clean['TotalBsmtSF'] == 0,
)
# Out:
# <style type="text/css">
# #T_9fb3c_row0_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 29.0%, transparent 29.0%);
# }
# #T_9fb3c_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 80.3%, transparent 80.3%);
# }
# #T_9fb3c_row0_col3, #T_9fb3c_row0_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 29.7%, transparent 29.7%);
# }
# #T_9fb3c_row0_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 28.6%, transparent 28.6%);
# }
# #T_9fb3c_row0_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 79.9%, transparent 79.9%);
# }
# #T_9fb3c_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 2.2%, transparent 2.2%);
# }
# #T_9fb3c_row1_col1, #T_9fb3c_row1_col3, #T_9fb3c_row1_col6, #T_9fb3c_row1_col8, #T_9fb3c_row2_col0, #T_9fb3c_row2_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
# }
# #T_9fb3c_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 2.7%, transparent 2.7%);
# }
# #T_9fb3c_row2_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 88.2%, transparent 88.2%);
# }
# #T_9fb3c_row2_col3, #T_9fb3c_row2_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 5.7%, transparent 5.7%);
# }
# #T_9fb3c_row2_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 87.9%, transparent 87.9%);
# }
# </style>
# <table id="T_9fb3c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >base-mean_fit_time</th>
#       <th class="col_heading level0 col1" >base-mean_test_score</th>
#       <th class="col_heading level0 col2" >base-std_test_score</th>
#       <th class="col_heading level0 col3" >base-mean_train_score</th>
#       <th class="col_heading level0 col4" >base-std_train_score</th>
#       <th class="col_heading level0 col5" >new-mean_fit_time</th>
#       <th class="col_heading level0 col6" >new-mean_test_score</th>
#       <th class="col_heading level0 col7" >new-std_test_score</th>
#       <th class="col_heading level0 col8" >new-mean_train_score</th>
#       <th class="col_heading level0 col9" >new-std_train_score</th>
#       <th class="col_heading level0 col10" >diff_mean</th>
#       <th class="col_heading level0 col11" >diff_std</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >param_model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9fb3c_level0_row0" class="row_heading level0 row0" >LGBMRegressor</th>
#       <td id="T_9fb3c_row0_col0" class="data row0 col0" >0.136001</td>
#       <td id="T_9fb3c_row0_col1" class="data row0 col1" >0.133059</td>
#       <td id="T_9fb3c_row0_col2" class="data row0 col2" >0.016813</td>
#       <td id="T_9fb3c_row0_col3" class="data row0 col3" >0.038326</td>
#       <td id="T_9fb3c_row0_col4" class="data row0 col4" >0.001698</td>
#       <td id="T_9fb3c_row0_col5" class="data row0 col5" >0.141800</td>
#       <td id="T_9fb3c_row0_col6" class="data row0 col6" >0.133052</td>
#       <td id="T_9fb3c_row0_col7" class="data row0 col7" >0.016817</td>
#       <td id="T_9fb3c_row0_col8" class="data row0 col8" >0.038326</td>
#       <td id="T_9fb3c_row0_col9" class="data row0 col9" >0.001698</td>
#       <td id="T_9fb3c_row0_col10" class="data row0 col10" >-0.000006</td>
#       <td id="T_9fb3c_row0_col11" class="data row0 col11" >0.000004</td>
#     </tr>
#     <tr>
#       <th id="T_9fb3c_level0_row1" class="row_heading level0 row1" >Ridge</th>
#       <td id="T_9fb3c_row1_col0" class="data row1 col0" >0.010202</td>
#       <td id="T_9fb3c_row1_col1" class="data row1 col1" >0.165763</td>
#       <td id="T_9fb3c_row1_col2" class="data row1 col2" >0.042284</td>
#       <td id="T_9fb3c_row1_col3" class="data row1 col3" >0.129176</td>
#       <td id="T_9fb3c_row1_col4" class="data row1 col4" >0.009979</td>
#       <td id="T_9fb3c_row1_col5" class="data row1 col5" >0.013202</td>
#       <td id="T_9fb3c_row1_col6" class="data row1 col6" >0.166462</td>
#       <td id="T_9fb3c_row1_col7" class="data row1 col7" >0.043026</td>
#       <td id="T_9fb3c_row1_col8" class="data row1 col8" >0.128982</td>
#       <td id="T_9fb3c_row1_col9" class="data row1 col9" >0.010150</td>
#       <td id="T_9fb3c_row1_col10" class="data row1 col10" >0.000699</td>
#       <td id="T_9fb3c_row1_col11" class="data row1 col11" >0.000743</td>
#     </tr>
#     <tr>
#       <th id="T_9fb3c_level0_row2" class="row_heading level0 row2" >XGBRegressor</th>
#       <td id="T_9fb3c_row2_col0" class="data row2 col0" >0.469399</td>
#       <td id="T_9fb3c_row2_col1" class="data row2 col1" >0.146241</td>
#       <td id="T_9fb3c_row2_col2" class="data row2 col2" >0.017503</td>
#       <td id="T_9fb3c_row2_col3" class="data row2 col3" >0.007353</td>
#       <td id="T_9fb3c_row2_col4" class="data row2 col4" >0.000871</td>
#       <td id="T_9fb3c_row2_col5" class="data row2 col5" >0.495198</td>
#       <td id="T_9fb3c_row2_col6" class="data row2 col6" >0.146241</td>
#       <td id="T_9fb3c_row2_col7" class="data row2 col7" >0.017503</td>
#       <td id="T_9fb3c_row2_col8" class="data row2 col8" >0.007353</td>
#       <td id="T_9fb3c_row2_col9" class="data row2 col9" >0.000871</td>
#       <td id="T_9fb3c_row2_col10" class="data row2 col10" >0.000000</td>
#       <td id="T_9fb3c_row2_col11" class="data row2 col11" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Missing values trial
# ### LotFrontage

# %%
X_pre.isna().sum().loc[lambda x: x>0], X_test_pre.isna().sum().loc[lambda x: x>0]
# Out:
# (LotFrontage    259
#  dtype: int64,
#  MSZoning         4
#  LotFrontage    227
#  Exterior1st      1
#  SaleType         1
#  dtype: int64)

# %%
sns.histplot(X_clean['LotFrontage'].where(X_pre['LotFrontage'].isna()))
# Out:
# <AxesSubplot:xlabel='LotFrontage', ylabel='Count'>

# %%
def test_lot_frontage(X_pre=X_pre):
    X_pre = X_pre.copy()
    X_pre[['LotFrontage']] = X_pre[['LotFrontage']].fillna(0)
    return test_new(X=force_clean(X_pre, X_pre))
test_lot_frontage()
# Out:
# <style type="text/css">
# #T_efbfe_row0_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 29.0%, transparent 29.0%);
# }
# #T_efbfe_row0_col1, #T_efbfe_row0_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 80.3%, transparent 80.3%);
# }
# #T_efbfe_row0_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 29.7%, transparent 29.7%);
# }
# #T_efbfe_row0_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 27.9%, transparent 27.9%);
# }
# #T_efbfe_row0_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 29.5%, transparent 29.5%);
# }
# #T_efbfe_row1_col0, #T_efbfe_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 2.2%, transparent 2.2%);
# }
# #T_efbfe_row1_col1, #T_efbfe_row1_col3, #T_efbfe_row1_col6, #T_efbfe_row1_col8, #T_efbfe_row2_col0, #T_efbfe_row2_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
# }
# #T_efbfe_row2_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 88.2%, transparent 88.2%);
# }
# #T_efbfe_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 5.7%, transparent 5.7%);
# }
# #T_efbfe_row2_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 87.6%, transparent 87.6%);
# }
# #T_efbfe_row2_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 6.0%, transparent 6.0%);
# }
# </style>
# <table id="T_efbfe_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >base-mean_fit_time</th>
#       <th class="col_heading level0 col1" >base-mean_test_score</th>
#       <th class="col_heading level0 col2" >base-std_test_score</th>
#       <th class="col_heading level0 col3" >base-mean_train_score</th>
#       <th class="col_heading level0 col4" >base-std_train_score</th>
#       <th class="col_heading level0 col5" >new-mean_fit_time</th>
#       <th class="col_heading level0 col6" >new-mean_test_score</th>
#       <th class="col_heading level0 col7" >new-std_test_score</th>
#       <th class="col_heading level0 col8" >new-mean_train_score</th>
#       <th class="col_heading level0 col9" >new-std_train_score</th>
#       <th class="col_heading level0 col10" >diff_mean</th>
#       <th class="col_heading level0 col11" >diff_std</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >param_model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_efbfe_level0_row0" class="row_heading level0 row0" >LGBMRegressor</th>
#       <td id="T_efbfe_row0_col0" class="data row0 col0" >0.136001</td>
#       <td id="T_efbfe_row0_col1" class="data row0 col1" >0.133059</td>
#       <td id="T_efbfe_row0_col2" class="data row0 col2" >0.016813</td>
#       <td id="T_efbfe_row0_col3" class="data row0 col3" >0.038326</td>
#       <td id="T_efbfe_row0_col4" class="data row0 col4" >0.001698</td>
#       <td id="T_efbfe_row0_col5" class="data row0 col5" >0.136598</td>
#       <td id="T_efbfe_row0_col6" class="data row0 col6" >0.132699</td>
#       <td id="T_efbfe_row0_col7" class="data row0 col7" >0.017331</td>
#       <td id="T_efbfe_row0_col8" class="data row0 col8" >0.038146</td>
#       <td id="T_efbfe_row0_col9" class="data row0 col9" >0.001519</td>
#       <td id="T_efbfe_row0_col10" class="data row0 col10" >-0.000360</td>
#       <td id="T_efbfe_row0_col11" class="data row0 col11" >0.000518</td>
#     </tr>
#     <tr>
#       <th id="T_efbfe_level0_row1" class="row_heading level0 row1" >Ridge</th>
#       <td id="T_efbfe_row1_col0" class="data row1 col0" >0.010202</td>
#       <td id="T_efbfe_row1_col1" class="data row1 col1" >0.165763</td>
#       <td id="T_efbfe_row1_col2" class="data row1 col2" >0.042284</td>
#       <td id="T_efbfe_row1_col3" class="data row1 col3" >0.129176</td>
#       <td id="T_efbfe_row1_col4" class="data row1 col4" >0.009979</td>
#       <td id="T_efbfe_row1_col5" class="data row1 col5" >0.010599</td>
#       <td id="T_efbfe_row1_col6" class="data row1 col6" >0.165208</td>
#       <td id="T_efbfe_row1_col7" class="data row1 col7" >0.041785</td>
#       <td id="T_efbfe_row1_col8" class="data row1 col8" >0.129141</td>
#       <td id="T_efbfe_row1_col9" class="data row1 col9" >0.009887</td>
#       <td id="T_efbfe_row1_col10" class="data row1 col10" >-0.000555</td>
#       <td id="T_efbfe_row1_col11" class="data row1 col11" >-0.000499</td>
#     </tr>
#     <tr>
#       <th id="T_efbfe_level0_row2" class="row_heading level0 row2" >XGBRegressor</th>
#       <td id="T_efbfe_row2_col0" class="data row2 col0" >0.469399</td>
#       <td id="T_efbfe_row2_col1" class="data row2 col1" >0.146241</td>
#       <td id="T_efbfe_row2_col2" class="data row2 col2" >0.017503</td>
#       <td id="T_efbfe_row2_col3" class="data row2 col3" >0.007353</td>
#       <td id="T_efbfe_row2_col4" class="data row2 col4" >0.000871</td>
#       <td id="T_efbfe_row2_col5" class="data row2 col5" >0.489598</td>
#       <td id="T_efbfe_row2_col6" class="data row2 col6" >0.144650</td>
#       <td id="T_efbfe_row2_col7" class="data row2 col7" >0.017444</td>
#       <td id="T_efbfe_row2_col8" class="data row2 col8" >0.007778</td>
#       <td id="T_efbfe_row2_col9" class="data row2 col9" >0.000907</td>
#       <td id="T_efbfe_row2_col10" class="data row2 col10" >-0.001592</td>
#       <td id="T_efbfe_row2_col11" class="data row2 col11" >-0.000059</td>
#     </tr>
#   </tbody>
# </table>

# %%
from sklearn.linear_model import RidgeCV

y_lotfrontage = X_pre['LotFrontage']
X_lotfrontage = X_clean.drop(columns=['LotFrontage'])

y_lotfrontage_train = y_lotfrontage.dropna()
X_lotfrontage_train = X_lotfrontage.loc[~y_lotfrontage.isna(), :]
X_lotfrontage_test = X_lotfrontage.loc[y_lotfrontage.isna(), :]

lr_lotfrontage = RidgeCV().fit(X_lotfrontage_train, y_lotfrontage_train)
lot_frontage = X_pre['LotFrontage'].copy()
lot_frontage.loc[X_pre['LotFrontage'].isna()] = lr_lotfrontage.predict(X_lotfrontage_test)

test_new(X=X_clean.assign(LotFrontage=lot_frontage))
# Out:
# <style type="text/css">
# #T_1667f_row0_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 29.0%, transparent 29.0%);
# }
# #T_1667f_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 80.3%, transparent 80.3%);
# }
# #T_1667f_row0_col3, #T_1667f_row0_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 29.7%, transparent 29.7%);
# }
# #T_1667f_row0_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 29.4%, transparent 29.4%);
# }
# #T_1667f_row0_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 79.9%, transparent 79.9%);
# }
# #T_1667f_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 2.2%, transparent 2.2%);
# }
# #T_1667f_row1_col1, #T_1667f_row1_col3, #T_1667f_row1_col6, #T_1667f_row1_col8, #T_1667f_row2_col0, #T_1667f_row2_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
# }
# #T_1667f_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 2.3%, transparent 2.3%);
# }
# #T_1667f_row2_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 88.2%, transparent 88.2%);
# }
# #T_1667f_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 5.7%, transparent 5.7%);
# }
# #T_1667f_row2_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 88.9%, transparent 88.9%);
# }
# #T_1667f_row2_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 5.6%, transparent 5.6%);
# }
# </style>
# <table id="T_1667f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >base-mean_fit_time</th>
#       <th class="col_heading level0 col1" >base-mean_test_score</th>
#       <th class="col_heading level0 col2" >base-std_test_score</th>
#       <th class="col_heading level0 col3" >base-mean_train_score</th>
#       <th class="col_heading level0 col4" >base-std_train_score</th>
#       <th class="col_heading level0 col5" >new-mean_fit_time</th>
#       <th class="col_heading level0 col6" >new-mean_test_score</th>
#       <th class="col_heading level0 col7" >new-std_test_score</th>
#       <th class="col_heading level0 col8" >new-mean_train_score</th>
#       <th class="col_heading level0 col9" >new-std_train_score</th>
#       <th class="col_heading level0 col10" >diff_mean</th>
#       <th class="col_heading level0 col11" >diff_std</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >param_model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1667f_level0_row0" class="row_heading level0 row0" >LGBMRegressor</th>
#       <td id="T_1667f_row0_col0" class="data row0 col0" >0.136001</td>
#       <td id="T_1667f_row0_col1" class="data row0 col1" >0.133059</td>
#       <td id="T_1667f_row0_col2" class="data row0 col2" >0.016813</td>
#       <td id="T_1667f_row0_col3" class="data row0 col3" >0.038326</td>
#       <td id="T_1667f_row0_col4" class="data row0 col4" >0.001698</td>
#       <td id="T_1667f_row0_col5" class="data row0 col5" >0.142198</td>
#       <td id="T_1667f_row0_col6" class="data row0 col6" >0.132327</td>
#       <td id="T_1667f_row0_col7" class="data row0 col7" >0.017977</td>
#       <td id="T_1667f_row0_col8" class="data row0 col8" >0.038428</td>
#       <td id="T_1667f_row0_col9" class="data row0 col9" >0.001762</td>
#       <td id="T_1667f_row0_col10" class="data row0 col10" >-0.000732</td>
#       <td id="T_1667f_row0_col11" class="data row0 col11" >0.001164</td>
#     </tr>
#     <tr>
#       <th id="T_1667f_level0_row1" class="row_heading level0 row1" >Ridge</th>
#       <td id="T_1667f_row1_col0" class="data row1 col0" >0.010202</td>
#       <td id="T_1667f_row1_col1" class="data row1 col1" >0.165763</td>
#       <td id="T_1667f_row1_col2" class="data row1 col2" >0.042284</td>
#       <td id="T_1667f_row1_col3" class="data row1 col3" >0.129176</td>
#       <td id="T_1667f_row1_col4" class="data row1 col4" >0.009979</td>
#       <td id="T_1667f_row1_col5" class="data row1 col5" >0.011200</td>
#       <td id="T_1667f_row1_col6" class="data row1 col6" >0.165662</td>
#       <td id="T_1667f_row1_col7" class="data row1 col7" >0.042086</td>
#       <td id="T_1667f_row1_col8" class="data row1 col8" >0.129180</td>
#       <td id="T_1667f_row1_col9" class="data row1 col9" >0.009951</td>
#       <td id="T_1667f_row1_col10" class="data row1 col10" >-0.000101</td>
#       <td id="T_1667f_row1_col11" class="data row1 col11" >-0.000198</td>
#     </tr>
#     <tr>
#       <th id="T_1667f_level0_row2" class="row_heading level0 row2" >XGBRegressor</th>
#       <td id="T_1667f_row2_col0" class="data row2 col0" >0.469399</td>
#       <td id="T_1667f_row2_col1" class="data row2 col1" >0.146241</td>
#       <td id="T_1667f_row2_col2" class="data row2 col2" >0.017503</td>
#       <td id="T_1667f_row2_col3" class="data row2 col3" >0.007353</td>
#       <td id="T_1667f_row2_col4" class="data row2 col4" >0.000871</td>
#       <td id="T_1667f_row2_col5" class="data row2 col5" >0.483400</td>
#       <td id="T_1667f_row2_col6" class="data row2 col6" >0.147256</td>
#       <td id="T_1667f_row2_col7" class="data row2 col7" >0.018430</td>
#       <td id="T_1667f_row2_col8" class="data row2 col8" >0.007247</td>
#       <td id="T_1667f_row2_col9" class="data row2 col9" >0.000735</td>
#       <td id="T_1667f_row2_col10" class="data row2 col10" >0.001015</td>
#       <td id="T_1667f_row2_col11" class="data row2 col11" >0.000927</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Dates

# %%
def test_dates_missing(X_clean=X_clean, X=X):
    X = X.copy()
    X_clean = X_clean.copy()
    
    for col in ['YearRemodAdd', 'GarageYrBlt', 'YrSold']:
        X_clean.loc[X[col].isna(), col] = X_clean.loc[X[col].isna(), 'YearBuilt']
    
    return test_new(X=X_clean)

test_dates_missing()
# Out:
# <style type="text/css">
# #T_873ac_row0_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 29.0%, transparent 29.0%);
# }
# #T_873ac_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 80.3%, transparent 80.3%);
# }
# #T_873ac_row0_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 29.7%, transparent 29.7%);
# }
# #T_873ac_row0_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 27.3%, transparent 27.3%);
# }
# #T_873ac_row0_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 80.4%, transparent 80.4%);
# }
# #T_873ac_row0_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 30.0%, transparent 30.0%);
# }
# #T_873ac_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 2.2%, transparent 2.2%);
# }
# #T_873ac_row1_col1, #T_873ac_row1_col3, #T_873ac_row1_col6, #T_873ac_row1_col8, #T_873ac_row2_col0, #T_873ac_row2_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
# }
# #T_873ac_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 2.0%, transparent 2.0%);
# }
# #T_873ac_row2_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 88.2%, transparent 88.2%);
# }
# #T_873ac_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 5.7%, transparent 5.7%);
# }
# #T_873ac_row2_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 89.3%, transparent 89.3%);
# }
# #T_873ac_row2_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 5.3%, transparent 5.3%);
# }
# </style>
# <table id="T_873ac_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >base-mean_fit_time</th>
#       <th class="col_heading level0 col1" >base-mean_test_score</th>
#       <th class="col_heading level0 col2" >base-std_test_score</th>
#       <th class="col_heading level0 col3" >base-mean_train_score</th>
#       <th class="col_heading level0 col4" >base-std_train_score</th>
#       <th class="col_heading level0 col5" >new-mean_fit_time</th>
#       <th class="col_heading level0 col6" >new-mean_test_score</th>
#       <th class="col_heading level0 col7" >new-std_test_score</th>
#       <th class="col_heading level0 col8" >new-mean_train_score</th>
#       <th class="col_heading level0 col9" >new-std_train_score</th>
#       <th class="col_heading level0 col10" >diff_mean</th>
#       <th class="col_heading level0 col11" >diff_std</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >param_model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_873ac_level0_row0" class="row_heading level0 row0" >LGBMRegressor</th>
#       <td id="T_873ac_row0_col0" class="data row0 col0" >0.136001</td>
#       <td id="T_873ac_row0_col1" class="data row0 col1" >0.133059</td>
#       <td id="T_873ac_row0_col2" class="data row0 col2" >0.016813</td>
#       <td id="T_873ac_row0_col3" class="data row0 col3" >0.038326</td>
#       <td id="T_873ac_row0_col4" class="data row0 col4" >0.001698</td>
#       <td id="T_873ac_row0_col5" class="data row0 col5" >0.133597</td>
#       <td id="T_873ac_row0_col6" class="data row0 col6" >0.133317</td>
#       <td id="T_873ac_row0_col7" class="data row0 col7" >0.017970</td>
#       <td id="T_873ac_row0_col8" class="data row0 col8" >0.038705</td>
#       <td id="T_873ac_row0_col9" class="data row0 col9" >0.001853</td>
#       <td id="T_873ac_row0_col10" class="data row0 col10" >0.000259</td>
#       <td id="T_873ac_row0_col11" class="data row0 col11" >0.001157</td>
#     </tr>
#     <tr>
#       <th id="T_873ac_level0_row1" class="row_heading level0 row1" >Ridge</th>
#       <td id="T_873ac_row1_col0" class="data row1 col0" >0.010202</td>
#       <td id="T_873ac_row1_col1" class="data row1 col1" >0.165763</td>
#       <td id="T_873ac_row1_col2" class="data row1 col2" >0.042284</td>
#       <td id="T_873ac_row1_col3" class="data row1 col3" >0.129176</td>
#       <td id="T_873ac_row1_col4" class="data row1 col4" >0.009979</td>
#       <td id="T_873ac_row1_col5" class="data row1 col5" >0.009800</td>
#       <td id="T_873ac_row1_col6" class="data row1 col6" >0.165726</td>
#       <td id="T_873ac_row1_col7" class="data row1 col7" >0.042185</td>
#       <td id="T_873ac_row1_col8" class="data row1 col8" >0.129205</td>
#       <td id="T_873ac_row1_col9" class="data row1 col9" >0.010036</td>
#       <td id="T_873ac_row1_col10" class="data row1 col10" >-0.000038</td>
#       <td id="T_873ac_row1_col11" class="data row1 col11" >-0.000099</td>
#     </tr>
#     <tr>
#       <th id="T_873ac_level0_row2" class="row_heading level0 row2" >XGBRegressor</th>
#       <td id="T_873ac_row2_col0" class="data row2 col0" >0.469399</td>
#       <td id="T_873ac_row2_col1" class="data row2 col1" >0.146241</td>
#       <td id="T_873ac_row2_col2" class="data row2 col2" >0.017503</td>
#       <td id="T_873ac_row2_col3" class="data row2 col3" >0.007353</td>
#       <td id="T_873ac_row2_col4" class="data row2 col4" >0.000871</td>
#       <td id="T_873ac_row2_col5" class="data row2 col5" >0.489000</td>
#       <td id="T_873ac_row2_col6" class="data row2 col6" >0.147996</td>
#       <td id="T_873ac_row2_col7" class="data row2 col7" >0.018663</td>
#       <td id="T_873ac_row2_col8" class="data row2 col8" >0.006858</td>
#       <td id="T_873ac_row2_col9" class="data row2 col9" >0.000772</td>
#       <td id="T_873ac_row2_col10" class="data row2 col10" >0.001754</td>
#       <td id="T_873ac_row2_col11" class="data row2 col11" >0.001160</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Cleaning in Pipeline

# %%
test_new(X=force_clean(X_pre, X_pre, final_imputer=False), pipe=impute.KNNImputer())
# Out:
# <style type="text/css">
# #T_f14d6_row0_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 29.0%, transparent 29.0%);
# }
# #T_f14d6_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 80.3%, transparent 80.3%);
# }
# #T_f14d6_row0_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 29.7%, transparent 29.7%);
# }
# #T_f14d6_row0_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 30.7%, transparent 30.7%);
# }
# #T_f14d6_row0_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 83.6%, transparent 83.6%);
# }
# #T_f14d6_row0_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 32.6%, transparent 32.6%);
# }
# #T_f14d6_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 2.2%, transparent 2.2%);
# }
# #T_f14d6_row1_col1, #T_f14d6_row1_col3, #T_f14d6_row1_col6, #T_f14d6_row1_col8, #T_f14d6_row2_col0, #T_f14d6_row2_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
# }
# #T_f14d6_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 9.2%, transparent 9.2%);
# }
# #T_f14d6_row2_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 88.2%, transparent 88.2%);
# }
# #T_f14d6_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 5.7%, transparent 5.7%);
# }
# #T_f14d6_row2_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 89.1%, transparent 89.1%);
# }
# #T_f14d6_row2_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 5.9%, transparent 5.9%);
# }
# </style>
# <table id="T_f14d6_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >base-mean_fit_time</th>
#       <th class="col_heading level0 col1" >base-mean_test_score</th>
#       <th class="col_heading level0 col2" >base-std_test_score</th>
#       <th class="col_heading level0 col3" >base-mean_train_score</th>
#       <th class="col_heading level0 col4" >base-std_train_score</th>
#       <th class="col_heading level0 col5" >new-mean_fit_time</th>
#       <th class="col_heading level0 col6" >new-mean_test_score</th>
#       <th class="col_heading level0 col7" >new-std_test_score</th>
#       <th class="col_heading level0 col8" >new-mean_train_score</th>
#       <th class="col_heading level0 col9" >new-std_train_score</th>
#       <th class="col_heading level0 col10" >diff_mean</th>
#       <th class="col_heading level0 col11" >diff_std</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >param_model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f14d6_level0_row0" class="row_heading level0 row0" >LGBMRegressor</th>
#       <td id="T_f14d6_row0_col0" class="data row0 col0" >0.136001</td>
#       <td id="T_f14d6_row0_col1" class="data row0 col1" >0.133059</td>
#       <td id="T_f14d6_row0_col2" class="data row0 col2" >0.016813</td>
#       <td id="T_f14d6_row0_col3" class="data row0 col3" >0.038326</td>
#       <td id="T_f14d6_row0_col4" class="data row0 col4" >0.001698</td>
#       <td id="T_f14d6_row0_col5" class="data row0 col5" >0.143201</td>
#       <td id="T_f14d6_row0_col6" class="data row0 col6" >0.138575</td>
#       <td id="T_f14d6_row0_col7" class="data row0 col7" >0.021421</td>
#       <td id="T_f14d6_row0_col8" class="data row0 col8" >0.042122</td>
#       <td id="T_f14d6_row0_col9" class="data row0 col9" >0.002332</td>
#       <td id="T_f14d6_row0_col10" class="data row0 col10" >0.005516</td>
#       <td id="T_f14d6_row0_col11" class="data row0 col11" >0.004608</td>
#     </tr>
#     <tr>
#       <th id="T_f14d6_level0_row1" class="row_heading level0 row1" >Ridge</th>
#       <td id="T_f14d6_row1_col0" class="data row1 col0" >0.010202</td>
#       <td id="T_f14d6_row1_col1" class="data row1 col1" >0.165763</td>
#       <td id="T_f14d6_row1_col2" class="data row1 col2" >0.042284</td>
#       <td id="T_f14d6_row1_col3" class="data row1 col3" >0.129176</td>
#       <td id="T_f14d6_row1_col4" class="data row1 col4" >0.009979</td>
#       <td id="T_f14d6_row1_col5" class="data row1 col5" >0.043000</td>
#       <td id="T_f14d6_row1_col6" class="data row1 col6" >0.165832</td>
#       <td id="T_f14d6_row1_col7" class="data row1 col7" >0.042358</td>
#       <td id="T_f14d6_row1_col8" class="data row1 col8" >0.129169</td>
#       <td id="T_f14d6_row1_col9" class="data row1 col9" >0.009973</td>
#       <td id="T_f14d6_row1_col10" class="data row1 col10" >0.000069</td>
#       <td id="T_f14d6_row1_col11" class="data row1 col11" >0.000075</td>
#     </tr>
#     <tr>
#       <th id="T_f14d6_level0_row2" class="row_heading level0 row2" >XGBRegressor</th>
#       <td id="T_f14d6_row2_col0" class="data row2 col0" >0.469399</td>
#       <td id="T_f14d6_row2_col1" class="data row2 col1" >0.146241</td>
#       <td id="T_f14d6_row2_col2" class="data row2 col2" >0.017503</td>
#       <td id="T_f14d6_row2_col3" class="data row2 col3" >0.007353</td>
#       <td id="T_f14d6_row2_col4" class="data row2 col4" >0.000871</td>
#       <td id="T_f14d6_row2_col5" class="data row2 col5" >0.467001</td>
#       <td id="T_f14d6_row2_col6" class="data row2 col6" >0.147828</td>
#       <td id="T_f14d6_row2_col7" class="data row2 col7" >0.019047</td>
#       <td id="T_f14d6_row2_col8" class="data row2 col8" >0.007663</td>
#       <td id="T_f14d6_row2_col9" class="data row2 col9" >0.000639</td>
#       <td id="T_f14d6_row2_col10" class="data row2 col10" >0.001587</td>
#       <td id="T_f14d6_row2_col11" class="data row2 col11" >0.001544</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Data Transformation (Power)

# %%
pipe_area = ColumnTransformer([('area', preprocessing.PowerTransformer(), area_columns)],
                              remainder='passthrough')
test_new(pipe=pipe_area)
# Out:
# <style type="text/css">
# #T_9014c_row0_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 29.0%, transparent 29.0%);
# }
# #T_9014c_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 80.3%, transparent 80.3%);
# }
# #T_9014c_row0_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 29.7%, transparent 29.7%);
# }
# #T_9014c_row0_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 32.9%, transparent 32.9%);
# }
# #T_9014c_row0_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 93.8%, transparent 93.8%);
# }
# #T_9014c_row0_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 34.3%, transparent 34.3%);
# }
# #T_9014c_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 2.2%, transparent 2.2%);
# }
# #T_9014c_row1_col1, #T_9014c_row1_col3, #T_9014c_row1_col8, #T_9014c_row2_col0, #T_9014c_row2_col5, #T_9014c_row2_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
# }
# #T_9014c_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 9.7%, transparent 9.7%);
# }
# #T_9014c_row1_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 99.5%, transparent 99.5%);
# }
# #T_9014c_row2_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 88.2%, transparent 88.2%);
# }
# #T_9014c_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 5.7%, transparent 5.7%);
# }
# #T_9014c_row2_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 5.6%, transparent 5.6%);
# }
# </style>
# <table id="T_9014c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >base-mean_fit_time</th>
#       <th class="col_heading level0 col1" >base-mean_test_score</th>
#       <th class="col_heading level0 col2" >base-std_test_score</th>
#       <th class="col_heading level0 col3" >base-mean_train_score</th>
#       <th class="col_heading level0 col4" >base-std_train_score</th>
#       <th class="col_heading level0 col5" >new-mean_fit_time</th>
#       <th class="col_heading level0 col6" >new-mean_test_score</th>
#       <th class="col_heading level0 col7" >new-std_test_score</th>
#       <th class="col_heading level0 col8" >new-mean_train_score</th>
#       <th class="col_heading level0 col9" >new-std_train_score</th>
#       <th class="col_heading level0 col10" >diff_mean</th>
#       <th class="col_heading level0 col11" >diff_std</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >param_model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9014c_level0_row0" class="row_heading level0 row0" >LGBMRegressor</th>
#       <td id="T_9014c_row0_col0" class="data row0 col0" >0.136001</td>
#       <td id="T_9014c_row0_col1" class="data row0 col1" >0.133059</td>
#       <td id="T_9014c_row0_col2" class="data row0 col2" >0.016813</td>
#       <td id="T_9014c_row0_col3" class="data row0 col3" >0.038326</td>
#       <td id="T_9014c_row0_col4" class="data row0 col4" >0.001698</td>
#       <td id="T_9014c_row0_col5" class="data row0 col5" >0.162998</td>
#       <td id="T_9014c_row0_col6" class="data row0 col6" >0.137580</td>
#       <td id="T_9014c_row0_col7" class="data row0 col7" >0.020864</td>
#       <td id="T_9014c_row0_col8" class="data row0 col8" >0.041977</td>
#       <td id="T_9014c_row0_col9" class="data row0 col9" >0.002594</td>
#       <td id="T_9014c_row0_col10" class="data row0 col10" >0.004521</td>
#       <td id="T_9014c_row0_col11" class="data row0 col11" >0.004051</td>
#     </tr>
#     <tr>
#       <th id="T_9014c_level0_row1" class="row_heading level0 row1" >Ridge</th>
#       <td id="T_9014c_row1_col0" class="data row1 col0" >0.010202</td>
#       <td id="T_9014c_row1_col1" class="data row1 col1" >0.165763</td>
#       <td id="T_9014c_row1_col2" class="data row1 col2" >0.042284</td>
#       <td id="T_9014c_row1_col3" class="data row1 col3" >0.129176</td>
#       <td id="T_9014c_row1_col4" class="data row1 col4" >0.009979</td>
#       <td id="T_9014c_row1_col5" class="data row1 col5" >0.048000</td>
#       <td id="T_9014c_row1_col6" class="data row1 col6" >0.146015</td>
#       <td id="T_9014c_row1_col7" class="data row1 col7" >0.028865</td>
#       <td id="T_9014c_row1_col8" class="data row1 col8" >0.122209</td>
#       <td id="T_9014c_row1_col9" class="data row1 col9" >0.007211</td>
#       <td id="T_9014c_row1_col10" class="data row1 col10" >-0.019748</td>
#       <td id="T_9014c_row1_col11" class="data row1 col11" >-0.013419</td>
#     </tr>
#     <tr>
#       <th id="T_9014c_level0_row2" class="row_heading level0 row2" >XGBRegressor</th>
#       <td id="T_9014c_row2_col0" class="data row2 col0" >0.469399</td>
#       <td id="T_9014c_row2_col1" class="data row2 col1" >0.146241</td>
#       <td id="T_9014c_row2_col2" class="data row2 col2" >0.017503</td>
#       <td id="T_9014c_row2_col3" class="data row2 col3" >0.007353</td>
#       <td id="T_9014c_row2_col4" class="data row2 col4" >0.000871</td>
#       <td id="T_9014c_row2_col5" class="data row2 col5" >0.494798</td>
#       <td id="T_9014c_row2_col6" class="data row2 col6" >0.146745</td>
#       <td id="T_9014c_row2_col7" class="data row2 col7" >0.017858</td>
#       <td id="T_9014c_row2_col8" class="data row2 col8" >0.006816</td>
#       <td id="T_9014c_row2_col9" class="data row2 col9" >0.000592</td>
#       <td id="T_9014c_row2_col10" class="data row2 col10" >0.000504</td>
#       <td id="T_9014c_row2_col11" class="data row2 col11" >0.000355</td>
#     </tr>
#   </tbody>
# </table>

# %%
pipe_area = ColumnTransformer([('area', preprocessing.FunctionTransformer(lambda x: np.sqrt(x+1)*(x!=0)), area_columns)],
                              remainder='passthrough')
test_new(pipe=pipe_area)
# Out:
# <style type="text/css">
# #T_bd6bc_row0_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 29.0%, transparent 29.0%);
# }
# #T_bd6bc_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 80.3%, transparent 80.3%);
# }
# #T_bd6bc_row0_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 29.7%, transparent 29.7%);
# }
# #T_bd6bc_row0_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 24.1%, transparent 24.1%);
# }
# #T_bd6bc_row0_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 91.7%, transparent 91.7%);
# }
# #T_bd6bc_row0_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 33.5%, transparent 33.5%);
# }
# #T_bd6bc_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 2.2%, transparent 2.2%);
# }
# #T_bd6bc_row1_col1, #T_bd6bc_row1_col3, #T_bd6bc_row1_col6, #T_bd6bc_row1_col8, #T_bd6bc_row2_col0, #T_bd6bc_row2_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
# }
# #T_bd6bc_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 2.6%, transparent 2.6%);
# }
# #T_bd6bc_row2_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 88.2%, transparent 88.2%);
# }
# #T_bd6bc_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 5.7%, transparent 5.7%);
# }
# #T_bd6bc_row2_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 96.8%, transparent 96.8%);
# }
# #T_bd6bc_row2_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 5.9%, transparent 5.9%);
# }
# </style>
# <table id="T_bd6bc_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >base-mean_fit_time</th>
#       <th class="col_heading level0 col1" >base-mean_test_score</th>
#       <th class="col_heading level0 col2" >base-std_test_score</th>
#       <th class="col_heading level0 col3" >base-mean_train_score</th>
#       <th class="col_heading level0 col4" >base-std_train_score</th>
#       <th class="col_heading level0 col5" >new-mean_fit_time</th>
#       <th class="col_heading level0 col6" >new-mean_test_score</th>
#       <th class="col_heading level0 col7" >new-std_test_score</th>
#       <th class="col_heading level0 col8" >new-mean_train_score</th>
#       <th class="col_heading level0 col9" >new-std_train_score</th>
#       <th class="col_heading level0 col10" >diff_mean</th>
#       <th class="col_heading level0 col11" >diff_std</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >param_model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bd6bc_level0_row0" class="row_heading level0 row0" >LGBMRegressor</th>
#       <td id="T_bd6bc_row0_col0" class="data row0 col0" >0.136001</td>
#       <td id="T_bd6bc_row0_col1" class="data row0 col1" >0.133059</td>
#       <td id="T_bd6bc_row0_col2" class="data row0 col2" >0.016813</td>
#       <td id="T_bd6bc_row0_col3" class="data row0 col3" >0.038326</td>
#       <td id="T_bd6bc_row0_col4" class="data row0 col4" >0.001698</td>
#       <td id="T_bd6bc_row0_col5" class="data row0 col5" >0.108801</td>
#       <td id="T_bd6bc_row0_col6" class="data row0 col6" >0.138310</td>
#       <td id="T_bd6bc_row0_col7" class="data row0 col7" >0.021057</td>
#       <td id="T_bd6bc_row0_col8" class="data row0 col8" >0.041651</td>
#       <td id="T_bd6bc_row0_col9" class="data row0 col9" >0.002732</td>
#       <td id="T_bd6bc_row0_col10" class="data row0 col10" >0.005251</td>
#       <td id="T_bd6bc_row0_col11" class="data row0 col11" >0.004244</td>
#     </tr>
#     <tr>
#       <th id="T_bd6bc_level0_row1" class="row_heading level0 row1" >Ridge</th>
#       <td id="T_bd6bc_row1_col0" class="data row1 col0" >0.010202</td>
#       <td id="T_bd6bc_row1_col1" class="data row1 col1" >0.165763</td>
#       <td id="T_bd6bc_row1_col2" class="data row1 col2" >0.042284</td>
#       <td id="T_bd6bc_row1_col3" class="data row1 col3" >0.129176</td>
#       <td id="T_bd6bc_row1_col4" class="data row1 col4" >0.009979</td>
#       <td id="T_bd6bc_row1_col5" class="data row1 col5" >0.011600</td>
#       <td id="T_bd6bc_row1_col6" class="data row1 col6" >0.150895</td>
#       <td id="T_bd6bc_row1_col7" class="data row1 col7" >0.031320</td>
#       <td id="T_bd6bc_row1_col8" class="data row1 col8" >0.124498</td>
#       <td id="T_bd6bc_row1_col9" class="data row1 col9" >0.008319</td>
#       <td id="T_bd6bc_row1_col10" class="data row1 col10" >-0.014868</td>
#       <td id="T_bd6bc_row1_col11" class="data row1 col11" >-0.010963</td>
#     </tr>
#     <tr>
#       <th id="T_bd6bc_level0_row2" class="row_heading level0 row2" >XGBRegressor</th>
#       <td id="T_bd6bc_row2_col0" class="data row2 col0" >0.469399</td>
#       <td id="T_bd6bc_row2_col1" class="data row2 col1" >0.146241</td>
#       <td id="T_bd6bc_row2_col2" class="data row2 col2" >0.017503</td>
#       <td id="T_bd6bc_row2_col3" class="data row2 col3" >0.007353</td>
#       <td id="T_bd6bc_row2_col4" class="data row2 col4" >0.000871</td>
#       <td id="T_bd6bc_row2_col5" class="data row2 col5" >0.450601</td>
#       <td id="T_bd6bc_row2_col6" class="data row2 col6" >0.146005</td>
#       <td id="T_bd6bc_row2_col7" class="data row2 col7" >0.017090</td>
#       <td id="T_bd6bc_row2_col8" class="data row2 col8" >0.007353</td>
#       <td id="T_bd6bc_row2_col9" class="data row2 col9" >0.000871</td>
#       <td id="T_bd6bc_row2_col10" class="data row2 col10" >-0.000236</td>
#       <td id="T_bd6bc_row2_col11" class="data row2 col11" >-0.000414</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Correlation (MI)

# %%
from sklearn.feature_selection import mutual_info_regression

def show_mi(X, y=y, clean=False):
    if clean:
        X = force_clean(X)
    
    columns_discrete = X.select_dtypes(['object', 'category'])
    discrete_features = X.columns.isin(columns_discrete)
    
    mi = mutual_info_regression(X, y,
                                random_state=random_state,
                                discrete_features=discrete_features)

    s = pd.Series(mi, index=X.columns, name='mutual_info_regression')\
          .sort_values(ascending=False)
          
    return s, s.to_frame().style.bar()

# %%
s_mi, mi = show_mi(X_clean)
mi

# %% [markdown]
# ## Discard low correlation

# %%
X_mi = X_clean.loc[:, s_mi > 1e-4]
X_clean.columns.difference(X_mi.columns)

# %%
test_new(X=X_mi)

# %% [markdown]
# ## Summary

# %%
def proc_univariate(X=X_pre, X_train=X_pre):
    X = X.copy()
    #X[['LotFrontage']] = X[['LotFrontage']].fillna(0)
    X = force_clean(X, X_train)   
    
    s_mi, _ = show_mi(X)
    X = X.loc[:, s_mi > 1e-4]
    
    filtered_area_columns = X.columns.intersection(area_columns)
    sqrt_transform = preprocessing.FunctionTransformer(lambda x: np.sqrt(x+1)*(x!=0))
    pipe_area = ColumnTransformer([('area', sqrt_transform, filtered_area_columns)],
                                  remainder='passthrough')
    return test_new(X=X, pipe=pipe_area)

proc_univariate()

# %% [markdown]
# # EDA Multi-variate

# %% [markdown]
# ## Feature Correlation

# %% [markdown]
# ### Numerical

# %%
# columns_numeric = X_clean.select_dtypes(exclude='category').columns.tolist() + ordered_categories

X_corr_num = X_clean[columns_numeric].astype(float).corr(method='spearman')

sns.clustermap(
    X_corr_num,
    vmin=-1,
    vmax=1,
    cmap='icefire',
    method='complete',
    xticklabels=True,
    yticklabels=True,
    linewidths=1,
)

# %% [markdown]
# ### Categorical / Numerical
#
# 1. https://stackoverflow.com/questions/20892799/using-pandas-calculate-cram%C3%A9rs-coefficient-matrix
# 2. https://stats.stackexchange.com/questions/484299/how-to-check-the-correlation-between-categorical-and-numeric-independent-variabl
# 3. https://stats.stackexchange.com/questions/369783/how-to-do-a-correlation-matrix-with-categorical-ordinal-and-interval-variable
# 4. https://stats.stackexchange.com/questions/108007/correlations-with-unordered-categorical-variables
# 5. https://medium.com/@outside2SDs/an-overview-of-correlation-measures-between-categorical-and-continuous-variables-4c7f85610365

# %%
def cramers_corrected_stat(s1, s2):
    """ calculate Cramers V statistic for categorial-categorial association.
        uses correction from Bergsma and Wicher, 
        Journal of the Korean Statistical Society 42 (2013): 323-328
    """
    confusion_matrix = pd.crosstab(s1, s2)
    
    chi2 = stats.chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    phi2 = chi2/n
    r,k = confusion_matrix.shape
    phi2corr = max(0, phi2 - ((k-1)*(r-1))/(n-1))    
    rcorr = r - ((r-1)**2)/(n-1)
    kcorr = k - ((k-1)**2)/(n-1)
    return np.sqrt(phi2corr / min( (kcorr-1), (rcorr-1)))

X_corr_mix = X_clean.astype(float).corr(method=cramers_corrected_stat).loc[columns_numeric, columns_object]

sns.clustermap(
    X_corr_mix,
    vmin=0,
    vmax=1,
    #cmap='icefire',
    method='complete',
    xticklabels=True,
    yticklabels=True,
    linewidths=1,
)

# %% [markdown]
# ### Category / Category

# %%
X_corr_cat = X_clean[columns_object].astype(int).corr(method=cramers_corrected_stat)

sns.clustermap(
    X_corr_cat,
    vmin=0,
    vmax=1,
    #cmap='icefire',
    method='complete',
    xticklabels=True,
    yticklabels=True,
    linewidths=1,
)

# %% [markdown]
# ## Summary

# %%
s_mi.head(20).to_frame().style.bar(vmin=0, vmax=1)
# s_mi[:40].plot.bar(figsize=(12, 2), rot=45)
# s_mi.to_frame().T.style.background_gradient(axis=None, vmin=0, vmax=1)

# %%
def smallest_corr(X, min_value=-1):
    X_mask = X.copy()
    if X.shape[0] == X.shape[1]:
        np.fill_diagonal(X_mask.values, np.nan)
    X_mask = X_mask.where(lambda x: x.abs() > min_value)
    
    X_small = X_mask.dropna(how='all', axis=0)\
                     .dropna(how='all', axis=1)\
                     .dropna(how='all', axis=0)
    
    q_mi = pd.cut(s_mi, bins=5, labels=False)
    mi_pal = sns.color_palette('Reds_r', len(q_mi.unique()))
    lut = dict(zip(q_mi.unique(), mi_pal))
    mi_colors = q_mi.map(lut)
    
    # return X_small.style.background_gradient(axis=None, cmap='magma', vmin=0, vmax=1)
    # return sns.clustermap(X_small.fillna(0), vmin=0, vmax=1, method='complete', row_colors=mi_colors, col_colors=mi_colors)
    return sns.clustermap(X, vmin=0, vmax=1, method='complete', mask=X_mask.isna(), xticklabels=True, yticklabels=True, linewidths=1, row_colors=mi_colors, col_colors=mi_colors, figsize=(12, 12), cmap='inferno')

smallest_corr(X_corr_num, 0.5)

# %%
X_corr_num.where(lambda x: x.abs() > 0.5).dropna(thresh=4, axis=0).index

# %%
test_new(
    X_clean.eval('GrLivArea / TotRmsAbvGrd'),
    #X_clean.eval('(`1stFlrSF` + `2ndFlrSF`) / TotRmsAbvGrd'),
    #X_clean.eval('GrLivArea / (FullBath+1)'),
    #X_clean.eval('GarageArea / (GarageCars+1)'),
    #X_clean.eval('BsmtFinSF1 / (BsmtFullBath+1)'),
    X_clean.eval('TotalBsmtSF - `1stFlrSF`'),
    #X_clean.eval('TotRmsAbvGrd - BedroomAbvGr'),
)

# %%
test_new(
    #X_clean.astype(int).eval('GarageQual * GarageCond'),
    #X_clean.astype(int).eval('Fireplaces * FireplaceQu'),
    #X_clean.astype(int).eval('PoolArea * PoolQC'),
    X_clean.eval('OverallQual * YearBuilt'),
)

# %%
smallest_corr(X_corr_mix, 0.5)

# %%
test_new(
    pd.get_dummies(X_clean['GarageType']).mul(X_clean['GarageCars'], axis=0)
)

# %%
smallest_corr(X_corr_cat, 0.4)

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA

def run_pca(columns=columns_numeric, X_clean=X_clean, s_mi=s_mi):
    X = X_clean.astype(float).transform(preprocessing.scale)
    #X = pd.DataFrame(X, columns=X_clean.columns, index=X_clean.index)
    pca = PCA(random_state=random_state).fit(X[columns])
        
    loadings = pd.DataFrame(pca.components_.T, index=X_clean[columns].columns)
    loadings = pd.concat([s_mi[columns], loadings], axis=1).sort_values(s_mi.name, ascending=False)
    
    X_pca = pd.DataFrame(pca.transform(X[columns]), index=X_clean.index)
    
    return pca, X_pca, loadings


def plot_pca(pca, X_pca, loadings):
    g = pd.DataFrame(pca.explained_variance_ratio_).plot.bar(figsize=(12, 6))
    s = loadings.style.bar(align='zero', vmin=-1, vmax=1)
    return g, s

# %%
pca, X_pca, loadings = run_pca()
g, s = plot_pca(pca, X_pca, loadings)
g
display(s)

# %%
test_new(X=pd.concat([X_pca, X_clean.drop(columns=columns_numeric)], axis=1))

# %%
test_new(X_pca)

# %%
# for i in range(1, 10):
#     display(test_new(X_pca.iloc[:, 0:i]))
display(test_new(X_pca.iloc[:, 0]))

# %%
test_new(X_clean.astype(float).eval("(TotRmsAbvGrd+TotalBsmtSF)/(GrLivArea+`1stFlrSF`)")) # loading 52

# %%
test_new(X_clean.astype(float).eval("(FireplaceQu+Fireplaces)/YearBuilt"))

# %%
test_new(X_clean.astype(float).eval("BsmtQual*YearRemodAdd"))

# %% [markdown]
# # Feature Engineering - Multivariate

# %%
pca, X_pca, loadings = run_pca(X_corr_num.where(lambda x: x.abs() > 0.6).dropna(thresh=4, axis=0).index)
g, s = plot_pca(pca, X_pca, loadings)
s

# %%
#for i in range(1, 5):
#    display(test_new(X_pca.iloc[:, 0:i]))
    
test_new(X_pca.iloc[:, 0])

# %%
sns.catplot(data=X_clean, x='Neighborhood', y=y, kind='boxen')

# %%
test_new(
    X_clean.groupby('Neighborhood')['GrLivArea'].transform('mean'),
    #X_clean.groupby('Neighborhood')['GrLivArea'].transform('std'),
)

# %%
test_new(
    X_clean.groupby('Neighborhood')['GrLivArea'].transform('median'),
    #X_clean.groupby('Neighborhood')['GrLivArea'].transform('std'),
)

# %%
sns.catplot(data=X_clean, x='MSSubClass', y=y, kind='boxen')

# %%
test_new(
    X_clean.groupby('MSSubClass')['GrLivArea'].transform('mean'),
    #X_clean.groupby('MSSubClass')['LotArea'].transform('mean'),
)

# %%
sns.displot(data=X_pre, y='Neighborhood', x='MSSubClass')

# %%
test_new(
    #X_clean.groupby(['MSSubClass', 'Neighborhood'])['LotArea'].transform('median'),
    X_clean.groupby(['MSSubClass', 'Neighborhood'])['GrLivArea'].transform('median'),
)

# %%
test_new(
    X_clean.groupby(['MSSubClass', 'Neighborhood', 'MSZoning'])['GrLivArea'].transform('mean'),
    X_clean.groupby(['MSSubClass', 'Neighborhood', 'MSZoning'])['LotArea'].transform('mean'),
)

# %%
test_new(
    #X_clean.groupby(['MSSubClass', 'Neighborhood', 'MSZoning'])['GrLivArea'].transform('median'),
    X_clean.groupby(['MSSubClass', 'Neighborhood', 'MSZoning'])['OverallQual'].transform(lambda x: x.mode()[0]),
)

# %%
sns.lmplot(data=X_pre.join(y), x='GrLivArea', y='SalePrice', col='Neighborhood', ci=None, col_wrap=5, height=2)

# %%
from sklearn.linear_model import LinearRegression

lr_all = X_clean.join(y).groupby('Neighborhood', group_keys=False).apply(
    lambda x: pd.Series(LinearRegression().fit(x[['GrLivArea']], x['SalePrice']).predict(x[['GrLivArea']]), index=x.index)
)

test_new(lr_all)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.base import TransformerMixin

class ModelGroupBy(TransformerMixin):
    def __init__(self, model, cols, groupby_col, **model_kwargs):
        self.model_ = model
        if isinstance(cols, list):
            self.cols_ = cols
        elif isinstance(cols, str):
            self.cols_ = [cols]
        self.groupby_col_ = groupby_col
        self.model_kwargs_ = model_kwargs

    def fit(self, X, y):
        self.fitted_models_ = {}
        self.median_ = y.median()
        
        gb = X.join(y).groupby(self.groupby_col_, group_keys=False)
        for name, group in gb:
            group_x = group[self.cols_]
            group_y = group[y.name]
            self.fitted_models_[name] = self.model_(**self.model_kwargs_).fit(group_x, group_y)
        
        return self

    def transform(self, X):
        s_predict = []
        
        gb = X.groupby(self.groupby_col_, group_keys=False)
        for name, group in gb:
            group_x = group[self.cols_]
            if (name in self.fitted_models_.keys()) and group_x.shape[0] > 1:
                group_model = self.fitted_models_[name]
                values = group_model.predict(group_x)
            else:
                values = self.median_
            
            s = pd.Series(values, index=group.index, name=f'model_{self.groupby_col_}')
            s_predict.append(s)
            
        X_predict = pd.concat(s_predict)
        return X.join(X_predict)

# %%
(ModelGroupBy(LinearRegression, cols="GrLivArea", groupby_col='Neighborhood').fit_transform(X_clean, y).iloc[:, -1] == lr_all.sort_index()).all()

# %% [markdown]
# class is correct (result between one-liner and class for all index transformations is same)

# %%
pipe_lr = ModelGroupBy(LinearRegression, cols="GrLivArea", groupby_col='Neighborhood')
test_new(pipe=pipe_lr)

# %%
pca, X_pca, loadings = run_pca(area_columns)
g, s = plot_pca(pca, X_pca, loadings)
s

# %%
test_new(X_pca[[0]])

# %%
test_new(
#     X_clean.eval('(WoodDeckSF+OpenPorchSF+EnclosedPorch+`3SsnPorch`+ScreenPorch+PoolArea) / (LotArea+1)'), # External bonus area
    X_clean.eval('GrLivArea / LotArea'), # External / interior
    X_clean.eval('GrLivArea + TotalBsmtSF'), # External / interior
    #X_clean.eval('(`1stFlrSF`+`2ndFlrSF`) / (TotalBsmtSF+1)'),
    #X_clean.eval('MasVnrArea/(GarageArea+1)')
    #X_clean.eval('LotArea / (GrLivArea+TotalBsmtSF+GarageArea)'),
)

# %%
pca, X_pca, loadings = run_pca(X.filter(regex='Qual|Cond|PoolQC|FireplaceQu').columns)
g, s = plot_pca(pca, X_pca, loadings)
s

# %%
test_new(X_pca[0])

# %%
test_new(
    (X_clean[["BsmtQual", "FireplaceQu", "PoolQC", 'Fence', "MiscFeature", "Alley"]] != 0).astype(int).sum(axis=1)
)

# %%
test_new(
    #X_clean.eval("OverallCond/OverallQual"),
    X_clean.astype(float).eval("(Condition1+Condition2)/OverallCond"),
)

# %%
test_new(
    (X_clean[["BsmtQual", "FireplaceQu", "PoolQC", 'OverallQual', 'GarageQual']] != 0).astype(int).sum(axis=1)
)

# %% [markdown]
# ## Target Encoder

# %%
from category_encoders import MEstimateEncoder

# %%
class CrossFoldEncoder:
    def __init__(self, encoder, **kwargs):
        self.encoder_ = encoder
        self.kwargs_ = kwargs  # keyword arguments for the encoder
        self.cv_ = KFold(n_splits=5)

    # Fit an encoder on one split and transform the feature on the
    # other. Iterating over the splits in all folds gives a complete
    # transformation. We also now have one trained encoder on each
    # fold.
    def fit_transform(self, X, y, cols):
        self.fitted_encoders_ = []
        self.cols_ = cols
        X_encoded = []
        for idx_encode, idx_train in self.cv_.split(X):
            fitted_encoder = self.encoder_(cols=cols, **self.kwargs_)
            fitted_encoder.fit(
                X.iloc[idx_encode, :], y.iloc[idx_encode],
            )
            X_encoded.append(fitted_encoder.transform(X.iloc[idx_train, :])[cols])
            self.fitted_encoders_.append(fitted_encoder)
        X_encoded = pd.concat(X_encoded)
        X_encoded.columns = [name + "_encoded" for name in X_encoded.columns]
        return X_encoded

    # To transform the test data, average the encodings learned from
    # each fold.
    def transform(self, X):
        from functools import reduce

        X_encoded_list = []
        for fitted_encoder in self.fitted_encoders_:
            X_encoded = fitted_encoder.transform(X)
            X_encoded_list.append(X_encoded[self.cols_])
        X_encoded = reduce(
            lambda x, y: x.add(y, fill_value=0), X_encoded_list
        ) / len(X_encoded_list)
        X_encoded.columns = [name + "_encoded" for name in X_encoded.columns]
        return X_encoded

# %%
test_new(CrossFoldEncoder(MEstimateEncoder, m=1).fit_transform(X_clean, y, cols=["MSSubClass"]))

# %%
test_new(pipe=MEstimateEncoder(m=1, cols=['MSSubClass']))

# %%
test_new(CrossFoldEncoder(MEstimateEncoder, m=1).fit_transform(X_clean, y, cols=['Neighborhood']))

# %%
test_new(CrossFoldEncoder(MEstimateEncoder, m=1).fit_transform(X_clean, y, cols=['MSZoning']))

# %% [markdown]
# ## Interaction + LassoCV

# %%
def scale_linear(X):
    X_num_scaled = X[columns_numeric].astype(float)
    X_cat_scaled = X[columns_object]
    
    X_num_scaled = preprocessing.scale(X_num_scaled)
    encoder = preprocessing.OneHotEncoder(sparse=False)
    X_cat_scaled = encoder.fit_transform(X_cat_scaled)
    
    X_num_scaled = pd.DataFrame(X_num_scaled, index=X.index, columns=columns_numeric)
    X_cat_scaled = pd.DataFrame(X_cat_scaled, index=X.index, columns=encoder.get_feature_names(columns_object))
    
    return X_num_scaled.join(X_cat_scaled)

scale_linear(X_clean)

# %%
test_new(X=scale_linear(X_clean))

# %%
X_int = preprocessing.PolynomialFeatures(interaction_only=True, include_bias=False).fit_transform(X_clean)
X_int = pd.DataFrame(X_int, index=X_clean.index)
test_new(X=X_int)

# %%
X_clean_scaled = scale_linear(X_clean)

X_int = preprocessing.PolynomialFeatures(interaction_only=True, include_bias=False).fit_transform(X_clean_scaled)
X_int = pd.DataFrame(X_int, index=X_clean.index)
test_new(X=X_int)

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LassoCV, Lasso

X_clean_scaled = scale_linear(X_clean)

interaction_transform = preprocessing.PolynomialFeatures(interaction_only=True, include_bias=False)
X_inter = interaction_transform.fit_transform(X_clean_scaled)
X_inter = pd.DataFrame(X_inter,
                       index=X_clean.index,
                       columns=interaction_transform.get_feature_names(X_clean_scaled.columns))

selecter = SelectFromModel(LassoCV(n_alphas=10, max_iter=10_000))
X_inter_select = selecter.fit_transform(X_inter, y_proc)
X_inter_select = pd.DataFrame(X_inter_select,
                              index=X_clean.index,
                              columns=X_inter.columns[selecter.get_support()])

# %%
X_inter.columns.shape, X_inter_select.columns.shape

# %%
s_inter_coef = pd.Series(selecter.estimator_.coef_, index=X_inter.columns, name='coef')\
                .drop(index=columns_numeric)\
                .sort_values(ascending=False)

s_inter_coef.head(20).to_frame().style.bar()

# %%
s_inter_mi, style_inter_mi = show_mi(X_inter_select, y=y_proc)
s_inter_mi.to_frame().head(40).style.bar()

# %%
test_new(X_inter_select.loc[:, s_inter_mi.drop(index=columns_numeric, errors='ignore').index])

# %%
X_inter_select_top = X_inter_select.loc[:, s_inter_mi.drop(index=columns_numeric, errors='ignore').head(20).index]

test_new(X_inter_select_top)

# %% [markdown]
# I add the intersections which have a better MI scores than there single counterparts

# %%
test_new(
    X_clean.astype(float).eval("OverallQual*KitchenQual"),
    #X_clean.astype(float).eval("OverallQual*BsmtQual"),
    X_clean.astype(float).eval("ExterQual*Fireplaces"),
    X_clean.astype(float).eval("CentralAir*GarageCars"),
    X_clean.astype(float).eval("TotalBsmtSF*KitchenAbvGr"),
    X_clean.astype(float).eval("ExterQual*FireplaceQu"),
    X_clean.astype(float).eval("FullBath*GarageYrBlt"),
    #X_clean.astype(float).eval("TotalBsmtSF*Condition2_2"),
    X_clean.astype(float).eval("TotalBsmtSF*Electrical"),
    X_clean.astype(float).eval("YearBuilt*CentralAir"),
    #X_clean.astype(float).eval("GarageCars*MiscFeature_1"),
    X_clean.astype(float).eval("BsmtQual*BsmtExposure"),
    X_clean.astype(float).eval("Alley*ExterQual"),
    X_clean.astype(float).eval("Street*GarageArea"),
    X_clean.astype(float).eval("ExterCond*GarageArea"),
    X_clean.astype(float).eval("LandContour*GarageArea"),
    X_clean.astype(float).eval("CentralAir*FullBath"),
    X_clean.astype(float).eval("LotShape*FullBath"),
    X_clean.astype(float).eval("ExterQual*ScreenPorch"),
    X_clean.astype(float).eval("BsmtHalfBath*KitchenQual"),
    X_clean.astype(float).eval("LandContour*BsmtQual"),
)

# %% [markdown]
# # Outliers

# %% [markdown]
# ## From features

# %%
def z_outliers(X, X_train=X_clean):
    X_num = X.select_dtypes('number')

    q1 = X_num.quantile(1/4)
    q3 = X_num.quantile(3/4)
    iqr = q3 - q1

    is_outlier_matrix = (X_num < q1-1.5*iqr) | (X_num > q3+1.5*iqr)
    return is_outlier_matrix
    
is_outlier_matrix = z_outliers(X_clean)

test_new(is_outlier_matrix.sum(axis=1) > 0)

# %%
from sklearn.ensemble import IsolationForest

clf_outlier = IsolationForest(random_state=random_state).fit(X_clean.astype(float))

test_new(pd.Series(clf_outlier.predict(X_clean.astype(float)), index=X_clean.index))

# %% [markdown]
# ## From target
#
# https://www.kaggle.com/jack89roberts/top-7-using-elasticnet-with-interactions/data#outliers

# %%
y_pred_lr = pd.Series(RidgeCV().fit(X_clean, np.log(y)).predict(X_clean), index=X_clean.index)
resid = np.log(y) - y_pred_lr

outliers = ((resid - resid.mean()) / resid.std()).abs() > 3
sns.scatterplot(x=np.log(y), y=y_pred_lr, hue=outliers)

# %%
test_new(outliers)

# %%
# def drop_outliers(X, y):
#     return X.drop(index=outliers[outliers].index, errors='ignore'), y.drop(index=outliers[outliers].index, errors='ignore')

# test_new(outliers, pipe=preprocessing.FunctionTransformer(drop_outliers))

# %% [markdown]
# # Processing Summary

# %% [markdown]
# Collection of individual best

# %%
# X_corr_num = X_clean[columns_numeric].astype(float).corr(method='spearman')

def test_proc(X=X_clean):
    X = X.copy()
    
    _, X_pca_all, _ = run_pca()
    _, X_pca_area, _ = run_pca(area_columns)
    #_, X_pca_num, _ = run_pca(X_corr_num.where(lambda x: x.abs() > 0.6).dropna(thresh=4, axis=0).index)
    
    new_columns = [
        (X[["BsmtQual", "FireplaceQu", "PoolQC", 'Fence', "MiscFeature", "Alley"]] != 0).astype(int).sum(axis=1),
        #X.eval('GrLivArea / LotArea'), # External / interior
        #X.eval('GrLivArea + TotalBsmtSF'), # External / interior
        #X.astype(float).eval("(FireplaceQu+Fireplaces)/YearBuilt"),
        #X.astype(float).eval("BsmtQual*YearRemodAdd"),
        X.groupby('Neighborhood')['GrLivArea'].transform('median'),
        X.eval("TotalBsmtSF * YearRemodAdd"), # Unknown origin
        #CrossFoldEncoder(MEstimateEncoder, m=1).fit_transform(X_clean, y, cols=['MSZoning']),
        X_pca_all[0],
        X_pca_area[0],
        #X_pca_num[0],
    ]
    
    s_mi, _ = show_mi(X, y=y_proc)
    X = X.loc[:, s_mi > 1e-4]
    
    filtered_area_columns = X.columns.intersection(area_columns)
    sqrt_transform = preprocessing.FunctionTransformer(lambda x: np.sqrt(x+1)*(x!=0))
    area_transform = ColumnTransformer([('area', sqrt_transform, filtered_area_columns)],
                                  remainder='passthrough')
    
    #lr_transform = ModelGroupBy(LinearRegression, cols="GrLivArea", groupby_col='Neighborhood')
    
    pipe = Pipeline([
        #('lr', lr_transform),
        ('me', MEstimateEncoder(m=1, cols=['MSZoning'])),
        ('area', area_transform)
    ]) 
        
    return test_new(*new_columns, X=X, pipe=pipe)

test_proc()

# %%
# (X_clean.replace(X_clean.groupby('MSSubClass')['GrLivArea'].agg('mean'))['MSSubClass'] == X_clean.groupby('MSSubClass')['GrLivArea'].transform('mean')).all()

# %% [markdown]
# I changed the order to add more coherence between the new features and the transformation. Changed area to "sqrt" and then calculate new features to keep same unit coherence.

# %%
from sklearn.feature_selection import mutual_info_regression

def show_mi(X, y=y, clean=False):
    if clean:
        X = force_clean(X)
    
    columns_discrete = X.select_dtypes(['object', 'category'])
    discrete_features = X.columns.isin(columns_discrete)
    
    mi = mutual_info_regression(X, y,
                                random_state=random_state,
                                discrete_features=discrete_features)

    s = pd.Series(mi, index=X.columns, name='mutual_info_regression')\
          .sort_values(ascending=False)
          
    return s, s.to_frame().style.bar()

# %%
def create_features(X=X_clean, X_train=X_clean, y=y_proc):
    X = X.copy()
    X_train = X_train.copy()
    
    # PCA - best column numerical
    #X_corr_num = X_train[columns_numeric].astype(float).corr(method='spearman')
    #best_num_columns = X_corr_num.where(lambda x: x.abs() > 0.6).dropna(thresh=4, axis=0).index
    
    # PCA - fit
    scaler_pca = preprocessing.StandardScaler()
    X_train_scaled = pd.DataFrame(scaler_pca.fit_transform(X_train.astype(float)[columns_numeric]), index=X_train.index, columns=columns_numeric)
    pca_all = PCA(random_state=random_state).fit(X_train_scaled[columns_numeric])
    pca_area = PCA(random_state=random_state).fit(X_train_scaled[area_columns])
    #pca_num = PCA(random_state=random_state).fit(X_train_scaled[best_num_columns])
    
    # PCA - transform
    X_scaled = pd.DataFrame(scaler_pca.transform(X.astype(float)[columns_numeric]), index=X.index, columns=columns_numeric)
    X_pca_all = pd.DataFrame(pca_all.transform(X_scaled[columns_numeric]), index=X.index)
    X_pca_area = pd.DataFrame(pca_area.transform(X_scaled[area_columns]), index=X.index)
    #X_pca_num = pd.DataFrame(pca_num.transform(X_scaled[best_num_columns]), index=X.index)
    
    # Transformer - ME
    m_encoder = MEstimateEncoder(m=1, cols=["MSZoning"])
    m_encoder.fit(X_train, y)
    X_encoded = m_encoder.transform(X)
    
    # # Transformer - 
    #lr = ModelGroupBy(LinearRegression, cols="GrLivArea", groupby_col='Neighborhood')
    #lr.fit(X_train, y)
    #X_lr = lr.transform(X)
    
    # Transformer - Area
    area_transform = preprocessing.FunctionTransformer(lambda x: np.sqrt(x+1)*(x!=0))
    #area_transform = preprocessing.PowerTransformer()
    area_transform.fit(X_train[area_columns])
    X[area_columns] = pd.DataFrame(area_transform.transform(X[area_columns]), index=X.index)
    
    encoded_1 = X_train.groupby('Neighborhood')['GrLivArea'].agg('median')
    
    new_series = [
        (X[["BsmtQual", "FireplaceQu", "PoolQC", 'Fence', "MiscFeature", "Alley"]] != 0).astype(int).sum(axis=1),
        #X.eval('GrLivArea / LotArea'), # External / interior
        #X.eval('GrLivArea + TotalBsmtSF'), # External / interior
        #X.astype(int).eval("(FireplaceQu+Fireplaces)/YearBuilt"),
        X.replace(encoded_1)['Neighborhood'], #X.groupby('Neighborhood')['GrLivArea'].transform('median'),
        #X.eval("TotalBsmtSF * YearRemodAdd"), # Unknown origin
        #CrossFoldEncoder(MEstimateEncoder, m=1).fit_transform(X_clean, y, cols=['MSZoning']),
        X_pca_all[0],
        X_pca_area[0],
        #X_pca_num[0],
        X_encoded.iloc[:, 0],
        #X_lr['model_Neighborhood']
    ]
    
    s_mi, _ = show_mi(X_train)
    X = X.loc[:, s_mi > 1e-4]
    #print(s_mi[~(s_mi > 1e-4)]) # Utilities, MiscVal, MiscFeatures, 3SsnPorch, MoSold, MiscVal, PoolQC
    
    X = X.join([s.rename(f'new_{i}') for i, s in enumerate(new_series)])
    
    return X

test_new(X=create_features())

# %% [markdown]
# ## from the raw data

# %%
X_pre = preproc(X)
X_test_pre = preproc(X_test)

X_clean = force_clean(X_pre, X_pre)
X_clean_test = force_clean(X_test_pre, X_pre)

X_proc = create_features(X_clean, X_clean)
X_proc_test = create_features(X_clean_test, X_clean)

# %%
# columns_proc_category = X_proc.columns[X_proc.columns.isin(columns_category)]
# columns_proc_ordinal = X_proc.drop(columns=columns_proc_category).select_dtypes('category').columns
# columns_proc_numeric = X_proc.select_dtypes('number').columns

columns_proc_category = X_proc.drop(columns=columns_numeric, errors='ignore').columns
columns_proc_numeric = columns_numeric

# %%
X_proc_test.isna().sum().loc[lambda x: x>0]

# %%
score_models(X=X_proc)

# %% [markdown]
# ### Outliers processing

# %%
score_models(X=X_proc.loc[~outliers, :], y=y_proc.loc[~outliers])

# %% [markdown]
# It seems interesting to drop outliers to avoid data noise in the training process...

# %%
# X_proc = X_proc.loc[~outliers, :]
# y_proc = y_proc.loc[~outliers]

# %%
y_encoded, _ = pd.qcut(y_proc, q=10).factorize()

def get_folds(X=X_proc, y=y_proc, y_encoded=y_encoded):
    y_encoded, _ = pd.qcut(y, q=10).factorize()
    return folds.split(X, y_encoded)

# %% [markdown]
# # Modeling

# %%
from sklearn.linear_model import ElasticNetCV, Lasso, Ridge, RidgeCV
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.svm import LinearSVR

# %% [markdown]
# ## Model Selection
# - LightGBM for sure
# - ElasticNet as the linear model (different outputs)
# - 3rd one choice: MLP ?
#
# Then stacking with RF

# %%
def scale(X, X_train=X_proc):
    X_norm = X.drop(columns=columns_proc_category)
    X_train_norm = X_train.drop(columns=columns_proc_category)
    
    #boxcox = preprocessing.PowerTransformer()
    #X_train_boxcox = boxcox.fit_transform(X_train.drop(columns=columns_proc_category))
    scaler = preprocessing.StandardScaler().fit(X_train_norm)
    
    X_norm = pd.DataFrame(scaler.transform(X_norm), columns=X_norm.columns, index=X_norm.index)
    
    #X_norm = X_norm.join(pd.get_dummies(X[columns_proc_category]))
    encoder = preprocessing.OneHotEncoder(sparse=False, handle_unknown='ignore').fit(X_train[columns_proc_category])
    X_norm = X_norm.join(pd.DataFrame(encoder.transform(X[columns_proc_category]),
                                      columns=encoder.get_feature_names(columns_proc_category),
                                      index=X.index))
    return X_norm

X_proc_norm = scale(X_proc)
X_proc_norm_test = scale(X_proc_test)
print('any NaN ?', X_proc_norm.isna().any(axis=None))

# %%
# model = MLPRegressor(hidden_layer_sizes=(100, 1000, 100), random_state=random_state, max_iter=10_000, solver='adam', activation='tanh', early_stopping=True)

# r = cross_val_score(model, X_proc_norm, y_proc,
#                     cv=folds.split(X_proc, y_encoded),
#                     scoring='neg_root_mean_squared_error')
# print(-r.mean()) # 0.3871994246713676

# %%
model_selection_dict = {
    "LGBM": lgb.LGBMRegressor(objective="rmse", random_state=random_state),
    "XGB": xgb.XGBRegressor(objective='reg:squarederror', eval_metric='rmse', random_state=random_state),
    "RandomForest": RandomForestRegressor(random_state=random_state),
    "ExtraTrees": ExtraTreesRegressor(random_state=random_state, bootstrap=True),
    "SVR": SVR(),
    #"SVR_linear": LinearSVR(max_iter=10_000),
    "ElasticNet": ElasticNet(max_iter=10_000, random_state=random_state), 
    "Ridge": Ridge(),
}
model_selection_score = {}

for name, model in model_selection_dict.items():
    if name in ['SVR']:
        x = X_proc_norm
    elif name == 'XGB':
        x = X_proc.copy()
        columns_proc_category = x.select_dtypes('category').columns
        x[columns_proc_category] = x[columns_proc_category].astype(int)
    else:
        x = X_proc
        
    r = cross_val_score(model, x, y_proc,
                        cv=folds.split(X_proc, y_encoded),
                        scoring='neg_root_mean_squared_error')
    model_selection_score[name] = -r.mean()
    
pd.Series(model_selection_score).sort_values()

# %% [markdown]
# ## SVR Hyperparameter Opt.

# %%
import optuna

# %%
def objective(trial):
    gamma = trial.suggest_categorical("gamma", ['auto', 'scale'])
    C = trial.suggest_float("C", 1e-10, 1e10, log=True)
    epsilon = trial.suggest_float("epsilon", 0.001, 0.5, log=True)
    
    kernel = 'rbf' #trial.suggest_categorical("kernel", ['poly', 'rbf'])
    if kernel=='poly':
        degree = trial.suggest_int("degree", 2, 5)
        coef0 = trial.suggest_float("coef0", 0.001, 10.0, log=True)
    else:
        degree = 3 # default
        coef0 = 0.0 # default
        
    model = SVR(gamma=gamma,
                C=C,
                kernel=kernel,
                degree=degree,
                coef0=coef0,
                epsilon=epsilon)

    r = cross_val_score(model, X_proc_norm, y_proc,
                        cv=folds.split(X_proc, y_encoded),
                        scoring='neg_root_mean_squared_error')
    return -r.mean()

study_rbf = optuna.create_study()
study_rbf.optimize(objective, n_trials=30)

# %%
print("Best score:", study_rbf.best_value)
print(study_rbf.best_params)

print("Best params:", study_rbf.best_params)
print("  Params: ")
for key, value in study_rbf.best_params.items():
    print("    {}: {}".format(key, value))

# %%
display(optuna.visualization.plot_optimization_history(study_rbf))
display(optuna.visualization.plot_param_importances(study_rbf))

# %%
def objective(trial):
    gamma = trial.suggest_categorical("gamma", ['auto', 'scale'])
    C = trial.suggest_float("C", 1e-10, 1e10, log=True)
    epsilon = trial.suggest_float("epsilon", 0.001, 0.5, log=True)
    
    kernel = 'poly' #trial.suggest_categorical("kernel", ['poly', 'rbf'])
    if kernel=='poly':
        degree = trial.suggest_int("degree", 2, 5)
        coef0 = trial.suggest_float("coef0", 0.001, 10.0, log=True)
    else:
        degree = 3 # default
        coef0 = 0.0 # default
        
    model = SVR(gamma=gamma,
                C=C,
                kernel=kernel,
                degree=degree,
                coef0=coef0,
                epsilon=epsilon)

    r = cross_val_score(model, X_proc_norm, y_proc,
                        cv=folds.split(X_proc, y_encoded),
                        scoring='neg_root_mean_squared_error')
    return -r.mean()

study_poly = optuna.create_study()
study_poly.optimize(objective, n_trials=50)

# %%
print("Best score:", study_poly.best_value)
print(study_poly.best_params)

print("Best params:", study_poly.best_params)
print("  Params: ")
for key, value in study_poly.best_params.items():
    print("    {}: {}".format(key, value))

# %%
display(optuna.visualization.plot_optimization_history(study_poly))
display(optuna.visualization.plot_param_importances(study_poly))

# %% [markdown]
# ## Ridge CV

# %%
ridgecv = RidgeCV(alphas=[1, 5, 10, 50, 100, 500, 1000],
                       cv=folds.split(X_proc, y_encoded),
                       scoring='neg_root_mean_squared_error')

ridgecv.fit(X_proc, y_proc)

print("RidgeCV alpha:", ridgecv.alpha_)

ridge = Ridge(alpha=ridgecv.alpha_)
r = cross_val_score(ridge, X_proc, y_proc,
                    cv=get_folds(),
                    scoring='neg_root_mean_squared_error')
print(-r.mean())

# %% [markdown]
# ## ElasticNet CV HyperParameter Opt.

# %%
model_linear_cv = ElasticNetCV(l1_ratio=np.arange(0.1, 1, 0.1),
                               alphas=np.arange(1, 1e3, 100),
                               max_iter=10_000,
                               random_state=random_state, cv=get_folds())

model_linear_cv.fit(X_proc, y_proc)

print("ElasticNetCV alpha:", model_linear_cv.alpha_)
print("ElasticNetCV l1_ratio:", model_linear_cv.l1_ratio_)

model_linear = ElasticNet(alpha=model_linear_cv.alpha_,
                          l1_ratio=model_linear_cv.l1_ratio_)

r = cross_val_score(model_linear, X_proc, y_proc,
                    cv=folds.split(X_proc, y_encoded),
                    scoring='neg_root_mean_squared_error')
print(-r.mean())

# %% [markdown]
# ElasticNetCV converge towards a Ridge model

# %% [markdown]
# ## XGB Hyperparameter Opt.

# %%
fixed_folds = []

for train_index, test_index in get_folds():
    fixed_folds.append((train_index, test_index))

# %%
X_proc_xgb = X_proc.select_dtypes('number').join(X_proc.select_dtypes('category').apply(lambda x: x.cat.codes))
X_proc_test_xgb = X_proc_test.select_dtypes('number').join(X_proc_test.select_dtypes('category').apply(lambda x: x.cat.codes))

# %%
dtrain = xgb.DMatrix(X_proc_xgb, label=y_proc, enable_categorical=True)

eval_hist = {}
for eta in [0.01, 0.03, 0.1, 0.3]:
    eval_hist[eta] = xgb.cv(
        params={"objective":"reg:squarederror", "eta":eta, "eval_metric":"rmse"},
        dtrain=dtrain,
        num_boost_round=1_000,
        early_stopping_rounds=100,
        folds=fixed_folds,
        stratified=False,
        shuffle=False,
        metrics='rmse',
        verbose_eval=False,
    )

# %%
r_eval_hist_train, r_eval_hist_test = {}, {}
for eta, d in eval_hist.items():
    r_eval_hist_train[eta] = pd.Series(d['train-rmse-mean'])
    r_eval_hist_test[eta] = pd.Series(d['test-rmse-mean'])

r_eval_hist_train = pd.DataFrame(r_eval_hist_train)
r_eval_hist_test = pd.DataFrame(r_eval_hist_test)
r_eval_hist_test.plot(style='-')

# %%
pd.concat([r_eval_hist_test.idxmin().rename('num_boost'),
           r_eval_hist_test.min().rename('min_test_score'),
           r_eval_hist_train.where(r_eval_hist_test.apply(lambda x: x==x.min())).agg('sum').rename('min_train_score')], axis=1)

# %%
dtrain = xgb.DMatrix(X_proc_xgb, label=y_proc, enable_categorical=True)

eval_hist_booster = {}
for booster in ["gbtree", "gblinear", "dart"]:
    eval_hist_booster[booster] = xgb.cv(
        params={"objective":"reg:squarederror", "eta":0.03, "eval_metric":"rmse", "booster":booster},
        dtrain=dtrain,
        num_boost_round=2_000,
        early_stopping_rounds=100,
        folds=fixed_folds,
        stratified=False,
        shuffle=False,
        metrics='rmse',
        verbose_eval=False,
    )

# %%
r_eval_hist_train, r_eval_hist_test = {}, {}
for booster, d in eval_hist_booster.items():
    r_eval_hist_train[booster] = pd.Series(d['train-rmse-mean'])
    r_eval_hist_test[booster] = pd.Series(d['test-rmse-mean'])

r_eval_hist_train = pd.DataFrame(r_eval_hist_train)
r_eval_hist_test = pd.DataFrame(r_eval_hist_test)

pd.concat([r_eval_hist_test.idxmin().rename('num_boost'),
           r_eval_hist_test.min().rename('min_test_score'),
           r_eval_hist_train.where(r_eval_hist_test.apply(lambda x: x==x.min())).agg('sum').rename('min_train_score')], axis=1)

# %%
def objective(trial):
    dtrain = xgb.DMatrix(X_proc_xgb, label=y_proc)#, enable_categorical=True)
    
    params = dict(
        verbosity=0,
        objective="reg:squarederror",
        eval_metric="rmse",
        eta=0.03,
        max_depth=trial.suggest_int("max_depth", 2, 10),
        min_child_weight=trial.suggest_int("min_child_weight", 1, 10),
        colsample_bytree=trial.suggest_float("colsample_bytree", 0.2, 1.0),
        subsample=trial.suggest_float("subsample", 0.2, 1.0),
        reg_alpha=trial.suggest_float("reg_alpha", 1e-4, 1e2, log=True),
        reg_lambda=trial.suggest_float("reg_lambda", 1e-4, 1e2, log=True),
    )
    
    pruning_callback = optuna.integration.XGBoostPruningCallback(trial, "test-rmse")
    history = xgb.cv(
        params,
        dtrain,
        num_boost_round=2_000,
        early_stopping_rounds=100,
        folds=fixed_folds,
        stratified=False,
        shuffle=False,
        callbacks=[pruning_callback]
    )
    
    trial.set_user_attr("n_estimators", len(history))
    
    best_score = history["test-rmse-mean"].values[-1]
    return best_score

pruner = optuna.pruners.MedianPruner(n_warmup_steps=100)
xgb_study = optuna.create_study(pruner=pruner, direction="minimize")
xgb_study.optimize(objective, n_trials=200)

# %%
# def objective(trial):
#     dtrain = xgb.DMatrix(X_proc, label=y_proc, enable_categorical=True)
    
#     param = {
#         "verbosity": 0,
#         "objective": "reg:squarederror",
#         "eval_metric": "rmse",
#         "eta":0.1,
#         "booster": trial.suggest_categorical("booster", ["gbtree", "gblinear", "dart"]),
#         "lambda": trial.suggest_float("lambda", 1e-8, 1.0, log=True),
#         "alpha": trial.suggest_float("alpha", 1e-8, 1.0, log=True),
#     }
    
#     if param["booster"] == "gbtree" or param["booster"] == "dart":
#         param["max_depth"] = trial.suggest_int("max_depth", 1, 9)
#         param["gamma"] = trial.suggest_float("gamma", 1e-8, 1.0, log=True)
#         param["grow_policy"] = trial.suggest_categorical("grow_policy", ["depthwise", "lossguide"])
#     if param["booster"] == "dart":
#         param["sample_type"] = trial.suggest_categorical("sample_type", ["uniform", "weighted"])
#         param["normalize_type"] = trial.suggest_categorical("normalize_type", ["tree", "forest"])
#         param["rate_drop"] = trial.suggest_float("rate_drop", 1e-8, 1.0, log=True)
#         param["skip_drop"] = trial.suggest_float("skip_drop", 1e-8, 1.0, log=True)
    
#     pruning_callback = optuna.integration.XGBoostPruningCallback(trial, "test-rmse")
#     history = xgb.cv(
#         param,
#         dtrain,
#         num_boost_round=1_000,
#         early_stopping_rounds=100,
#         folds=fixed_folds,
#         stratified=False,
#         shuffle=False,
#         callbacks=[pruning_callback]
#     )
    
#     trial.set_user_attr("n_estimators", len(history))
    
#     best_score = history["test-rmse-mean"].values[-1]
#     return best_score

# pruner = optuna.pruners.MedianPruner(n_warmup_steps=5)
# xgb_study = optuna.create_study(pruner=pruner, direction="minimize")
# xgb_study.optimize(objective, n_trials=5)

# %%
print("Number of finished trials: {}".format(len(xgb_study.trials)))

print("Best trial:")
xgb_trial = xgb_study.best_trial

print("  Value: {}".format(xgb_trial.value))

print("  Params: ")
for key, value in xgb_trial.params.items():
    print("    {}: {}".format(key, value))
    
print("  Number of estimators: {}".format(xgb_trial.user_attrs["n_estimators"]))

# %%
display(optuna.visualization.plot_optimization_history(xgb_study))
display(optuna.visualization.plot_param_importances(xgb_study))

# %% [markdown]
# ## LightGBM Hyperparameter Opt.

# %% [markdown]
# ### Hyperparameter Opt. part 1

# %%
dtrain = lgb.Dataset(X_proc, y_proc, categorical_feature=columns_proc_category.tolist(), free_raw_data=False)

eval_hist = {}
for learning_rate in np.geomspace(1e-3, 1e-1, 5):
    eval_hist[learning_rate] = lgb.cv(
        params={"objective":"rmse", "learning_rate":learning_rate},
        train_set=dtrain,
        num_boost_round=10_000,
        early_stopping_rounds=100,
        folds=get_folds(),
        stratified=False,
        shuffle=False,
        metrics='rmse',
        verbose_eval=False,
    )

# %%
r_eval_hist = {}
for eta, d in eval_hist.items():
    r_eval_hist[eta] = pd.Series(d['rmse-mean'])
    
r_eval_hist = pd.DataFrame(r_eval_hist)
r_eval_hist.plot()

# %%
pd.concat([r_eval_hist.idxmin().rename('num_boost'),
           r_eval_hist.min().rename('min_test_score')], axis=1)

# %% [markdown]
# ### Hyperparameter Opt. part 2 with Optuna

# %%
import optuna
from optuna.integration import lightgbm as lgb_opt

dtrain = lgb_opt.Dataset(X_proc, y_proc) #, categorical_feature=columns_proc_category.tolist(), free_raw_data=False)

params = {
    "objective": "regression",
    "random_state": random_state,
    "metric": "rmse",
    "verbosity": -1,
    "learning_rate": 0.01,
    "num_threads":4,
}

study = optuna.create_study()
lgb_tuner = lgb_opt.LightGBMTunerCV(
    params=params,
    train_set=dtrain,
    folds=fixed_folds,
    #shuffle=False,
    #nfold=5,
    shuffle=False,
    stratified=False,
    #feature_name='auto',
    #categorical_feature=columns_proc_category,
    return_cvbooster=True,
    verbose_eval=-1,
    show_progress_bar=False,
    optuna_seed=random_state,
    early_stopping_rounds=100,
    num_boost_round=2_000,
    study=study,
)
lgb_tuner.run()

# %%
optuna.visualization.plot_optimization_history(study)

# %%
lgb_tuner.get_best_booster().best_iteration

# %%
print("Best score:", lgb_tuner.best_score)
best_params = lgb_tuner.best_params
print("Best params:", best_params)
print("  Params: ")
for key, value in best_params.items():
    print("    {}: {}".format(key, value))

# %% [markdown]
# # Stacking

# %% [markdown]
# Cannot use `sklearn.ensemble.StackingRegressor`, because:
# 1. to hyperoptimzie the final_estimator
# 2. because some of them need different processing (could use pipelines but would be a hassle)

# %%
# from sklearn.ensemble import StackingRegressor

# %% [markdown]
# I predict y from each model by hold-out like [sklearn.ensemble.StackingRegressor](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.StackingRegressor.html) for proper Stacking (and avoid overfitting)

# %%
xgb_params = dict(verbosity=0,
                  objective="reg:squarederror",
                  eval_metric="rmse",
                  eta=0.03,
                  num_boost_round=2000, #num_boost_round=int(xgb_trial.user_attrs["n_estimators"]*2),
                  **xgb_trial.params)
print("XGB", xgb_params)

lgb_params = lgb_tuner.best_params
lgb_params['n_jobs'] = 1
lgb_params['n_estimators'] = int(lgb_tuner.get_best_booster().best_iteration*2) # 2000
lgb_params.pop('num_threads')
print("LGB", lgb_params)

# %%
svr_rbf = SVR(kernel='rbf', **study_rbf.best_params).fit(X_proc_norm, y_proc)
svr_poly = SVR(kernel='poly', **study_poly.best_params).fit(X_proc_norm, y_proc)
#elastic_net = model_linear.fit(X_proc_norm, y_proc)
ridge = ridge.fit(X_proc, y_proc)
lgbm = lgb.LGBMRegressor(**lgb_params).fit(X_proc, y_proc)
# xgbm = xgb.train({**xgb_params, **xgb_trial.params}, dtrain,
#                  num_boost_round=int(xgb_trial.user_attrs["n_estimators"]*1.2))
xgbm = xgb.XGBRegressor(**xgb_params).fit(X_proc_xgb, y_proc)

model_dict = {
    "xgbm": xgbm,
    "lgbm": lgbm,
    "svr_rbf": svr_rbf,
    "svr_poly": svr_poly,
    #"elastic_net": elastic_net,
    "ridge": ridge,
}

# %%
from sklearn.model_selection import cross_val_predict

X_out_all = X_proc.copy()
X_out_test_all = X_proc_test.copy()
X_out, X_out_test = pd.DataFrame(), pd.DataFrame()

final_score = {}

for name, model in model_dict.items():
    if name in ["svr_rbf", "svr_poly"]:
        X_train_estimator = X_proc_norm
        X_test_estimator = X_proc_norm_test
    elif name in ['xgbm']:
        X_train_estimator = X_proc_xgb
        X_test_estimator = X_proc_test_xgb
    else:
        X_train_estimator = X_proc
        X_test_estimator = X_proc_test
        
    #model.fit(X_train_estimator, y_proc)
    #s_train = model.predict(X_train_estimator)
    s_train = cross_val_predict(model, X_train_estimator, y_proc,
                                n_jobs=4, cv=5) # get_folds()
    s_test = model.predict(X_test_estimator)
    
    final_score[name] = mean_squared_error(y_proc, s_train, squared=False)
    print(name, final_score[name])
    
    X_out[f'out_{name}'] = pd.Series(s_train, X_proc.index)
    X_out_test[f'out_{name}'] = pd.Series(s_test, X_proc_test.index)
    
X_out_all = X_out_all.join(X_out)
X_out_test_all = X_out_test_all.join(X_out_test)

# pd.Series(final_score).to_frame().style.bar()

# %% [markdown]
# Matrix without initial columns (only outputs)

# %%
r_same_folds = cross_val_score(ExtraTreesRegressor(), X_out, y_proc,
                               cv=get_folds(),
                               scoring='neg_root_mean_squared_error')

r_new_folds_5 = cross_val_score(ExtraTreesRegressor(), X_out, y_proc,
                              cv=5,
                              scoring='neg_root_mean_squared_error')

r_new_folds_10 = cross_val_score(ExtraTreesRegressor(), X_out, y_proc,
                              cv=10,
                              scoring='neg_root_mean_squared_error')

print("same folds:", -r_same_folds.mean(), "random 5 new folds:", -r_new_folds_5.mean(), "random 10 new folds:", -r_new_folds_10.mean())

# %%
# r_same_folds = cross_val_score(LinearRegression(), X_out, y_proc,
#                                cv=get_folds(),
#                                scoring='neg_root_mean_squared_error')

# r_new_folds = cross_val_score(LinearRegression(), X_out, y_proc,
#                               cv=5,
#                               scoring='neg_root_mean_squared_error')

# print("same folds:", -r_same_folds.mean(), "random 5 new folds:", -r_new_folds.mean())
# #>>>same folds: 0.11607714315880906 random new folds: 0.1275152949072265

# %% [markdown]
# Matrix with initial columns

# %%
r_same_folds = cross_val_score(ExtraTreesRegressor(), X_out_all, y_proc,
                               cv=get_folds(),
                               scoring='neg_root_mean_squared_error')

r_new_folds_5 = cross_val_score(ExtraTreesRegressor(), X_out_all, y_proc,
                              cv=5,
                              scoring='neg_root_mean_squared_error')

r_new_folds_10 = cross_val_score(ExtraTreesRegressor(), X_out_all, y_proc,
                              cv=10,
                              scoring='neg_root_mean_squared_error')

print("same folds:", -r_same_folds.mean(), "random 5 new folds:", -r_new_folds_5.mean(), "random 10 new folds:", -r_new_folds_10.mean())

# %%
r_same_folds = cross_val_score(RidgeCV(), X_out_all, y_proc,
                               cv=get_folds(),
                               scoring='neg_root_mean_squared_error')

r_new_folds_5 = cross_val_score(RidgeCV(), X_out_all, y_proc,
                              cv=5,
                              scoring='neg_root_mean_squared_error')

r_new_folds_10 = cross_val_score(RidgeCV(), X_out_all, y_proc,
                              cv=10,
                              scoring='neg_root_mean_squared_error')

print("same folds:", -r_same_folds.mean(), "random 5 new folds:", -r_new_folds_5.mean(), "random 10 new folds:", -r_new_folds_10.mean())
#>>>same folds: 0.11607714315880906 random new folds: 0.1275152949072265

# %%
def objective(trial):
    
    max_depth_isnone = trial.suggest_categorical("max_depth_isnone", [True, False])
    if not max_depth_isnone:
        max_depth = trial.suggest_int("max_depth", 2, 32, log=True)
    else:
        max_depth = None
    min_samples_leaf = trial.suggest_int("min_samples_leaf", 1, 100, log=True)
    min_samples_split = trial.suggest_int("min_samples_split", 2, 64, log=True)
    max_features = trial.suggest_categorical("max_features", ['auto','sqrt','log2'])
    n_estimators = trial.suggest_categorical("n_estimators", [100, 1000]) 
    
    model = ExtraTreesRegressor(criterion='mse',
                                n_estimators=n_estimators,
                                max_depth=max_depth,
                                min_samples_split=min_samples_split,
                                min_samples_leaf=min_samples_leaf,
                                max_features=max_features,
                                random_state=random_state)
    
    folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=random_state+1)
    r = cross_val_score(model, X_out_all, y_proc,
                        cv=folds.split(X_proc, y_encoded),
                        scoring='neg_root_mean_squared_error')
    return -r.mean()

study_final = optuna.create_study()
study_final.optimize(objective, n_trials=40)

# %%
print("Best score:", study_final.best_value)
print(study_final.best_params)

print("Best params:", study_final.best_params)
print("  Params: ")
for key, value in study_final.best_params.items():
    print("    {}: {}".format(key, value))

# %%
display(optuna.visualization.plot_optimization_history(study_final))
display(optuna.visualization.plot_param_importances(study_final))

# %%
final_best_params = dict(study_final.best_params)
final_best_params.pop('max_depth_isnone')
if study_final.best_params['max_depth_isnone']:
    final_best_params['max_depth'] = None

final_estimator = ExtraTreesRegressor(criterion='mse', **final_best_params).fit(X_out_all, y_proc)

# %% [markdown]
# ## Summary

# %% [markdown]
# Our final leaderboard score should be close to the value below:

# %%
r = cross_val_score(final_estimator, X_out_all, y_proc,
                    cv=get_folds(), scoring='neg_root_mean_squared_error')

print("final score in old-out/CV:", -r.mean())

# %%
final_estimator.fit(X_out_all, y_proc)
y_pred = final_estimator.predict(X_out_all)
y_pred = pd.Series(y_pred, index=y_proc.index, name='predictions')
y_pred_test = final_estimator.predict(X_out_test_all)

print("final 'training' score on training data:", mean_squared_error(y_proc, y_pred, squared=False))

# %% [markdown]
# With LinearRegression as final estimator

# %%
# r = cross_val_score(LinearRegression(), X_out_all, y_proc,
#                     cv=get_folds(), scoring='neg_root_mean_squared_error')

# print("final score in old-out/CV:", -r.mean())

# %%
# final_lr = LinearRegression().fit(X_out_all, y_proc)
# y_pred_lr = final_lr.predict(X_out_all)
# y_pred_lr = pd.Series(y_pred_lr, index=y_proc.index, name='predictions')
# y_pred_test_lr = final_lr.predict(X_out_test_all)

# print("final 'training' score on training data:", mean_squared_error(y_proc, y_pred, squared=False))

# %% [markdown]
# # Output visualization

# %%
fig, ax = plt.subplots()
sns.histplot(x=y_proc, y=y_pred, color='b')
sns.regplot(x=y_proc, y=y_pred, color='b', truncate=False, line_kws={"color":"k"}, scatter_kws={"s": 1}, ax=ax)

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

sns.histplot([y_proc, y_pred], ax=axs[0], color=['r', 'b'])
sm.ProbPlot(y_proc.values).qqplot(ax=axs[1], fmt='r')
sm.ProbPlot(y_pred).qqplot(ax=axs[1], fmt='b')
plt.tight_layout()

# %% [markdown]
# With Linear Regression

# %%
# fig, ax = plt.subplots()
# sns.histplot(x=y_proc, y=y_pred_lr, color='b')
# sns.regplot(x=y_proc, y=y_pred_lr, color='b', truncate=False, line_kws={"color":"k"}, scatter_kws={"s": 1}, ax=ax)

# %%
# fig, axs = plt.subplots(1, 2, figsize=(12, 6))

# sns.histplot([y_proc, y_pred_lr], ax=axs[0], color=['r', 'b'])
# sm.ProbPlot(y_proc.values).qqplot(ax=axs[1], fmt='r')
# sm.ProbPlot(y_pred_lr).qqplot(ax=axs[1], fmt='b')
# plt.tight_layout()

# %% [markdown]
# Manual refinment does not work

# %%
# def refinment(y):
#     y = y.copy()
#     index_q1 = y < (y.mean() - y.std())
#     #index_q3 = y > (y.mean() + 2*y.std())
#     y[index_q1] = y[index_q1] ** 0.999
#     #y[index_q3] = y[index_q3] ** 1
#     return y

# y_pred_refi = refinment(y_pred)

# fig, axs = plt.subplots(1, 2, figsize=(12, 6))
# sns.histplot([y_proc, y_pred_refi], ax=axs[0], color=['r', 'g'])
# sm.ProbPlot(y_proc.values).qqplot(ax=axs[1], fmt='r')
# sm.ProbPlot(y_pred_refi).qqplot(ax=axs[1], fmt='b')
# plt.tight_layout()

# print("final score on training data:", mean_squared_error(y_proc, y_pred_refi, squared=False))
## >>> final score on training data: 0.09899767369324648

# %% [markdown]
# # Submission

# %%
def submit(y_pred, name):
    ys = pd.DataFrame(np.exp(y_pred), index=X_test.index, columns=[y.name])
    ys.to_csv(f"{name}.csv")
    return ys

try:
    os.mkdir('kaggle/output/house-prices-advanced-regression-techniques')
except:
    pass

# %%
for name, _ in model_dict.items():
    submit(X_out_test[f'out_{name}'].values, name)
    
X_out_test

# %%
submit(y_pred_test, 'final')

# %%
# submit(y_pred_test_lr, 'final_lr')
